# %% [markdown]
# # Configuration de la connexion à la base de données

# %%
import pandas as pd 
import cx_Oracle
import sys
import os

# %pylab inline
# %load_ext sql
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# On Linux this must be None.
# Instead, the Oracle environment must be set before Python starts.
instant_client_dir = None

if sys.platform.startswith("win"):
    instant_client_dir = r"C:\instantclient_21_3"

# On macOS (Intel x86) set the directory to your Instant Client directory
if sys.platform.startswith("darwin"):
    instant_client_dir = os.environ.get("HOME")+"/instantclient_19_8"

# This can be called at most once per process.
if instant_client_dir is not None:
    cx_Oracle.init_oracle_client(lib_dir=instant_client_dir)

utilisateur = os.environ.get("PYTHON_USER", "stag26")

connexion = os.environ.get("PYTHON_CONNECT_STRING", "51.91.76.248:15440/coursdb")

password = os.environ.get("PYTHON_PASSWORD", "Phoenix#Icar79")

print('utilisateur :',utilisateur)
print('connexion   :',connexion)
print('password    :',password)
# Out:
# utilisateur : stag26
# connexion   : 51.91.76.248:15440/coursdb
# password    : Phoenix#Icar79

# %% [markdown]
# # Connexion

# %%
connection = cx_Oracle.connect(utilisateur, password, connexion)

# %%
# %sql oracle+cx_oracle://stag26:Phoenix#Icar79@51.91.76.248:15440/coursdb
# Out:
# 'Connected: stag26@coursdb'

# %%
print(f"Version base de données : {connection.version}\n"+
      f"Utilisateur             : {connection.username}\n"+
      f"Page de code            : {connection.encoding}\n"+
      f"Chaine de connexion     : {connection.dsn}")
# Out:
# Version base de données : 18.0.0.0.0
# Utilisateur             : stag26
# Page de code            : UTF-8
# Chaine de connexion     : 51.91.76.248:15440/coursdb

# %% [markdown]
# # Projection
#
#
# >> SELECT [ ALL | DISTINCT ] <br>
# >>> { [{ NOM_TABLE | ALIAS2 }.]* ,<br><br>
# >>> [ [{NOM_TABLE |ALIAS2}.]COLONNE1 [AS] ALIAS1[,...]} <br><br>
# >> FROM NOM_TABLE ALIAS2 <br>

# %%
query = """
SELECT
    *   
FROM
    categories
"""
donnees = pd.read_sql_query(query, connection)
donnees
# Out:
#    CODE_CATEGORIE              NOM_CATEGORIE  \
# 0               1                   Boissons
# 1               2                 Condiments
# 2               3                   Desserts
# 3               4          Produits laitiers
# 4               5          Pâtes et céréales
# 5               6                    Viandes
# 6               7              Produits secs
# 7               8  Poissons et fruits de mer
# 8               9                  Conserves
# 9              10         Viande en conserve
#
#                                  DESCRIPTION
# 0              Boissons, cafés, thés, bières
# 1          Sauces, assaisonnements et épices
# 2                     Desserts et friandises
# 3                                   Fromages
# 4         Pains, biscuits, pâtes et céréales
# 5                          Viandes préparées
# 6               Fruits secs, raisins, autres
# 7         Poissons, fruits de mer, escargots
# 8  Fruits, légumes en conserve et confitures
# ...

# %%
# %sql SELECT CODE_CLIENT, DATE_COMMANDE, NO_EMPLOYE, PORT FROM COMMANDES FETCH NEXT 5 ROWS ONLY
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('CACTU', datetime.datetime(2010, 1, 21, 0, 0), 90, Decimal('96')),
#  ('LONEP', datetime.datetime(2010, 1, 21, 0, 0), 79, Decimal('55.8')),
#  ('EASTC', datetime.datetime(2010, 1, 21, 0, 0), 62, Decimal('64.8')),
#  ('GREAL', datetime.datetime(2010, 1, 21, 0, 0), 84, Decimal('57.6')),
#  ('WARTH', datetime.datetime(2010, 1, 21, 0, 0), 54, Decimal('63.9'))]

# %%
# %sql SELECT COMMANDES.CODE_CLIENT, COMMANDES.DATE_COMMANDE, COMMANDES.NO_EMPLOYE, PORT FROM COMMANDES FETCH NEXT 5 ROWS ONLY
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('CACTU', datetime.datetime(2010, 1, 21, 0, 0), 90, Decimal('96')),
#  ('LONEP', datetime.datetime(2010, 1, 21, 0, 0), 79, Decimal('55.8')),
#  ('EASTC', datetime.datetime(2010, 1, 21, 0, 0), 62, Decimal('64.8')),
#  ('GREAL', datetime.datetime(2010, 1, 21, 0, 0), 84, Decimal('57.6')),
#  ('WARTH', datetime.datetime(2010, 1, 21, 0, 0), 54, Decimal('63.9'))]

# %% [markdown]
# # Les constantes

# %%
# %sql SELECT 0, -1234567890, +1234567890, -123.456, +123.456, -1E+13  FROM DUAL
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [(0, -1234567890, 1234567890, Decimal('-123.456'), Decimal('123.456'), -10000000000000)]

# %%
# %sql SELECT -123, 456, +123, 456,-1E+13 FROM DUAL
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [(-123, 456, 123, 456, -10000000000000)]

# %%
# %sql SELECT 'Bonjour aujourd''hui c''est le :' "Aujourd'hui", SYSDATE "Date" FROM DUAL
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [("Bonjour aujourd'hui c'est le :", datetime.datetime(2021, 11, 25, 12, 23, 27))]

# %% [markdown]
# # Opérateur de concaténation

# %%
# %sql SELECT NO_EMPLOYE||' -- '||NOM||' -- '||PRENOM||' -- '||DATE_NAISSANCE  "Liste des employés"  FROM EMPLOYES
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('70 -- Berlioz -- Jacques -- 12/10/67',),
#  ('71 -- Nocella -- Guy -- 19/11/76',),
#  ('72 -- Herve -- Didier -- 19/09/79',),
#  ('73 -- Mangeard -- Jocelyne -- 27/12/79',),
#  ('74 -- Cazade -- Anne-Claire -- 19/09/79',),
#  ('75 -- Devie -- Thérèse -- 26/03/68',),
#  ('76 -- Peacock -- Margaret -- 20/03/69',),
#  ('77 -- Idesheim -- Annick -- 29/09/82',),
#  ('78 -- Rollet -- Philippe -- 09/03/85',),
#  ('79 -- Silberreiss -- Albert -- 18/08/78',),
#  ('80 -- Weiss -- Sylvie -- 08/01/78',),
#  ('81 -- Delorgue -- Jean -- 11/07/81',),
#  ('82 -- Zonca -- Virginie -- 12/03/80',),
#  ('83 -- Twardowski -- Colette -- 13/01/79',),
#  ('84 -- Coutou -- Myriam -- 31/08/85',),
#  ('85 -- King -- Robert -- 10/02/75',),
#  ('86 -- Ragon -- André -- 21/05/89',),
#  ('87 -- Dohr -- Sylvie -- 30/12/82',),
#  ('88 -- Maurousset -- James -- 26/09/78',),
#  ('89 -- Pouetre -- Camille-Hélène -- 16/03/87',),
# ...

# %%
# %sql SELECT concat(concat(concat(concat(NO_EMPLOYE,' -- '),NOM),' -- '),PRENOM)  "Liste des employés"  FROM EMPLOYES
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('70 -- Berlioz -- Jacques',),
#  ('71 -- Nocella -- Guy',),
#  ('72 -- Herve -- Didier',),
#  ('73 -- Mangeard -- Jocelyne',),
#  ('74 -- Cazade -- Anne-Claire',),
#  ('75 -- Devie -- Thérèse',),
#  ('76 -- Peacock -- Margaret',),
#  ('77 -- Idesheim -- Annick',),
#  ('78 -- Rollet -- Philippe',),
#  ('79 -- Silberreiss -- Albert',),
#  ('80 -- Weiss -- Sylvie',),
#  ('81 -- Delorgue -- Jean',),
#  ('82 -- Zonca -- Virginie',),
#  ('83 -- Twardowski -- Colette',),
#  ('84 -- Coutou -- Myriam',),
#  ('85 -- King -- Robert',),
#  ('86 -- Ragon -- André',),
#  ('87 -- Dohr -- Sylvie',),
#  ('88 -- Maurousset -- James',),
#  ('89 -- Pouetre -- Camille-Hélène',),
#  ('90 -- Montesinos -- Aline',),
#  ('91 -- Aubert -- Maria',),
#  ('92 -- Thomas -- Patricia',),
#  ('93 -- Falatik -- Bernard',),
#  ('94 -- Marielle -- Michel',),
#  ('95 -- Leger -- Pierre',),
#  ('96 -- Marchand -- Dominique',),
# ...

# %% [markdown]
# # Opérateurs arithmétiques
#
# Une expression arithmétique est une combinaison de noms de colonnes, de constantes et de fonctions arithmétiques (les fonctions arithmétiques sont traitées plus loin) combinées au moyen des opérateurs arithmétiques addition « + », soustraction « - », multiplication « * » ou division « / ».

# %%
# %sql \
SELECT NOM_PRODUIT "Produit", PRIX_UNITAIRE*UNITES_STOCK "Stock",\
       UNITES_COMMANDEES*12 "Commandes" \
FROM PRODUITS
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Chai', 3510, None),
#  ('Chang', 1615, 480),
#  ('Aniseed Syrup', 650, 840),
#  ("Chef Anton's Cajun Seasoning", 5830, None),
#  ("Grandma's Boysenberry Spread", 15000, None),
#  ("Uncle Bob's Organic Dried Pears", 2250, None),
#  ('Northwoods Cranberry Sauce', 1200, None),
#  ('Mishi Kobe Niku', None, None),
#  ('Ikura', 4805, None),
#  ('Queso Cabrales', 2310, 360),
#  ('Queso Manchego La Pastora', 16340, None),
#  ('Konbu', 720, None),
#  ('Alice Mutton', None, None),
#  ('Teatime Chocolate Biscuits', 1150, None),
#  ("Sir Rodney's Marmalade", 16200, None),
#  ("Sir Rodney's Scones", 150, 480),
#  ("Gustaf's Knäckebröd", 10920, None),
#  ('Tunnbröd', 2745, None),
#  ('NuNuCa Nuß-Nougat-Creme', 5320, None),
#  ('Rössle Sauerkraut', None, None),
#  ('Mascarpone Fabioli', 1440, 480),
#  ('Sasquatch Ale', 7770, None),
#  ('Steeleye Stout', 1800, None),
#  ('Inlagd Sill', 10640, None),
# ...

# %%
# %sql \
SELECT NOM||' '||PRENOM "Employé", SALAIRE * 1.1 "Nouveau Salaire"\
FROM EMPLOYES
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Berlioz Jacques', 10340),
#  ('Nocella Guy', 8360),
#  ('Herve Didier', 7370),
#  ('Mangeard Jocelyne', 9020),
#  ('Cazade Anne-Claire', 7920),
#  ('Devie Thérèse', 1694),
#  ('Peacock Margaret', 6710),
#  ('Idesheim Annick', 8030),
#  ('Rollet Philippe', 5500),
#  ('Silberreiss Albert', 10120),
#  ('Weiss Sylvie', 7260),
#  ('Delorgue Jean', 6490),
#  ('Zonca Virginie', 7370),
#  ('Twardowski Colette', 10340),
#  ('Coutou Myriam', 7590),
#  ('King Robert', 7920),
#  ('Ragon André', 14300),
#  ('Dohr Sylvie', 9020),
#  ('Maurousset James', 8910),
#  ('Pouetre Camille-Hélène', 2200),
#  ('Montesinos Aline', 9570),
#  ('Aubert Maria', 5610),
#  ('Thomas Patricia', 7810),
#  ('Falatik Bernard', 8360),
#  ('Marielle Michel', 7810),
#  ('Leger Pierre', 20900),
#  ('Marchand Dominique', 7590),
#  ('Seigne Marie-Pierre', 10560),
#  ('Burst Jean-Yves', 8470),
#  ('Damas Lydiane', 8470),
# ...

# %%
# %sql \
SELECT NOM,DATE_NAISSANCE,DATE_NAISSANCE+1,\
      (SYSDATE-DATE_NAISSANCE)/365 "jours" FROM EMPLOYES
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Berlioz', datetime.datetime(1967, 10, 12, 0, 0), datetime.datetime(1967, 10, 13, 0, 0), Decimal('54.16033089167935058346017250126839167945')),
#  ('Nocella', datetime.datetime(1976, 11, 19, 0, 0), datetime.datetime(1976, 11, 20, 0, 0), Decimal('45.04800212455606291222729578893962455616')),
#  ('Herve', datetime.datetime(1979, 9, 19, 0, 0), datetime.datetime(1979, 9, 20, 0, 0), Decimal('42.2151254122272957889396245560629122274')),
#  ('Mangeard', datetime.datetime(1979, 12, 27, 0, 0), datetime.datetime(1979, 12, 28, 0, 0), Decimal('41.94389253551496702181633688483003551507')),
#  ('Cazade', datetime.datetime(1979, 9, 19, 0, 0), datetime.datetime(1979, 9, 20, 0, 0), Decimal('42.2151254122272957889396245560629122274')),
#  ('Devie', datetime.datetime(1968, 3, 26, 0, 0), datetime.datetime(1968, 3, 27, 0, 0), Decimal('53.70553637113140537798072044647387113151')),
# ...

# %% [markdown]
# # La valeur NULL

# %%
# %sql \
SELECT NOM, SALAIRE, COMMISSION, SALAIRE+COMMISSION FROM EMPLOYES
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Berlioz', Decimal('9400'), Decimal('980'), 10380),
#  ('Nocella', Decimal('7600'), Decimal('910'), 8510),
#  ('Herve', Decimal('6700'), Decimal('1170'), 7870),
#  ('Mangeard', Decimal('8200'), Decimal('190'), 8390),
#  ('Cazade', Decimal('7200'), Decimal('550'), 7750),
#  ('Devie', Decimal('1540'), None, None),
#  ('Peacock', Decimal('6100'), Decimal('930'), 7030),
#  ('Idesheim', Decimal('7300'), Decimal('600'), 7900),
#  ('Rollet', Decimal('5000'), Decimal('570'), 5570),
#  ('Silberreiss', Decimal('9200'), Decimal('1100'), 10300),
#  ('Weiss', Decimal('6600'), Decimal('1110'), 7710),
#  ('Delorgue', Decimal('5900'), Decimal('510'), 6410),
#  ('Zonca', Decimal('6700'), Decimal('470'), 7170),
#  ('Twardowski', Decimal('9400'), Decimal('1540'), 10940),
#  ('Coutou', Decimal('6900'), Decimal('770'), 7670),
#  ('King', Decimal('7200'), Decimal('1040'), 8240),
# ...

# %% [markdown]
# ## COALESCE

# %%
# %sql \
SELECT NOM, SALAIRE, COMMISSION, SALAIRE+COALESCE(COMMISSION,0) FROM EMPLOYES
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Berlioz', Decimal('9400'), Decimal('980'), 10380),
#  ('Nocella', Decimal('7600'), Decimal('910'), 8510),
#  ('Herve', Decimal('6700'), Decimal('1170'), 7870),
#  ('Mangeard', Decimal('8200'), Decimal('190'), 8390),
#  ('Cazade', Decimal('7200'), Decimal('550'), 7750),
#  ('Devie', Decimal('1540'), None, 1540),
#  ('Peacock', Decimal('6100'), Decimal('930'), 7030),
#  ('Idesheim', Decimal('7300'), Decimal('600'), 7900),
#  ('Rollet', Decimal('5000'), Decimal('570'), 5570),
#  ('Silberreiss', Decimal('9200'), Decimal('1100'), 10300),
#  ('Weiss', Decimal('6600'), Decimal('1110'), 7710),
#  ('Delorgue', Decimal('5900'), Decimal('510'), 6410),
#  ('Zonca', Decimal('6700'), Decimal('470'), 7170),
#  ('Twardowski', Decimal('9400'), Decimal('1540'), 10940),
#  ('Coutou', Decimal('6900'), Decimal('770'), 7670),
#  ('King', Decimal('7200'), Decimal('1040'), 8240),
# ...

# %% [markdown]
# ## NVL

# %%
# %sql \
SELECT NOM, SALAIRE, COMMISSION, SALAIRE+nvl(COMMISSION,0) FROM EMPLOYES
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Berlioz', Decimal('9400'), Decimal('980'), 10380),
#  ('Nocella', Decimal('7600'), Decimal('910'), 8510),
#  ('Herve', Decimal('6700'), Decimal('1170'), 7870),
#  ('Mangeard', Decimal('8200'), Decimal('190'), 8390),
#  ('Cazade', Decimal('7200'), Decimal('550'), 7750),
#  ('Devie', Decimal('1540'), None, 1540),
#  ('Peacock', Decimal('6100'), Decimal('930'), 7030),
#  ('Idesheim', Decimal('7300'), Decimal('600'), 7900),
#  ('Rollet', Decimal('5000'), Decimal('570'), 5570),
#  ('Silberreiss', Decimal('9200'), Decimal('1100'), 10300),
#  ('Weiss', Decimal('6600'), Decimal('1110'), 7710),
#  ('Delorgue', Decimal('5900'), Decimal('510'), 6410),
#  ('Zonca', Decimal('6700'), Decimal('470'), 7170),
#  ('Twardowski', Decimal('9400'), Decimal('1540'), 10940),
#  ('Coutou', Decimal('6900'), Decimal('770'), 7670),
#  ('King', Decimal('7200'), Decimal('1040'), 8240),
# ...

# %%
# %sql \
SELECT SOCIETE, NVL(FAX, 'Non affecté') FROM CLIENTS
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Consolidated Holdings', '(71) 555-9199'),
#  ('Drachenblut Delikatessen', '0241-059428'),
#  ('Du monde entier', '02.40.67.89.89'),
#  ('Eastern Connection', '(71) 555-3373'),
#  ('Ernst Handel', '7675-3426'),
#  ('Familia Arquibaldo', 'Non affecté'),
#  ('FISSA Fabrica Inter. Salchichas S.A.', '(91) 555 55 93'),
#  ('Folies gourmandes', '03.20.16.10.17'),
#  ('Folk och fä HB', 'Non affecté'),
#  ('Frankenversand', '089-0877451'),
#  ('France restauration', '02.40.32.21.20'),
#  ('Franchi S.p.A.', '011-4988261'),
#  ('Furia Bacalhau e Frutos do Mar', '(1) 354-2535'),
#  ('Galería del gastrónomo', '(93) 203 4561'),
#  ('Godos Cocina Típica', 'Non affecté'),
#  ('Gourmet Lanchonetes', 'Non affecté'),
#  ('Great Lakes Food Market', 'Non affecté'),
#  ('GROSELLA-Restaurante', '(2) 283-3397'),
#  ('Hanari Carnes', '(21) 555-8765'),
#  ('HILARIÓN-Abastos', '(5) 555-1948'),
# ...

# %% [markdown]
# ## NVL2

# %%
# %sql \
SELECT NOM, SALAIRE, COMMISSION,\
       NVL2( COMMISSION, SALAIRE+COMMISSION, SALAIRE) R \
FROM EMPLOYES
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Berlioz', Decimal('9400'), Decimal('980'), 10380),
#  ('Nocella', Decimal('7600'), Decimal('910'), 8510),
#  ('Herve', Decimal('6700'), Decimal('1170'), 7870),
#  ('Mangeard', Decimal('8200'), Decimal('190'), 8390),
#  ('Cazade', Decimal('7200'), Decimal('550'), 7750),
#  ('Devie', Decimal('1540'), None, 1540),
#  ('Peacock', Decimal('6100'), Decimal('930'), 7030),
#  ('Idesheim', Decimal('7300'), Decimal('600'), 7900),
#  ('Rollet', Decimal('5000'), Decimal('570'), 5570),
#  ('Silberreiss', Decimal('9200'), Decimal('1100'), 10300),
#  ('Weiss', Decimal('6600'), Decimal('1110'), 7710),
#  ('Delorgue', Decimal('5900'), Decimal('510'), 6410),
#  ('Zonca', Decimal('6700'), Decimal('470'), 7170),
#  ('Twardowski', Decimal('9400'), Decimal('1540'), 10940),
#  ('Coutou', Decimal('6900'), Decimal('770'), 7670),
#  ('King', Decimal('7200'), Decimal('1040'), 8240),
# ...

# %% [markdown]
# # Tri du résultat d'une requête
#
# >> **SELECT [ALL | DISTINCT]{*,[EXPRESSION1 [AS] ALIAS1[,...]}<br>
# >> FROM NOM_TABLE<br>
# >> ORDER BY <br>
# >> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[NOM_COLONNE1|ALIAS1|POSITION1|EXPRESSION1][ASC|DESC] [NULLS {FIRST|LAST}],<br>
# >> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[NOM_COLONNE2|ALIAS2|POSITION2|EXPRESSION2][ASC|DESC] [NULLS {FIRST|LAST}]**<br>

# %%
# %sql \
SELECT NOM, PRENOM, FONCTION FROM EMPLOYES ORDER BY NOM
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Alvarez', 'Marcel', 'Représentant(e)'),
#  ('Arrambide', 'Jean Pierre', 'Représentant(e)'),
#  ('Aubert', 'Maria', 'Représentant(e)'),
#  ('Aubry', 'Jean-Claude', 'Représentant(e)'),
#  ('Barre', 'Jean-Paul', 'Représentant(e)'),
#  ('Bazart', 'Régis', 'Représentant(e)'),
#  ('Belin', 'Chantal', 'Chef des ventes'),
#  ('Berlioz', 'Jacques', 'Représentant(e)'),
#  ('Besse', 'José', 'Représentant(e)'),
#  ('Bettan', 'Henri-Michel', 'Représentant(e)'),
#  ('Blard', 'Jean-Benoît', 'Représentant(e)'),
#  ('Bodard', 'René', 'Représentant(e)'),
#  ('Brasseur', 'Hervé', 'Vice-Président'),
#  ('Brunet', 'Jean-Luc', 'Représentant(e)'),
#  ('Buchanan', 'Steven', 'Chef des ventes'),
#  ('Burst', 'Jean-Yves', 'Représentant(e)'),
#  ('Callahan', 'Laura', 'Assistante commerciale'),
#  ('Canu', 'Christian', 'Représentant(e)'),
#  ('Capharsie', 'Gérard', 'Représentant(e)'),
# ...

# %%
# %sql \
SELECT NOM||' '||PRENOM "Employé", FONCTION \
FROM EMPLOYES \
ORDER BY "Employé" ASC
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Alvarez Marcel', 'Représentant(e)'),
#  ('Arrambide Jean Pierre', 'Représentant(e)'),
#  ('Aubert Maria', 'Représentant(e)'),
#  ('Aubry Jean-Claude', 'Représentant(e)'),
#  ('Barre Jean-Paul', 'Représentant(e)'),
#  ('Bazart Régis', 'Représentant(e)'),
#  ('Belin Chantal', 'Chef des ventes'),
#  ('Berlioz Jacques', 'Représentant(e)'),
#  ('Besse José', 'Représentant(e)'),
#  ('Bettan Henri-Michel', 'Représentant(e)'),
#  ('Blard Jean-Benoît', 'Représentant(e)'),
#  ('Bodard René', 'Représentant(e)'),
#  ('Brasseur Hervé', 'Vice-Président'),
#  ('Brunet Jean-Luc', 'Représentant(e)'),
#  ('Buchanan Steven', 'Chef des ventes'),
#  ('Burst Jean-Yves', 'Représentant(e)'),
#  ('Callahan Laura', 'Assistante commerciale'),
#  ('Canu Christian', 'Représentant(e)'),
#  ('Capharsie Gérard', 'Représentant(e)'),
#  ('Cazade Anne-Claire', 'Représentant(e)'),
#  ('Chambaud Axelle', 'Chef des ventes'),
# ...

# %% [markdown]
# Le tri se fait d'abord selon le premier critère spécifié dans la clause « **ORDER BY** », puis les lignes ayant la même valeur pour le premier critère sont triées selon le deuxième critère de la clause « **ORDER BY** », etc.

# %%
# %sql \
SELECT NOM_PRODUIT, NO_FOURNISSEUR, CODE_CATEGORIE \
FROM PRODUITS\
ORDER BY NO_FOURNISSEUR, CODE_CATEGORIE DESC
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Aniseed Syrup', 1, 2),
#  ('Chai', 1, 1),
#  ('Chang', 1, 1),
#  ('Cherry Pie Filling', 2, 9),
#  ('Amandes', 2, 7),
#  ('Brownie Mix', 2, 3),
#  ("Chef Anton's Gumbo Mix", 2, 2),
#  ('Louisiana Hot Spiced Okra', 2, 2),
#  ("Chef Anton's Cajun Seasoning", 2, 2),
#  ('Louisiana Fiery Hot Pepper Sauce', 2, 2),
#  ("Uncle Bob's Organic Dried Pears", 3, 7),
#  ('Northwoods Cranberry Sauce', 3, 2),
#  ("Grandma's Boysenberry Spread", 3, 2),
#  ('Corn', 4, 9),
#  ('Ikura', 4, 8),
#  ('Longlife Tofu', 4, 7),
#  ('Long Grain Rice', 4, 7),
#  ('Mishi Kobe Niku', 4, 6),
#  ('Scones', 4, 3),
#  ('Mustard', 4, 2),
#  ('Green Beans', 5, 9),
#  ('Peas', 5, 9),
#  ('Walnuts', 5, 7),
#  ('Queso Cabrales', 5, 4),
#  ('Queso Manchego La Pastora', 5, 4),
#  ('Peaches', 6, 9),
#  ('Konbu', 6, 8),
#  ('Tofu', 6, 7),
#  ('Long Grain Rice - Gnocchi', 6, 5),
#  ('Les Comptoirs  - Olive Oil', 6, 2),
# ...

# %% [markdown]
# Si un attribut sur lequel porte un critère de tri contient la valeur « **NULL** », les lignes correspondantes sont affichées en dernier. Oracle traite les valeurs « **NULL** » comme si elles étaient des valeurs infinies.

# %%
# %sql \
SELECT NOM,PRENOM,SALAIRE,COMMISSION\
FROM EMPLOYES\
ORDER BY COMMISSION
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Petit', 'Michel', Decimal('6300'), Decimal('20')),
#  ('Gregoire', 'Renée', Decimal('8000'), Decimal('30')),
#  ('Michiels', 'François', Decimal('5500'), Decimal('40')),
#  ('Dupouey', 'Pierre', Decimal('5500'), Decimal('40')),
#  ('Jenny', 'Michel', Decimal('9800'), Decimal('150')),
#  ('Arrambide', 'Jean Pierre', Decimal('5400'), Decimal('190')),
#  ('Piroddi', 'Nathalie', Decimal('6700'), Decimal('190')),
#  ('Mangeard', 'Jocelyne', Decimal('8200'), Decimal('190')),
#  ('Dohr', 'Sylvie', Decimal('8200'), Decimal('200')),
#  ('Lamarre', 'Eric', Decimal('7800'), Decimal('200')),
#  ('Poidatz', 'Benoît', Decimal('6600'), Decimal('200')),
#  ('Leverling', 'Janet', Decimal('7400'), Decimal('240')),
#  ('Rivat', 'Jean-Louis', Decimal('5200'), Decimal('310')),
#  ('Teixeira', 'Claudia', Decimal('6800'), Decimal('330')),
#  ('Perny', 'Sylvie', Decimal('6500'), Decimal('340')),
# ...

# %%
# %sql \
SELECT NOM,PRENOM,SALAIRE,COMMISSION\
FROM EMPLOYES\
ORDER BY COMMISSION NULLS FIRST
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Ziliox', 'Francoise', Decimal('1900'), None),
#  ('Guerdon', 'Béatrice', Decimal('1700'), None),
#  ('Grangirard', 'Patricia', Decimal('1700'), None),
#  ('Devie', 'Thérèse', Decimal('1540'), None),
#  ('Maurer', 'Véronique', Decimal('1400'), None),
#  ('Poupard', 'Claudette', Decimal('1800'), None),
#  ('Fuller', 'Andrew', Decimal('96000'), None),
#  ('Etienne', 'Brigitte', Decimal('2000'), None),
#  ('Lampis', 'Gabrielle', Decimal('1300'), None),
#  ('Callahan', 'Laura', Decimal('1200'), None),
#  ('Brasseur', 'Hervé', Decimal('147000'), None),
#  ('Pouetre', 'Camille-Hélène', Decimal('2000'), None),
#  ('Giroux', 'Jean-Claude', Decimal('150000'), None),
#  ('Petit', 'Michel', Decimal('6300'), Decimal('20')),
#  ('Gregoire', 'Renée', Decimal('8000'), Decimal('30')),
#  ('Michiels', 'François', Decimal('5500'), Decimal('40')),
#  ('Dupouey', 'Pierre', Decimal('5500'), Decimal('40')),
# ...

# %% [markdown]
# # La limitation d’enregistrements

# %%
# %sql \
SELECT CODE_CATEGORIE,NOM_CATEGORIE \
FROM CATEGORIES  FETCH FIRST 3 ROWS ONLY
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [(1, 'Boissons'), (2, 'Condiments'), (3, 'Desserts')]

# %%
# %sql \
SELECT CODE_CATEGORIE,NOM_CATEGORIE \
FROM CATEGORIES  OFFSET 5 ROWS FETCH NEXT 3 ROWS ONLY
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [(6, 'Viandes'), (7, 'Produits secs'), (8, 'Poissons et fruits de mer')]

# %%
# %sql \
SELECT NOM_PRODUIT, UNITES_STOCK \
FROM PRODUITS \
ORDER BY UNITES_STOCK DESC NULLS LAST \
FETCH NEXT 5 ROWS ONLY
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Potato Chips', 200),
#  ('Rhönbräu Klosterbier', 125),
#  ('Green Tea', 125),
#  ('Boston Crab Meat', 123),
#  ("Grandma's Boysenberry Spread", 120)]

# %%
# %sql \
SELECT NOM_PRODUIT, UNITES_STOCK \
FROM PRODUITS \
ORDER BY UNITES_STOCK DESC NULLS LAST \
FETCH NEXT 5 ROWS WITH TIES
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Potato Chips', 200),
#  ('Rhönbräu Klosterbier', 125),
#  ('Green Tea', 125),
#  ('Boston Crab Meat', 123),
#  ("Grandma's Boysenberry Spread", 120),
#  ('Long Grain Rice - Gnocchi', 120),
#  ('Crab Meat', 120)]

# %%
# %sql \
SELECT NO_COMMANDE,REF_PRODUIT,QUANTITE,PRIX_UNITAIRE\
FROM DETAILS_COMMANDES FETCH NEXT 5 ROWS ONLY
# Out:
#  * oracle+cx_oracle://stag26:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [(214994, 87, 34, Decimal('62.16')),
#  (214994, 49, 89, Decimal('88.2')),
#  (214994, 3, 53, Decimal('37.56')),
#  (214994, 84, 104, Decimal('48.72')),
#  (214994, 57, 125, Decimal('65.04'))]

# %% [markdown]
# # Atelier 2.1	Interrogation des données

# %% [markdown]
# ## Projection
# Écrivez les requêtes vous permettant d’afficher :
# >> * Le nom, le prénom et la date de naissance de tous les employés de la société.<br>
# >> * Le nom de la société, la ville et le pays de tous les fournisseurs.<br>
# >> * La fonction de tous les employés.<br>
# >> * Toutes les fonctions des employés de l’entreprise, chaque fonction doit être affichée une seule fois.<br>
# >> * La liste des localités dans lesquelles la société a au moins un client.<br>
#
# ## Opérateurs
# Créez les requêtes vous permettant d’afficher :
# >> * Les produits commercialisés, la valeur du stock par produit et la valeur des produits commandés. Dans la table **PRODUITS**, vous trouvez les champs **UNITES_STOCK** et **UNITES_COMMANDEES** que vous multipliez par le **PRIX_UNITAIRE** pour retrouver les valeurs des deux stocks.<br>
# >> * Le nom, le prénom, l’âge et l’ancienneté des employés, dans la société.<br>
# >> * Le numéro de la commande, le temps écoulé entre la commande et la livraison de celle-ci ainsi que les frais de port.<br>
#
# ## Les ordres de tri
# >> * Les employés par ordre alphabétique.<br>
# >> * Les employés depuis le plus récemment embauché jusqu’au plus ancien.<br>
# >> * Les fournisseurs dans l’ordre alphabétique de leur pays et ville de résidence.<br>
# >> * Les employés par ordre alphabétique de leur fonction et du plus grand salaire au plus petit.<br>
# >> * Les employés dans l’ordre de leur commission.<br>
