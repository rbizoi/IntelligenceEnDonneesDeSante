# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Les-librairies-nécessaires" data-toc-modified-id="Les-librairies-nécessaires-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Les librairies nécessaires</a></span></li><li><span><a href="#La-connexion-à-la-base-de-données-PostgreSQL" data-toc-modified-id="La-connexion-à-la-base-de-données-PostgreSQL-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>La connexion à la base de données PostgreSQL</a></span></li><li><span><a href="#Table-patients" data-toc-modified-id="Table-patients-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Table patients</a></span></li><li><span><a href="#Table-patients_hospitalises" data-toc-modified-id="Table-patients_hospitalises-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Table patients_hospitalises</a></span></li><li><span><a href="#Table-soins_ambulatoires" data-toc-modified-id="Table-soins_ambulatoires-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Table soins_ambulatoires</a></span></li></ul></div>

# %% [markdown]
# # Les librairies nécessaires

# %% [raw]
# !conda install sqlalchemy
# !pip   install ipython-sql
# !pip   install sql
# !pip   install psycopg2

# %%
import pandas as pd 
import seaborn as sns
import warnings 
import os
import sqlalchemy

from datetime import datetime
warnings.filterwarnings(action="ignore")

# %pylab inline
# %load_ext sql

plt.style.use('seaborn-darkgrid')
sns.set(font_scale=3)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # La connexion à la base de données PostgreSQL
#
# **`postgresql://user:pass@host:port/dbname[?key=value&key=value...]`**<br>
# **`engine = create_engine("postgresql://scott:tiger@localhost/test")`**<br>

# %%
engine = sqlalchemy.create_engine("postgresql://healthcare:Phoenix#Icar67@51.91.76.248:15432/healthcare")
connection = engine.connect()
print("connecting with engine " + str(engine))
# Out:
# connecting with engine Engine(postgresql://healthcare:***@51.91.76.248:15432/healthcare)

# %% [markdown]
# <img src="https://raw.githubusercontent.com/rbizoi/IntelligenceEnDonneesDeSante/main/InterrogationSQL/images/schema_examen.png" width="800">

# %% [markdown]
# # Table patients

# %%
requete  = "select * from patients"
donnees = pd.read_sql_query(requete, connection)
donnees.head()
# Out:
#   patient_id date_naissance date_deces gender alzheimer heartfailure  \
# 0  BENE11207     1928-06-01       None  homme       oui          non
# 1  BENE11208     1923-09-01       None  homme       non          oui
# 2  BENE11209     1915-07-01       None  femme       non          oui
# 3  BENE11210     1929-06-01       None  homme       oui          oui
# 4  BENE11211     1930-07-01       None  femme       oui          oui
#
#   kidneydisease cancer obstrpulmonary depression diabetes ischemicheart  \
# 0           non    oui            oui        non      non           non
# 1           non    oui            oui        non      non           non
# 2           oui    oui            oui        non      non           non
# 3           oui    non            oui        oui      non           non
# 4           oui    oui            oui        oui      non           oui
#
#   osteoporasis rheumatoidarthritis stroke
# 0          oui                 non    oui
# ...

# %%
# %sql postgresql://healthcare:Phoenix#Icar67@51.91.76.248:15432/healthcare

# %%
# %sql select * from patients limit 10
# Out:
#  * postgresql://healthcare:***@51.91.76.248:15432/healthcare
# 10 rows affected.
# [('BENE11207', datetime.date(1928, 6, 1), None, 'homme', 'oui', 'non', 'non', 'oui', 'oui', 'non', 'non', 'non', 'oui', 'non', 'oui'),
#  ('BENE11208', datetime.date(1923, 9, 1), None, 'homme', 'non', 'oui', 'non', 'oui', 'oui', 'non', 'non', 'non', 'oui', 'oui', 'oui'),
#  ('BENE11209', datetime.date(1915, 7, 1), None, 'femme', 'non', 'oui', 'oui', 'oui', 'oui', 'non', 'non', 'non', 'oui', 'non', 'oui'),
#  ('BENE11210', datetime.date(1929, 6, 1), None, 'homme', 'oui', 'oui', 'oui', 'non', 'oui', 'oui', 'non', 'non', 'non', 'oui', 'oui'),
#  ('BENE11211', datetime.date(1930, 7, 1), None, 'femme', 'oui', 'oui', 'oui', 'oui', 'oui', 'oui', 'non', 'oui', 'oui', 'oui', 'oui'),
#  ('BENE11212', datetime.date(1924, 1, 1), None, 'femme', 'oui', 'non', 'non', 'oui', 'non', 'non', 'non', 'non', 'non', 'non', 'oui'),
# ...

# %% [markdown]
# # Table patients_hospitalises

# %%
requete  = "select * from patients_hospitalises"
donnees = pd.read_sql_query(requete, connection)
donnees.head()
# Out:
#   patient_id reclamation_id debut_reclamation fin_reclamation  provider  \
# 0  BENE11769       CLM65259        2009-08-25      2009-09-04  PRV56421
# 1  BENE11772       CLM73448        2009-10-26      2009-10-29  PRV54350
# 2  BENE11778       CLM31851        2009-01-01      2009-01-08  PRV54692
# 3  BENE11791       CLM68361        2009-09-17      2009-09-18  PRV54692
# 4  BENE11793       CLM56484        2009-06-21      2009-06-26  PRV55209
#
#    remboursement date_admission  franchise date_sortie
# 0        19000.0     2009-08-25     1068.0  2009-09-04
# 1         9000.0     2009-10-26     1068.0  2009-10-29
# 2        20000.0     2009-01-01     1068.0  2009-01-08
# 3         2000.0     2009-09-17     1068.0  2009-09-18
# 4        11000.0     2009-06-21     1068.0  2009-06-26

# %%
# %%sql
# select *
# from patients_hospitalises limit 15
# Out:
#  * postgresql://healthcare:***@51.91.76.248:15432/healthcare
# 15 rows affected.
# [('BENE11769', 'CLM65259', datetime.date(2009, 8, 25), datetime.date(2009, 9, 4), 'PRV56421', Decimal('19000'), datetime.date(2009, 8, 25), Decimal('1068.00'), datetime.date(2009, 9, 4)),
#  ('BENE11772', 'CLM73448', datetime.date(2009, 10, 26), datetime.date(2009, 10, 29), 'PRV54350', Decimal('9000'), datetime.date(2009, 10, 26), Decimal('1068.00'), datetime.date(2009, 10, 29)),
#  ('BENE11778', 'CLM31851', datetime.date(2009, 1, 1), datetime.date(2009, 1, 8), 'PRV54692', Decimal('20000'), datetime.date(2009, 1, 1), Decimal('1068.00'), datetime.date(2009, 1, 8)),
#  ('BENE11791', 'CLM68361', datetime.date(2009, 9, 17), datetime.date(2009, 9, 18), 'PRV54692', Decimal('2000'), datetime.date(2009, 9, 17), Decimal('1068.00'), datetime.date(2009, 9, 18)),
# ...

# %% [markdown]
# # Table soins_ambulatoires

# %%
requete  = "select * from soins_ambulatoires"
donnees = pd.read_sql_query(requete, connection)
donnees.head()
# Out:
#   patient_id reclamation_id debut_reclamation fin_reclamation  provider  \
# 0  BENE11085      CLM176946        2009-02-05      2009-02-05  PRV52395
# 1  BENE11085      CLM276534        2009-03-31      2009-03-31  PRV52399
# 2  BENE11085      CLM330105        2009-04-29      2009-04-29  PRV52399
# 3  BENE11085      CLM344959        2009-05-07      2009-05-25  PRV52450
# 4  BENE11085      CLM531181        2009-08-18      2009-08-18  PRV52395
#
#    remboursement  franchise
# 0           40.0        0.0
# 1           50.0        0.0
# 2           60.0        0.0
# 3           30.0        0.0
# 4          600.0        0.0

# %%
# %%sql
# select *
# from soins_ambulatoires limit 15
# Out:
#  * postgresql://healthcare:***@51.91.76.248:15432/healthcare
# 15 rows affected.
# [('BENE11085', 'CLM176946', datetime.date(2009, 2, 5), datetime.date(2009, 2, 5), 'PRV52395', Decimal('40'), Decimal('0')),
#  ('BENE11085', 'CLM276534', datetime.date(2009, 3, 31), datetime.date(2009, 3, 31), 'PRV52399', Decimal('50'), Decimal('0')),
#  ('BENE11085', 'CLM330105', datetime.date(2009, 4, 29), datetime.date(2009, 4, 29), 'PRV52399', Decimal('60'), Decimal('0')),
#  ('BENE11085', 'CLM344959', datetime.date(2009, 5, 7), datetime.date(2009, 5, 25), 'PRV52450', Decimal('30'), Decimal('0')),
#  ('BENE11085', 'CLM531181', datetime.date(2009, 8, 18), datetime.date(2009, 8, 18), 'PRV52395', Decimal('600'), Decimal('0')),
#  ('BENE11085', 'CLM574950', datetime.date(2009, 9, 12), datetime.date(2009, 9, 12), 'PRV52437', Decimal('90'), Decimal('0')),
#  ('BENE11085', 'CLM597266', datetime.date(2009, 9, 25), datetime.date(2009, 9, 25), 'PRV52399', Decimal('800'), Decimal('0')),
# ...
