# %% [markdown]
# # Les librairies nécessaires

# %%
import pandas as pd 
import seaborn as sns
import warnings 
import os
import sqlalchemy

from datetime import datetime
warnings.filterwarnings(action="ignore")

# %pylab inline
# %load_ext sql

plt.style.use('seaborn-darkgrid')
sns.set(font_scale=3)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # La connexion à la base de données PostgreSQL
#
# **`postgresql://user:pass@host:port/dbname[?key=value&key=value...]`**<br>
# **`engine = create_engine("postgresql://scott:tiger@localhost/test")`**<br>

# %%
# %sql postgresql://

# %% [markdown]
# # Les conversions implicites

# %%
# %%sql
# SELECT RPAD(NOM,15)||' '||DATE_NAISSANCE||' '||SALAIRE * '1,1' "Employe"
# FROM EMPLOYES
# FETCH FIRST 5 ROWS ONLY
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Berlioz         12/10/67 10340',),
#  ('Nocella         19/11/76 8360',),
#  ('Herve           19/09/79 7370',),
#  ('Mangeard        27/12/79 9020',),
#  ('Cazade          19/09/79 7920',)]

# %% [markdown]
# # Date vers chaîne
# ## TO_CHAR, TO_DATE

# %% [markdown]
# >>  <table style="text-align:left;">
# >>  <tr>
# >>      <th  style="text-align:left;background-color:#053061;color:white;">Format	                                                              </th>
# >>      <th  style="text-align:left;background-color:#053061;color:white;">Description                                                             </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">MM	                                                                  </th>
# >>      <th  style="text-align:left;">Numéro du mois dans l'année                                             </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">RM	                                                                  </th>
# >>      <th  style="text-align:left;">Numéro du mois dans l'année en chiffres romains                         </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">MON	                                                                  </th>
# >>      <th  style="text-align:left;">Le nom du mois abrégé sur trois lettres                                 </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">MONTH	                                                                  </th>
# >>      <th  style="text-align:left;">Le nom du mois écrit en entier                                          </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">DDD	                                                                  </th>
# >>      <th  style="text-align:left;">Numéro du jour dans l'année, de 1 à 366                                 </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">DD	                                                                  </th>
# >>      <th  style="text-align:left;">Numéro du jour dans le mois, de 1 à 31                                  </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">D	                                                                      </th>
# >>      <th  style="text-align:left;">Numéro du jour dans la semaine, de 1 à 7                                </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">DY	                                                                  </th>
# >>      <th  style="text-align:left;">Le nom de la journée abrégé sur trois lettres                           </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">DAY	                                                                  </th>
# >>      <th  style="text-align:left;">Le nom de la journée écrit en entier                                    </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">YYYY	                                                                  </th>
# >>      <th  style="text-align:left;">Année complète sur quatre chiffres                                      </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">YYY	                                                                  </th>
# >>      <th  style="text-align:left;">Les trois derniers chiffres de l'année                                  </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">RR	                                                                  </th>
# >>      <th  style="text-align:left;">Deux derniers chiffres de l'année de la date courante                   </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">CC	                                                                  </th>
# >>      <th  style="text-align:left;">Le siècle                                                               </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">YEAR	                                                                  </th>
# >>      <th  style="text-align:left;">Année écrite en lettres: TWO THOUSAND (option apparemment non francisée)</th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">Q	                                                                      </th>
# >>      <th  style="text-align:left;">Le numéro du trimestre                                                  </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">WW	                                                                  </th>
# >>      <th  style="text-align:left;">Numéro de la semaine dans l'année                                       </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">IW	                                                                  </th>
# >>      <th  style="text-align:left;">Semaine de l'année selon le standard ISO                                </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">W	                                                                      </th>
# >>      <th  style="text-align:left;">Numéro de la semaine dans le mois                                       </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">J	                                                                      </th>
# >>      <th  style="text-align:left;">Calendrier Julien -jours écoulés depuis le 31 décembre 4713 av. J.-C    </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">HH	                                                                  </th>
# >>      <th  style="text-align:left;">Heure du jour, toujours de format 1-12                                  </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">HH24	                                                                  </th>
# >>      <th  style="text-align:left;">Heure du jour, sur 24 heures                                            </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">MI	                                                                  </th>
# >>      <th  style="text-align:left;">Minutes écoulées dans l'heure                                           </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">SS	                                                                  </th>
# >>      <th  style="text-align:left;">Secondes écoulées dans une minute                                       </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">SSSSS	                                                                  </th>
# >>      <th  style="text-align:left;">Secondes écoulées depuis minuit, toujours 0-86399                       </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">AM, PM	                                                              </th>
# >>      <th  style="text-align:left;">Affiche AM ou PM selon qu'il s'agit du matin ou de l'après-midi         </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">FM	                                                                  </th>
# >>      <th  style="text-align:left;">Les valeurs sont renvoyées sans les caractères blanc avant ou après     </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">TZH	                                                                  </th>
# >>      <th  style="text-align:left;">Affiche l’heure du fuseau horaire                                       </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">TZM	                                                                  </th>
# >>      <th  style="text-align:left;">Affiche les minutes du fuseau horaire                                   </th>
# >> </tr>
# >>  <tr>
# >>      <th  style="text-align:left;">TZR	                                                                  </th>
# >>      <th  style="text-align:left;">Affiche le fuseau horaire complet                                       </th>
#                                                                                                               </th>
# >> </tr>
# >> </table>

# %%
# %%sql
# SELECT TO_CHAR( now(),'D DD DDD DAY Day')
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [('3 22 326 TUESDAY   Tuesday  ',)]

# %%
# %sql SELECT TO_CHAR( now(),'MM MON Mon MONTH Month')
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [('11 NOV Nov NOVEMBER  November ',)]

# %%
# %%sql
# SELECT TO_CHAR( now(),'DD/MM/YYYY Q WW iW W HH:MM:SS SSSS')
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [('22/11/2022 4 47 24 4 05:11:34 62254',)]

# %%
# %sql SELECT TO_CHAR(now(),'DD/MM/YYYY HH24:MM:SS SSSS')
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [('22/11/2022 17:11:28 62248',)]

# %%
# %%sql
# SELECT TO_CHAR(now()+INTERVAL '1' HOUR,'HH:MM:SS AM'),
#        TO_CHAR(now()+INTERVAL '1' HOUR,'HH24:MM:SS ')
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [('06:11:01 PM', '18:11:01 ')]

# %% [markdown]
# # Extraire des informations
# ## EXTRACT

# %%
# %%sql
# SELECT
#     NOM,
#     EXTRACT (YEAR FROM DATE_EMBAUCHE)  "Année",
#     EXTRACT (MONTH FROM DATE_EMBAUCHE) "Mois",
#     EXTRACT (DAY FROM DATE_EMBAUCHE)   "Jour"
# FROM EMPLOYES ORDER BY 2,3,4
# FETCH FIRST 5 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [('Malejac', 1987.0, 11.0, 29.0),
#  ('Alvarez', 1988.0, 8.0, 3.0),
#  ('Burst', 1988.0, 10.0, 23.0),
#  ('Peacock', 1989.0, 4.0, 16.0),
#  ('Maurer', 1989.0, 5.0, 27.0)]

# %% [markdown]
# # Chaîne vers autres types
# ## TO_NUMBER

# %%
# %%sql
# SELECT
#     TO_NUMBER('-1234567890','S9999999999') "Colonne 1",
#     TO_NUMBER('+1234567890','S9999999999') "Colonne 2",
#     TO_NUMBER('+123.456'   ,'S999.999'   ) "Colonne 3",
#     TO_NUMBER('-123.456'   ,'999.999'    ) "Colonne 4"
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(Decimal('-1234567890'), Decimal('1234567890'), Decimal('123.456'), Decimal('-123.456'))]

# %% [markdown]
# ## TO_DATE

# %%
# %%sql
# SELECT TO_DATE( '10/04/2021','DD/MM/YYYY'),
#        TO_DATE( '12/10/2021 20:12:00',
#                 'DD/MM/YYYY HH24:MI:SS') "TO_DATE"
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(datetime.date(2021, 4, 10), datetime.date(2021, 10, 12))]

# %% [markdown]
# # Les fonctions générales
# ## CASE

# %%
# %%sql
# SELECT
#     NOM||' '||PRENOM "Employé",
#     FONCTION,
#     CASE FONCTION
#         WHEN 'Président'  THEN
#              SALAIRE*1.05
#         WHEN 'Vice-Président'  THEN
#              SALAIRE*1.1
#         WHEN 'Chef des ventes' THEN
#              SALAIRE*1.2
#         WHEN 'Représentant(e)' THEN
#              SALAIRE*1.1 + COMMISSION
#         ELSE
#              SALAIRE
#     END "Salaire"
# FROM EMPLOYES
# ORDER BY SALAIRE DESC
# FETCH FIRST 15 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 15 rows affected.
# [('Giroux Jean-Claude', 'Président', Decimal('157500.0000')),
#  ('Brasseur Hervé', 'Vice-Président', Decimal('161700.000')),
#  ('Fuller Andrew', 'Vice-Président', Decimal('105600.000')),
#  ('Leger Pierre', 'Chef des ventes', Decimal('22800.000')),
#  ('Splingart Lydia', 'Chef des ventes', Decimal('19200.000')),
#  ('Buchanan Steven', 'Chef des ventes', Decimal('15600.000')),
#  ('Ragon André', 'Chef des ventes', Decimal('15600.000')),
#  ('Chambaud Axelle', 'Chef des ventes', Decimal('14400.000')),
#  ('Cheutin Corinne', 'Représentant(e)', Decimal('11570.000')),
#  ('Belin Chantal', 'Chef des ventes', Decimal('12000.000')),
#  ('Courty Jean-Louis', 'Représentant(e)', Decimal('12690.000')),
#  ('Besse José', 'Représentant(e)', Decimal('11830.000')),
#  ('Destenay Agnès', 'Représentant(e)', Decimal('11680.000')),
#  ('Jenny Michel', 'Représentant(e)', Decimal('10930.000')),
#  ('Seigne Marie-Pierre', 'Représentant(e)', Decimal('11720.000'))]

# %%
# %%sql
# SELECT
#     NOM,
#     FONCTION,
#     SALAIRE,
#     CASE
#         WHEN FONCTION = 'Assistante commerciale'
#         THEN '10%'
#         WHEN FONCTION = 'Représentant(e)' AND
#           SALAIRE between 6000 AND 6400
#         THEN '30%'
#         WHEN FONCTION = 'Représentant(e)' AND
#           SALAIRE < 6000
#         THEN '20%'
#         ELSE
#           'Pas d''augmentation'
#     END "Salaire"
# FROM EMPLOYES
# ORDER BY SALAIRE DESC
# OFFSET 80 ROWS FETCH NEXT 25 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 25 rows affected.
# [('Espeche', 'Représentant(e)', Decimal('6500.00'), "Pas d'augmentation"),
#  ('Lombard', 'Représentant(e)', Decimal('6400.00'), '30%'),
#  ('Petit', 'Représentant(e)', Decimal('6300.00'), '30%'),
#  ('Pequignot', 'Représentant(e)', Decimal('6200.00'), '30%'),
#  ('Peacock', 'Représentant(e)', Decimal('6100.00'), '30%'),
#  ('Kremser', 'Représentant(e)', Decimal('6000.00'), '30%'),
#  ('Charles', 'Représentant(e)', Decimal('6000.00'), '30%'),
#  ('Delorgue', 'Représentant(e)', Decimal('5900.00'), '20%'),
#  ('Blard', 'Représentant(e)', Decimal('5900.00'), '20%'),
#  ('Canu', 'Représentant(e)', Decimal('5800.00'), '20%'),
#  ('Letertre', 'Représentant(e)', Decimal('5600.00'), '20%'),
#  ('Dupouey', 'Représentant(e)', Decimal('5500.00'), '20%'),
#  ('Michiels', 'Représentant(e)', Decimal('5500.00'), '20%'),
#  ('Bodard', 'Représentant(e)', Decimal('5500.00'), '20%'),
#  ('Bettan', 'Représentant(e)', Decimal('5500.00'), '20%'),
#  ('Steiner', 'Représentant(e)', Decimal('5400.00'), '20%'),
#  ('Arrambide', 'Représentant(e)', Decimal('5400.00'), '20%'),
#  ('Rivat', 'Représentant(e)', Decimal('5200.00'), '20%'),
#  ('Guillossou', 'Représentant(e)', Decimal('5200.00'), '20%'),
#  ('Aubert', 'Représentant(e)', Decimal('5100.00'), '20%'),
#  ('Rollet', 'Représentant(e)', Decimal('5000.00'), '20%'),
#  ('Pouetre', 'Assistante commerciale', Decimal('2000.00'), '10%'),
#  ('Etienne', 'Assistante commerciale', Decimal('2000.00'), '10%'),
#  ('Ziliox', 'Assistante commerciale', Decimal('1900.00'), '10%'),
#  ('Poupard', 'Assistante commerciale', Decimal('1800.00'), '10%')]

# %% [markdown]
# ## NULLIF

# %%
# %%sql
# SELECT
#     COMMISSION,
#     NULLIF(COMMISSION, 1000) RETOUR1,
#     NOM||' '||PRENOM "Employé",
#     NULLIF(LENGTH(NOM),
#     LENGTH(PRENOM)) RETOUR2
# FROM EMPLOYES
# FETCH FIRST 10 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 10 rows affected.
# [(None, None, 'Giroux Jean-Claude', 6),
#  (None, None, 'Fuller Andrew', None),
#  (None, None, 'Brasseur Hervé', 8),
#  (Decimal('12940.00'), Decimal('12940.00'), 'Buchanan Steven', 8),
#  (Decimal('11150.00'), Decimal('11150.00'), 'Leger Pierre', 5),
#  (Decimal('10640.00'), Decimal('10640.00'), 'Belin Chantal', 5),
#  (Decimal('11600.00'), Decimal('11600.00'), 'Chambaud Axelle', 8),
#  (Decimal('5980.00'), Decimal('5980.00'), 'Ragon André', None),
#  (Decimal('16480.00'), Decimal('16480.00'), 'Splingart Lydia', 9),
#  (Decimal('940.00'), Decimal('940.00'), 'Besse José', 5)]

# %% [markdown]
# # COALESCE

# %%
# %%sql
# SELECT
#     NOM_PRODUIT,
#     UNITES_COMMANDEES,
#     UNITES_STOCK,
#     INDISPONIBLE,
#     CASE
#         WHEN UNITES_COMMANDEES IS NOT NULL
#         THEN 'Unités commandées = '
#         WHEN UNITES_STOCK IS NOT NULL
#         THEN 'Unités en stock = '
#         ELSE
#             'Produit indisponible = '
#     END ||
#     COALESCE(UNITES_COMMANDEES, UNITES_STOCK, INDISPONIBLE) "Stock des produits"
# FROM PRODUITS
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 120 rows affected.
# [('Tea', Decimal('20'), Decimal('50'), Decimal('0'), 'Unités commandées = 20'),
#  ('Pears', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Peaches', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Pineapple', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Cherry Pie Filling', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Green Beans', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Corn', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Peas', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Tuna Fish', Decimal('30'), Decimal('50'), Decimal('0'), 'Unités commandées = 30'),
#  ('Smoked Salmon', Decimal('30'), Decimal('50'), Decimal('0'), 'Unités commandées = 30'),
#  ('Hot Cereal', Decimal('50'), Decimal('60'), Decimal('0'), 'Unités commandées = 50'),
#  ('Vegetable Soup', Decimal('100'), Decimal('25'), Decimal('0'), 'Unités commandées = 100'),
#  ('Chicken Soup', Decimal('90'), Decimal('60'), Decimal('0'), 'Unités commandées = 90'),
#  ('Chai', None, Decimal('39'), Decimal('0'), 'Unités en stock = 39'),
#  ('Chang', Decimal('40'), Decimal('17'), Decimal('0'), 'Unités commandées = 40'),
#  ('Aniseed Syrup', Decimal('70'), Decimal('13'), Decimal('0'), 'Unités commandées = 70'),
#  ("Chef Anton's Cajun Seasoning", None, Decimal('53'), Decimal('0'), 'Unités en stock = 53'),
#  ("Grandma's Boysenberry Spread", None, Decimal('120'), Decimal('0'), 'Unités en stock = 120'),
#  ("Uncle Bob's Organic Dried Pears", None, Decimal('15'), Decimal('0'), 'Unités en stock = 15'),
#  ('Northwoods Cranberry Sauce', None, Decimal('6'), Decimal('0'), 'Unités en stock = 6'),
#  ('Mishi Kobe Niku', None, None, Decimal('0'), 'Produit indisponible = 0'),
#  ('Ikura', None, Decimal('31'), Decimal('0'), 'Unités en stock = 31'),
#  ('Queso Cabrales', Decimal('30'), Decimal('22'), Decimal('0'), 'Unités commandées = 30'),
#  ('Queso Manchego La Pastora', None, Decimal('86'), Decimal('0'), 'Unités en stock = 86'),
#  ('Konbu', None, Decimal('24'), Decimal('1'), 'Unités en stock = 24'),
#  ('Alice Mutton', None, None, Decimal('0'), 'Produit indisponible = 0'),
#  ('Teatime Chocolate Biscuits', None, Decimal('25'), Decimal('0'), 'Unités en stock = 25'),
#  ("Sir Rodney's Marmalade", None, Decimal('40'), Decimal('0'), 'Unités en stock = 40'),
#  ("Sir Rodney's Scones", Decimal('40'), Decimal('3'), Decimal('0'), 'Unités commandées = 40'),
#  ("Gustaf's Knäckebröd", None, Decimal('104'), Decimal('0'), 'Unités en stock = 104'),
#  ('Tunnbröd', None, Decimal('61'), Decimal('0'), 'Unités en stock = 61'),
#  ('NuNuCa Nuß-Nougat-Creme', None, Decimal('76'), Decimal('1'), 'Unités en stock = 76'),
#  ('Rössle Sauerkraut', None, None, Decimal('0'), 'Produit indisponible = 0'),
#  ('Mascarpone Fabioli', Decimal('40'), Decimal('9'), Decimal('0'), 'Unités commandées = 40'),
#  ('Sasquatch Ale', None, Decimal('111'), Decimal('0'), 'Unités en stock = 111'),
#  ('Steeleye Stout', None, Decimal('20'), Decimal('0'), 'Unités en stock = 20'),
#  ('Inlagd Sill', None, Decimal('112'), Decimal('0'), 'Unités en stock = 112'),
#  ('Gravad lax', Decimal('50'), Decimal('11'), Decimal('0'), 'Unités commandées = 50'),
#  ('Chartreuse verte', None, Decimal('69'), Decimal('0'), 'Unités en stock = 69'),
#  ('Boston Crab Meat', None, Decimal('123'), Decimal('0'), 'Unités en stock = 123'),
#  ('Singaporean Hokkien Fried Mee', None, None, Decimal('0'), 'Produit indisponible = 0'),
#  ('Ipoh Coffee', Decimal('10'), Decimal('17'), Decimal('0'), 'Unités commandées = 10'),
#  ('Spegesild', None, Decimal('95'), Decimal('0'), 'Unités en stock = 95'),
#  ('Maxilaku', Decimal('60'), Decimal('10'), Decimal('0'), 'Unités commandées = 60'),
#  ('Manjimup Dried Apples', None, Decimal('20'), Decimal('0'), 'Unités en stock = 20'),
#  ('Filo Mix', None, Decimal('38'), Decimal('0'), 'Unités en stock = 38'),
#  ('Perth Pasties', None, None, Decimal('0'), 'Produit indisponible = 0'),
#  ('Pâté chinois', None, Decimal('115'), Decimal('0'), 'Unités en stock = 115'),
#  ('Gnocchi di nonna Alice', Decimal('10'), Decimal('21'), Decimal('0'), 'Unités commandées = 10'),
#  ('Raclette Courdavault', None, Decimal('79'), Decimal('0'), 'Unités en stock = 79'),
#  ('Camembert Pierrot', None, Decimal('19'), Decimal('0'), 'Unités en stock = 19'),
#  ('Louisiana Hot Spiced Okra', Decimal('100'), Decimal('4'), Decimal('0'), 'Unités commandées = 100'),
#  ('Laughing Lumberjack Lager', None, Decimal('52'), Decimal('0'), 'Unités en stock = 52'),
#  ('Gudbrandsdalsost', None, Decimal('26'), Decimal('0'), 'Unités en stock = 26'),
#  ('Outback Lager', Decimal('10'), Decimal('15'), Decimal('0'), 'Unités commandées = 10'),
#  ('Mozzarella di Giovanni', None, Decimal('14'), Decimal('0'), 'Unités en stock = 14'),
#  ('Röd Kaviar', None, Decimal('101'), Decimal('0'), 'Unités en stock = 101'),
#  ('Longlife Tofu', Decimal('20'), Decimal('4'), Decimal('0'), 'Unités commandées = 20'),
#  ('Lakkalikööri', None, Decimal('57'), Decimal('0'), 'Unités en stock = 57'),
#  ('Original Frankfurter grüne Soße', None, Decimal('32'), Decimal('0'), 'Unités en stock = 32'),
#  ("Chef Anton's Gumbo Mix", None, Decimal('0'), Decimal('0'), 'Unités en stock = 0'),
#  ('Tofu', None, Decimal('35'), Decimal('0'), 'Unités en stock = 35'),
#  ('Genen Shouyu', None, Decimal('39'), Decimal('0'), 'Unités en stock = 39'),
#  ('Pavlova', None, Decimal('29'), Decimal('0'), 'Unités en stock = 29'),
#  ('Carnarvon Tigers', None, Decimal('42'), Decimal('0'), 'Unités en stock = 42'),
#  ('Guaraná Fantástica', None, None, Decimal('0'), 'Produit indisponible = 0'),
#  ('Gumbär Gummibärchen', None, Decimal('15'), Decimal('0'), 'Unités en stock = 15'),
#  ('Schoggi Schokolade', None, Decimal('49'), Decimal('0'), 'Unités en stock = 49'),
#  ('Thüringer Rostbratwurst', None, None, Decimal('0'), 'Produit indisponible = 0'),
#  ('Nord-Ost Matjeshering', None, Decimal('10'), Decimal('0'), 'Unités en stock = 10'),
#  ('Gorgonzola Telino', Decimal('70'), Decimal('0'), Decimal('0'), 'Unités commandées = 70'),
#  ('Geitost', None, Decimal('112'), Decimal('0'), 'Unités en stock = 112'),
#  ('Côte de Blaye', None, Decimal('17'), Decimal('0'), 'Unités en stock = 17'),
#  ("Jack's New England Clam Chowder", None, Decimal('85'), Decimal('0'), 'Unités en stock = 85'),
#  ('Gula Malacca', None, Decimal('27'), Decimal('1'), 'Unités en stock = 27'),
#  ('Røgede sild', Decimal('70'), Decimal('5'), Decimal('0'), 'Unités commandées = 70'),
#  ('Zaanse koeken', None, Decimal('36'), Decimal('0'), 'Unités en stock = 36'),
#  ('Chocolade', Decimal('70'), Decimal('15'), Decimal('0'), 'Unités commandées = 70'),
#  ('Valkoinen suklaa', None, Decimal('65'), Decimal('0'), 'Unités en stock = 65'),
#  ('Tourtière', None, Decimal('21'), Decimal('0'), 'Unités en stock = 21'),
#  ('Ravioli Angelo', None, Decimal('36'), Decimal('0'), 'Unités en stock = 36'),
#  ('Escargots de Bourgogne', None, Decimal('62'), Decimal('0'), 'Unités en stock = 62'),
#  ("Sirop d'érable", None, Decimal('113'), Decimal('0'), 'Unités en stock = 113'),
#  ('Tarte au sucre', None, Decimal('17'), Decimal('0'), 'Unités en stock = 17'),
#  ('Vegie-spread', None, Decimal('24'), Decimal('0'), 'Unités en stock = 24'),
#  ('Wimmers gute Semmelknödel', Decimal('80'), Decimal('22'), Decimal('0'), 'Unités commandées = 80'),
#  ('Louisiana Fiery Hot Pepper Sauce', None, Decimal('76'), Decimal('0'), 'Unités en stock = 76'),
#  ('Scottish Longbreads', Decimal('10'), Decimal('6'), Decimal('0'), 'Unités commandées = 10'),
#  ('Fløtemysost', None, Decimal('26'), Decimal('0'), 'Unités en stock = 26'),
#  ('Rhönbräu Klosterbier', None, Decimal('125'), Decimal('0'), 'Unités en stock = 125'),
#  ('Syrup', Decimal('25'), Decimal('100'), Decimal('0'), 'Unités commandées = 25'),
#  ('Cajun Seasoning', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Les Comptoirs  - Olive Oil', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Boysenberry Spread', Decimal('25'), Decimal('100'), Decimal('0'), 'Unités commandées = 25'),
#  ('Dried Pears', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Curry Sauce', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Walnuts', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Fruit Cocktail', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Chocolate Biscuits Mix', Decimal('5'), Decimal('20'), Decimal('0'), 'Unités commandées = 5'),
#  ('Marmalade', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Scones', Decimal('5'), Decimal('20'), Decimal('0'), 'Unités commandées = 5'),
#  ('Beer', Decimal('15'), Decimal('60'), Decimal('0'), 'Unités commandées = 15'),
#  ('Crab Meat', Decimal('30'), Decimal('120'), Decimal('0'), 'Unités commandées = 30'),
#  ('Clam Chowder', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Coffee', Decimal('25'), Decimal('100'), Decimal('0'), 'Unités commandées = 25'),
#  ('Dried Apples', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Long Grain Rice', Decimal('25'), Decimal('100'), Decimal('0'), 'Unités commandées = 25'),
#  ('Long Grain Rice - Gnocchi', Decimal('30'), Decimal('120'), Decimal('0'), 'Unités commandées = 30'),
#  ('Ravioli', Decimal('20'), Decimal('80'), Decimal('0'), 'Unités commandées = 20'),
#  ('Hot Pepper Sauce', Decimal('10'), Decimal('40'), Decimal('0'), 'Unités commandées = 10'),
#  ('Tomato Sauce', Decimal('20'), Decimal('80'), Decimal('0'), 'Unités commandées = 20'),
#  ('Mozzarella', Decimal('10'), Decimal('40'), Decimal('1'), 'Unités commandées = 10'),
#  ('Amandes', Decimal('5'), Decimal('20'), Decimal('0'), 'Unités commandées = 5'),
#  ('Mustard', Decimal('15'), Decimal('60'), Decimal('0'), 'Unités commandées = 15'),
#  ('Dried Plums', Decimal('50'), Decimal('75'), Decimal('0'), 'Unités commandées = 50'),
#  ('Green Tea', Decimal('100'), Decimal('125'), Decimal('0'), 'Unités commandées = 100'),
#  ('Granola', Decimal('20'), Decimal('100'), Decimal('0'), 'Unités commandées = 20'),
#  ('Potato Chips', Decimal('30'), Decimal('200'), Decimal('0'), 'Unités commandées = 30'),
#  ('Brownie Mix', Decimal('10'), Decimal('20'), Decimal('0'), 'Unités commandées = 10'),
#  ('Cake Mix', Decimal('10'), Decimal('20'), Decimal('0'), 'Unités commandées = 10')]
