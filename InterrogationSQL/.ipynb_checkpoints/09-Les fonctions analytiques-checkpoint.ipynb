# %% [markdown]
# # Configuration de la connexion à la base de données

# %%
import pandas as pd 
import cx_Oracle
import sys
import os

# %pylab inline
# %load_ext sql
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sys.path.append(os.path.abspath('../../.'))
from dbconnect import utilisateur,connexion,password

# %% [markdown]
# # Connexion

# %%
# %sql oracle+cx_oracle://$utilisateur:$password@$connexion
# Out:
# 'Connected: stag01@coursdb'

# %% [markdown]
# # La clause de partitionnement
#
# <img src="https://raw.githubusercontent.com/rbizoi/IntelligenceEnDonneesDeSante/main/InterrogationSQL/images/M06-10.png" width="400">

# %%
# %%sql
# SELECT NO_EMPLOYE, FONCTION, SALAIRE,
# SUM( SALAIRE) OVER ( PARTITION BY FONCTION) "Somme Salaire"
# FROM EMPLOYES
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [(44, 'Assistante commerciale', Decimal('2000'), 16540),
#  (57, 'Assistante commerciale', Decimal('1700'), 16540),
#  (104, 'Assistante commerciale', Decimal('1900'), 16540),
#  (30, 'Assistante commerciale', Decimal('1200'), 16540),
#  (75, 'Assistante commerciale', Decimal('1540'), 16540),
#  (109, 'Assistante commerciale', Decimal('1300'), 16540),
#  (64, 'Assistante commerciale', Decimal('1700'), 16540),
#  (21, 'Assistante commerciale', Decimal('1800'), 16540),
#  (89, 'Assistante commerciale', Decimal('2000'), 16540),
#  (27, 'Assistante commerciale', Decimal('1400'), 16540),
#  (33, 'Chef des ventes', Decimal('12000'), 83000),
#  (24, 'Chef des ventes', Decimal('13000'), 83000),
#  (23, 'Chef des ventes', Decimal('16000'), 83000),
#  (11, 'Chef des ventes', Decimal('10000'), 83000),
#  (95, 'Chef des ventes', Decimal('19000'), 83000),
#  (86, 'Chef des ventes', Decimal('13000'), 83000),
# ...

# %%
# %%sql
# SELECT
#     NOM_PRODUIT "Produit",
#     CODE_CATEGORIE "Cat",
#     NO_FOURNISSEUR "Four",
#     UNITES_STOCK "US",
#     SUM(UNITES_STOCK) OVER (PARTITION BY CODE_CATEGORIE) "SUSC",
#     AVG(UNITES_STOCK) OVER (PARTITION BY NO_FOURNISSEUR) "AUSF"
# FROM PRODUITS
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Chang', 1, 1, 17, 874, 23),
#  ('Aniseed Syrup', 2, 1, 13, 1032, 23),
#  ('Chai', 1, 1, 39, 874, 23),
#  ('Amandes', 7, 2, 20, 589, Decimal('30.42857142857142857142857142857142857143')),
#  ('Cherry Pie Filling', 9, 2, 40, 460, Decimal('30.42857142857142857142857142857142857143')),
#  ("Chef Anton's Cajun Seasoning", 2, 2, 53, 1032, Decimal('30.42857142857142857142857142857142857143')),
#  ("Chef Anton's Gumbo Mix", 2, 2, 0, 1032, Decimal('30.42857142857142857142857142857142857143')),
#  ('Brownie Mix', 3, 2, 20, 466, Decimal('30.42857142857142857142857142857142857143')),
#  ('Louisiana Fiery Hot Pepper Sauce', 2, 2, 76, 1032, Decimal('30.42857142857142857142857142857142857143')),
#  ('Louisiana Hot Spiced Okra', 2, 2, 4, 1032, Decimal('30.42857142857142857142857142857142857143')),
#  ("Grandma's Boysenberry Spread", 2, 3, 120, 1032, 47),
#  ('Northwoods Cranberry Sauce', 2, 3, 6, 1032, 47),
# ...

# %%
# %%sql
# SELECT
#     NOM,
#     FONCTION, SALAIRE,
#     SALAIRE * 100/ SUM( SALAIRE) OVER ( PARTITION BY FONCTION) "% Fonction",
#     SALAIRE * 100/ SUM( SALAIRE) OVER () "% Total"
# FROM EMPLOYES
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Etienne', 'Assistante commerciale', Decimal('2000'), Decimal('12.09189842805320435308343409915356711004'), Decimal('0.1687137265487920097179106492104197597517')),
#  ('Grangirard', 'Assistante commerciale', Decimal('1700'), Decimal('10.27811366384522370012091898428053204353'), Decimal('0.1434066675664732082602240518288567957889')),
#  ('Ziliox', 'Assistante commerciale', Decimal('1900'), Decimal('11.48730350665054413542926239419588875453'), Decimal('0.1602780402213524092320151167498987717641')),
#  ('Callahan', 'Assistante commerciale', Decimal('1200'), Decimal('7.25513905683192261185006045949214026602'), Decimal('0.101228235929275205830746389526251855851')),
#  ('Devie', 'Assistante commerciale', Decimal('1540'), Decimal('9.31076178960096735187424425634824667473'), Decimal('0.1299095694425698474827911998920232150088')),
# ...

# %%
# %%sql
# SELECT
#     PAYS,
#     ANNEE,
#     TRIMESTRE T,
#     SUM(PRIX_UNITAIRE*QUANTITE) CA,
#     SUM(SUM(PRIX_UNITAIRE*QUANTITE)) OVER( PARTITION BY PAYS) "S Pays",
#     SUM(SUM(PRIX_UNITAIRE*QUANTITE)) OVER( PARTITION BY ANNEE) "S Année"
# FROM CLIENTS CL
#      JOIN COMMANDES CO
#         ON ( CL.CODE_CLIENT = CO.CODE_CLIENT)
#      JOIN DETAILS_COMMANDES DC
#         ON ( CO.NO_COMMANDE = DC.NO_COMMANDE)
# GROUP BY PAYS, ANNEE, TRIMESTRE
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Allemagne', 2010, 3, Decimal('58831184.88'), Decimal('420063829.44'), Decimal('2019971906.04')),
#  ('Allemagne', 2010, 1, Decimal('68206105.92'), Decimal('420063829.44'), Decimal('2019971906.04')),
#  ('Allemagne', 2011, 2, Decimal('84152788.08'), Decimal('420063829.44'), Decimal('1403112413.76')),
#  ('Allemagne', 2011, 1, 87169620, Decimal('420063829.44'), Decimal('1403112413.76')),
#  ('Allemagne', 2010, 4, Decimal('55341073.56'), Decimal('420063829.44'), Decimal('2019971906.04')),
#  ('Allemagne', 2010, 2, 66363057, Decimal('420063829.44'), Decimal('2019971906.04')),
#  ('Argentine', 2010, 4, Decimal('16707964.8'), Decimal('112213361.64'), Decimal('2019971906.04')),
#  ('Argentine', 2010, 1, Decimal('17302195.92'), Decimal('112213361.64'), Decimal('2019971906.04')),
#  ('Argentine', 2010, 3, Decimal('14884703.52'), Decimal('112213361.64'), Decimal('2019971906.04')),
# ...

# %% [markdown]
# # La clause d’ordre
#
# <img src="https://raw.githubusercontent.com/rbizoi/IntelligenceEnDonneesDeSante/main/InterrogationSQL/images/M06-11.png" width="400">

# %%
# %%sql
# SELECT
#     CL.SOCIETE,
#     CO.DATE_COMMANDE,
#     CO.PORT P,
#     SUM(CO.PORT) OVER ( PARTITION BY CO.CODE_CLIENT ORDER BY CO.DATE_COMMANDE) SCC,
#     SUM(CO.PORT) OVER ( ORDER BY CO.CODE_CLIENT, CO.DATE_COMMANDE)  SCT
# FROM CLIENTS CL
#      JOIN COMMANDES CO
#         ON ( CL.CODE_CLIENT = CO.CODE_CLIENT)
# WHERE ANNEE = 2011 AND MOIS = 5 AND PAYS = 'France'
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Blondel père et fils', datetime.datetime(2011, 5, 12, 0, 0), Decimal('56'), 56, 56),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 13, 0, 0), Decimal('71.5'), Decimal('127.5'), Decimal('127.5')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 15, 0, 0), Decimal('90'), Decimal('217.5'), Decimal('217.5')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 16, 0, 0), Decimal('51.9'), Decimal('269.4'), Decimal('269.4')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 17, 0, 0), Decimal('83.5'), Decimal('352.9'), Decimal('352.9')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 19, 0, 0), Decimal('78.3'), Decimal('431.2'), Decimal('431.2')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 20, 0, 0), Decimal('76.3'), Decimal('507.5'), Decimal('507.5')),
# ...

# %% [markdown]
# # La clause de fenêtrage
#
# <img src="https://raw.githubusercontent.com/rbizoi/IntelligenceEnDonneesDeSante/main/InterrogationSQL/images/M06-12.png" width="400">

# %%
# %%sql
# SELECT
#     CL.SOCIETE,
#     CO.DATE_COMMANDE,
#     CO.PORT P,
#     SUM(CO.PORT) OVER ( PARTITION BY CO.CODE_CLIENT
#                         ORDER BY CO.DATE_COMMANDE
#                         ROWS BETWEEN 1 PRECEDING AND 1 PRECEDING )  C01,
#     SUM(CO.PORT) OVER ( PARTITION BY CO.CODE_CLIENT
#                         ORDER BY CO.DATE_COMMANDE
#                         ROWS BETWEEN 1 FOLLOWING AND 1 FOLLOWING )  C02
# FROM CLIENTS CL
#      JOIN COMMANDES CO
#         ON ( CL.CODE_CLIENT = CO.CODE_CLIENT)
# WHERE ANNEE = 2011 AND MOIS = 5 AND PAYS = 'France'
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Blondel père et fils', datetime.datetime(2011, 5, 12, 0, 0), Decimal('56'), None, Decimal('71.5')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 13, 0, 0), Decimal('71.5'), 56, 90),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 15, 0, 0), Decimal('90'), Decimal('71.5'), Decimal('51.9')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 16, 0, 0), Decimal('51.9'), 90, Decimal('83.5')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 17, 0, 0), Decimal('83.5'), Decimal('51.9'), Decimal('78.3')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 19, 0, 0), Decimal('78.3'), Decimal('83.5'), Decimal('76.3')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 20, 0, 0), Decimal('76.3'), Decimal('78.3'), Decimal('85.3')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 21, 0, 0), Decimal('85.3'), Decimal('76.3'), Decimal('83.7')),
# ...

# %%
# %%sql
# SELECT
#     CL.SOCIETE,
#     CO.DATE_COMMANDE,
#     CO.PORT P,
#     SUM(CO.PORT) OVER ( ORDER BY CO.CODE_CLIENT, CO.DATE_COMMANDE)  SCT,
#     SUM(CO.PORT) OVER ( ORDER BY CO.CODE_CLIENT, CO.DATE_COMMANDE
#                         ROWS UNBOUNDED PRECEDING                         )  C01,
#     SUM(CO.PORT) OVER ( ORDER BY CO.CODE_CLIENT, CO.DATE_COMMANDE
#                         ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW )  C02
# FROM CLIENTS CL
#      JOIN COMMANDES CO
#         ON ( CL.CODE_CLIENT = CO.CODE_CLIENT)
# WHERE ANNEE = 2011 AND MOIS = 5 AND PAYS = 'France'
# FETCH NEXT 18 ROWS WITH TIES
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Blondel père et fils', datetime.datetime(2011, 5, 12, 0, 0), Decimal('56'), 56, 56, 56),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 13, 0, 0), Decimal('71.5'), Decimal('127.5'), Decimal('127.5'), Decimal('127.5')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 15, 0, 0), Decimal('90'), Decimal('217.5'), Decimal('217.5'), Decimal('217.5')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 16, 0, 0), Decimal('51.9'), Decimal('269.4'), Decimal('269.4'), Decimal('269.4')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 17, 0, 0), Decimal('83.5'), Decimal('352.9'), Decimal('352.9'), Decimal('352.9')),
#  ('Blondel père et fils', datetime.datetime(2011, 5, 19, 0, 0), Decimal('78.3'), Decimal('431.2'), Decimal('431.2'), Decimal('431.2')),
# ...

# %%
# %%sql
# SELECT
# DATE_COMMANDE,
# SUM(PORT) SP,
# AVG(SUM(PORT)) OVER ( ORDER BY DATE_COMMANDE
#                       ROWS BETWEEN 1 PRECEDING AND 1 FOLLOWING ) AP
# FROM CLIENTS CL
#      JOIN COMMANDES CO
#         ON ( CL.CODE_CLIENT = CO.CODE_CLIENT)
# WHERE ANNEE = 2011 AND MOIS = 5
# GROUP BY DATE_COMMANDE
# FETCH NEXT 18 ROWS WITH TIES
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [(datetime.datetime(2011, 5, 1, 0, 0), Decimal('1665.1'), Decimal('1751.7')),
#  (datetime.datetime(2011, 5, 2, 0, 0), Decimal('1838.3'), Decimal('1674.3')),
#  (datetime.datetime(2011, 5, 3, 0, 0), Decimal('1519.5'), Decimal('1620.066666666666666666666666666666666667')),
#  (datetime.datetime(2011, 5, 4, 0, 0), Decimal('1502.4'), Decimal('1630.766666666666666666666666666666666667')),
#  (datetime.datetime(2011, 5, 5, 0, 0), Decimal('1870.4'), Decimal('1681.033333333333333333333333333333333333')),
#  (datetime.datetime(2011, 5, 6, 0, 0), Decimal('1670.3'), Decimal('1751.733333333333333333333333333333333333')),
#  (datetime.datetime(2011, 5, 7, 0, 0), Decimal('1714.5'), Decimal('2085.433333333333333333333333333333333333')),
#  (datetime.datetime(2011, 5, 8, 0, 0), Decimal('2871.5'), Decimal('2543.866666666666666666666666666666666667')),
# ...

# %% [markdown]
# # Fonctions de classement

# %% [markdown]
# ## ROW_NUMBER

# %%
# %%sql
# SELECT
#     CODE_CATEGORIE CAT,
#     NO_FOURNISSEUR NF,
#     UNITES_STOCK US,
#     ROW_NUMBER() OVER ( PARTITION BY CODE_CATEGORIE
#                        ORDER BY UNITES_STOCK)       RN1,
#     ROW_NUMBER() OVER ( PARTITION BY CODE_CATEGORIE
#                  ORDER BY UNITES_STOCK NULLS FIRST) RN2,
#     ROW_NUMBER()OVER (
#        ORDER BY CODE_CATEGORIE, UNITES_STOCK)       RN3,
#     ROW_NUMBER() OVER ( ORDER BY CODE_CATEGORIE,
#                  NO_FOURNISSEUR,UNITES_STOCK)       RN4,
#     ROW_NUMBER() OVER ( ORDER BY NO_FOURNISSEUR,
#                            UNITES_STOCK  )          RN5
# FROM PRODUITS WHERE CODE_CATEGORIE < 3
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [(1, 7, 15, 1, 2, 1, 3, 13),
#  (1, 1, 17, 2, 3, 2, 1, 2),
#  (1, 20, 17, 3, 5, 3, 15, 33),
#  (1, 18, 17, 4, 4, 4, 12, 30),
#  (1, 16, 20, 5, 6, 5, 8, 23),
#  (1, 1, 39, 6, 7, 6, 2, 3),
#  (1, 14, 50, 7, 8, 7, 6, 21),
#  (1, 16, 52, 8, 9, 8, 9, 24),
#  (1, 23, 57, 9, 10, 9, 16, 35),
#  (1, 18, 60, 10, 11, 10, 13, 31),
#  (1, 18, 69, 11, 12, 11, 14, 32),
#  (1, 16, 100, 12, 13, 12, 10, 27),
#  (1, 16, 111, 13, 14, 13, 11, 28),
#  (1, 12, 125, 14, 16, 14, 5, 17),
#  (1, 14, 125, 15, 15, 15, 7, 22),
#  (1, 10, None, 16, 1, 16, 4, 15),
#  (2, 2, 0, 1, 1, 17, 18, 4),
#  (2, 2, 4, 2, 2, 18, 19, 5),
#  (2, 3, 6, 3, 3, 19, 22, 8),
#  (2, 1, 13, 4, 4, 20, 17, 1),
#  (2, 7, 24, 5, 5, 21, 27, 14),
#  (2, 13, 25, 6, 6, 22, 29, 18),
#  (2, 20, 27, 7, 7, 23, 35, 34),
#  (2, 12, 32, 8, 8, 24, 28, 16),
#  (2, 6, 39, 9, 9, 25, 25, 11),
#  (2, 6, 40, 10, 11, 26, 26, 12),
#  (2, 27, 40, 11, 14, 27, 37, 37),
# ...

# %% [markdown]
# ## RANK

# %%
# %%sql
# SELECT
#     ROW_NUMBER() OVER ( ORDER BY SALAIRE DESC) RN,
#     NOM,
#     SALAIRE,
#     RSD,
#     RSC
# FROM (SELECT
#           NOM,
#           SALAIRE,
#           RANK ()OVER ( ORDER BY SALAIRE DESC) RSD,
#           RANK ()OVER ( ORDER BY SALAIRE ASC ) RSC
#       FROM EMPLOYES)
# WHERE RSD <= 3 or RSC <= 3
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [(1, 'Giroux', Decimal('150000'), 1, 111),
#  (2, 'Brasseur', Decimal('147000'), 2, 110),
#  (3, 'Fuller', Decimal('96000'), 3, 109),
#  (4, 'Maurer', Decimal('1400'), 109, 3),
#  (5, 'Lampis', Decimal('1300'), 110, 2),
#  (6, 'Callahan', Decimal('1200'), 111, 1)]

# %% [markdown]
# ## DENSE_RANK

# %%
# %%sql
# SELECT
#     ROW_NUMBER() OVER
#             ( ORDER BY UNITES_STOCK NULLS LAST) RN,
#     NOM_PRODUIT, NO_FOURNISSEUR NF, UNITES_STOCK US,
#     RANK() OVER ( ORDER BY UNITES_STOCK) R,
#     DENSE_RANK() OVER (ORDER BY UNITES_STOCK) DR,
#     DENSE_RANK() OVER (ORDER BY UNITES_STOCK
#                       NULLS FIRST) DRI
# FROM PRODUITS
# WHERE CODE_CATEGORIE = 1
# ORDER BY US NULLS LAST
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [(1, 'Outback Lager', 7, 15, 1, 1, 2),
#  (2, 'Chang', 1, 17, 2, 2, 3),
#  (3, 'Côte de Blaye', 18, 17, 2, 2, 3),
#  (4, 'Ipoh Coffee', 20, 17, 2, 2, 3),
#  (5, 'Steeleye Stout', 16, 20, 5, 3, 4),
#  (6, 'Chai', 1, 39, 6, 4, 5),
#  (7, 'Tea', 14, 50, 7, 5, 6),
#  (8, 'Laughing Lumberjack Lager', 16, 52, 8, 6, 7),
#  (9, 'Lakkalikööri', 23, 57, 9, 7, 8),
#  (10, 'Beer', 18, 60, 10, 8, 9),
#  (11, 'Chartreuse verte', 18, 69, 11, 9, 10),
#  (12, 'Coffee', 16, 100, 12, 10, 11),
#  (13, 'Sasquatch Ale', 16, 111, 13, 11, 12),
#  (14, 'Rhönbräu Klosterbier', 12, 125, 14, 12, 13),
#  (15, 'Green Tea', 14, 125, 14, 12, 13),
#  (16, 'Guaraná Fantástica', 10, None, 16, 13, 1)]

# %% [markdown]
# ## PERCENT_RANK

# %%
# %%sql
# SELECT
#     FONCTION,
#     PAYS,
#     SUM(SALAIRE) SS,
#     PERCENT_RANK() OVER ( PARTITION BY FONCTION
#            ORDER BY SUM(SALAIRE)) PERCENT_RANK
# FROM EMPLOYES
# GROUP BY FONCTION, PAYS
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Assistante commerciale', None, 16540, 0),
#  ('Chef des ventes', None, 83000, 0),
#  ('Président', None, 150000, 0),
#  ('Représentant(e)', 'Brésil', 23100, 0),
#  ('Représentant(e)', 'États-Unis', 23100, 0),
#  ('Représentant(e)', 'Autriche', 25600, Decimal('0.1')),
#  ('Représentant(e)', 'Belgique', 27000, Decimal('0.15')),
#  ('Représentant(e)', 'Danemark', 27500, Decimal('0.2')),
#  ('Représentant(e)', 'Mexique', 28900, Decimal('0.25')),
#  ('Représentant(e)', 'Italie', 29000, Decimal('0.3')),
#  ('Représentant(e)', 'Finlande', 29800, Decimal('0.35')),
#  ('Représentant(e)', 'Suède', 31300, Decimal('0.4')),
#  ('Représentant(e)', 'Portugal', 31600, Decimal('0.45')),
#  ('Représentant(e)', 'France', 32200, Decimal('0.5')),
#  ('Représentant(e)', 'Pologne', 32400, Decimal('0.55')),
#  ('Représentant(e)', 'Norvège', 35300, Decimal('0.6')),
#  ('Représentant(e)', 'Canada', 35500, Decimal('0.65')),
# ...

# %% [markdown]
# ## NTILE

# %%
# %%sql
# SELECT
#     ROW_NUMBER() OVER(ORDER BY SUM(PRIX_UNITAIRE*QUANTITE)) RN,
#     PAYS,
#     SUM(PRIX_UNITAIRE*QUANTITE) CA,
#     NTILE(4) OVER(ORDER BY SUM(PRIX_UNITAIRE*QUANTITE)) NT
# FROM CLIENTS CL
#     JOIN COMMANDES CO
#         ON ( CL.CODE_CLIENT = CO.CODE_CLIENT)
#     JOIN DETAILS_COMMANDES DC
#         ON ( CO.NO_COMMANDE = DC.NO_COMMANDE)
# WHERE ANNEE = 2011
# GROUP BY PAYS
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [(1, 'Pologne', 10464648, 1),
#  (2, 'Irlande', Decimal('18515472.96'), 1),
#  (3, 'Norvège', Decimal('19121804.88'), 1),
#  (4, 'Autriche', Decimal('23540791.8'), 1),
#  (5, 'Finlande', Decimal('26656539.48'), 1),
#  (6, 'Suisse', Decimal('29869836.12'), 1),
#  (7, 'Belgique', Decimal('30031948.44'), 2),
#  (8, 'Suède', Decimal('32004958.92'), 2),
#  (9, 'Danemark', Decimal('33055389.84'), 2),
#  (10, 'Portugal', Decimal('36860874.6'), 2),
#  (11, 'Italie', Decimal('42563171.16'), 2),
#  (12, 'Argentine', Decimal('43528525.56'), 3),
#  (13, 'Canada', Decimal('51809202.24'), 3),
#  (14, 'Venezuela', Decimal('65413824.72'), 3),
#  (15, 'Mexique', Decimal('72323122.32'), 3),
#  (16, 'Espagne', Decimal('81051274.56'), 3),
#  (17, 'Royaume-Uni', Decimal('112585949.16'), 4),
#  (18, 'Brésil', Decimal('130405107.6'), 4),
#  (19, 'Allemagne', Decimal('171322408.08'), 4),
# ...

# %% [markdown]
# ## WIDTH_BUCKET

# %%
# %%sql
# SELECT
#     PAYS,
#     SUM(QUANTITE) Q,
#     ROUND(MAX(SUM(QUANTITE))OVER()   / 4) B1,
#     ROUND(MAX(SUM(QUANTITE))OVER()   / 2) B2,
#     ROUND(MAX(SUM(QUANTITE))OVER()*3 / 4) B3,
#     NTILE(4) OVER(ORDER BY SUM(QUANTITE)) NT,
#     WIDTH_BUCKET( SUM(QUANTITE),
#                   MIN(SUM(QUANTITE)) OVER (),
#                   MAX(SUM(QUANTITE)) OVER ()+1,
#                   4 ) WB
# FROM CLIENTS CL
#      JOIN COMMANDES CO
#         ON ( CL.CODE_CLIENT = CO.CODE_CLIENT)
#      JOIN DETAILS_COMMANDES DC
#         ON ( CO.NO_COMMANDE = DC.NO_COMMANDE)
# WHERE ANNEE = 2011
# GROUP BY PAYS
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Pologne', 159140, 740755, 1481509, 2222264, 1, 1),
#  ('Irlande', 282713, 740755, 1481509, 2222264, 1, 1),
#  ('Norvège', 291405, 740755, 1481509, 2222264, 1, 1),
#  ('Autriche', 362205, 740755, 1481509, 2222264, 1, 1),
#  ('Finlande', 407997, 740755, 1481509, 2222264, 1, 1),
#  ('Suisse', 457257, 740755, 1481509, 2222264, 1, 1),
#  ('Belgique', 457380, 740755, 1481509, 2222264, 2, 1),
#  ('Suède', 488813, 740755, 1481509, 2222264, 2, 1),
#  ('Danemark', 506217, 740755, 1481509, 2222264, 2, 1),
#  ('Portugal', 564737, 740755, 1481509, 2222264, 2, 1),
#  ('Italie', 649492, 740755, 1481509, 2222264, 2, 1),
#  ('Argentine', 663302, 740755, 1481509, 2222264, 3, 1),
#  ('Canada', 794266, 740755, 1481509, 2222264, 3, 1),
#  ('Venezuela', 998992, 740755, 1481509, 2222264, 3, 2),
#  ('Mexique', 1101722, 740755, 1481509, 2222264, 3, 2),
#  ('Espagne', 1238242, 740755, 1481509, 2222264, 3, 2),
# ...

# %% [markdown]
# # Fonctions de fenêtre
# ## FIRST_VALUE

# %%
# %%sql
# WITH VENTES AS (
# SELECT CL.PAYS,CO.DATE_COMMANDE,SUM(CO.PORT) SP
#     FROM CLIENTS CL JOIN COMMANDES CO
#          ON ( CL.CODE_CLIENT = CO.CODE_CLIENT
#              AND CO.ANNEE = 2011 AND CO.MOIS = 5
#              AND CL.PAYS IN ('Suisse'))
# GROUP BY CL.PAYS,CO.DATE_COMMANDE)
# SELECT PAYS,JOUR,SP,
#        FIRST_VALUE( SP) OVER
#          ( ORDER BY JOUR RANGE INTERVAL '1' DAY PRECEDING) FV1,
#        FIRST_VALUE( SP) OVER ( ORDER BY JOUR
#                                RANGE 1 PRECEDING )         FV2,
#        FIRST_VALUE( SP) OVER ( ORDER BY JOUR)              FV3,
#        FIRST_VALUE( SP) IGNORE NULLS OVER ( ORDER BY JOUR) FV4
# FROM VENTES V
#      PARTITION BY (PAYS) RIGHT OUTER JOIN
#       ( SELECT JOUR FROM DIM_TEMPS
#         WHERE  ANNEE = 2011 AND MOIS_N = 5) T
#      ON ( V.DATE_COMMANDE = T.JOUR)
# ORDER BY PAYS,JOUR
# FETCH NEXT 10 ROWS WITH TIES
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('Suisse', datetime.datetime(2011, 5, 1, 0, 0), None, None, None, None, None),
#  ('Suisse', datetime.datetime(2011, 5, 2, 0, 0), Decimal('73.6'), None, None, None, Decimal('73.6')),
#  ('Suisse', datetime.datetime(2011, 5, 3, 0, 0), Decimal('87.6'), Decimal('73.6'), Decimal('73.6'), None, Decimal('73.6')),
#  ('Suisse', datetime.datetime(2011, 5, 4, 0, 0), None, Decimal('87.6'), Decimal('87.6'), None, Decimal('73.6')),
#  ('Suisse', datetime.datetime(2011, 5, 5, 0, 0), Decimal('61.4'), None, None, None, Decimal('73.6')),
#  ('Suisse', datetime.datetime(2011, 5, 6, 0, 0), Decimal('78.5'), Decimal('61.4'), Decimal('61.4'), None, Decimal('73.6')),
#  ('Suisse', datetime.datetime(2011, 5, 7, 0, 0), Decimal('65.1'), Decimal('78.5'), Decimal('78.5'), None, Decimal('73.6')),
#  ('Suisse', datetime.datetime(2011, 5, 8, 0, 0), 122, Decimal('65.1'), Decimal('65.1'), None, Decimal('73.6')),
# ...

# %% [markdown]
# ## LAST_VALUE

# %%
# %%sql
# SELECT PAYS, MOIS, SUM(DC.QUANTITE) Q,
#        LAST_VALUE( SUM(DC.QUANTITE)) OVER
#          ( PARTITION BY PAYS ORDER BY MOIS ROWS
#                   BETWEEN CURRENT ROW AND 1 FOLLOWING ) LV1,
#        LAST_VALUE( SUM(DC.QUANTITE)) OVER
#                     ( PARTITION BY PAYS ORDER BY MOIS ) LV2,
#        LAST_VALUE( SUM(DC.QUANTITE)) OVER
#                     ( PARTITION BY PAYS               ) LV3
# FROM CLIENTS CL
#      JOIN COMMANDES CO
#         ON ( CL.CODE_CLIENT = CO.CODE_CLIENT)
#      JOIN DETAILS_COMMANDES DC
#         ON ( CO.NO_COMMANDE = DC.NO_COMMANDE)
#      JOIN PRODUITS PR
#         ON ( DC.REF_PRODUIT = PR.REF_PRODUIT)
# WHERE ANNEE = 2010 AND PAYS IN ('France','Suisse')
# GROUP BY PAYS, MOIS
# Out:
#  * oracle+cx_oracle://stag01:***@51.91.76.248:15440/coursdb
# 0 rows affected.
# [('France', 1, 369797, 266531, 369797, 188311),
#  ('France', 2, 266531, 292601, 266531, 188311),
#  ('France', 3, 292601, 320200, 292601, 188311),
#  ('France', 4, 320200, 354684, 320200, 188311),
#  ('France', 5, 354684, 265565, 354684, 188311),
#  ('France', 6, 265565, 271807, 265565, 188311),
#  ('France', 7, 271807, 336000, 271807, 188311),
#  ('France', 8, 336000, 326181, 336000, 188311),
#  ('France', 9, 326181, 383735, 326181, 188311),
#  ('France', 10, 383735, 355441, 383735, 188311),
#  ('France', 11, 355441, 188311, 355441, 188311),
#  ('France', 12, 188311, 188311, 188311, 188311),
#  ('Suisse', 1, 48029, 70379, 48029, 49359),
#  ('Suisse', 2, 70379, 26949, 70379, 49359),
#  ('Suisse', 3, 26949, 55450, 26949, 49359),
#  ('Suisse', 4, 55450, 66974, 55450, 49359),
#  ('Suisse', 5, 66974, 73855, 66974, 49359),
#  ('Suisse', 6, 73855, 95323, 73855, 49359),
# ...
