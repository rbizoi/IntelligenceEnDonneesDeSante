# %% [markdown]
# # Les librairies nécessaires

# %%
import pandas as pd 
import seaborn as sns
import warnings 
import os
import sqlalchemy

from datetime import datetime
warnings.filterwarnings(action="ignore")

# %pylab inline
# %load_ext sql

plt.style.use('seaborn-darkgrid')
sns.set(font_scale=3)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# # La connexion à la base de données PostgreSQL
#
# **`postgresql://user:pass@host:port/dbname[?key=value&key=value...]`**<br>
# **`engine = create_engine("postgresql://scott:tiger@localhost/test")`**<br>

# %%
# %sql postgresql://

# %% [markdown]
# # La jointure sans condition
#
# <img src="https://raw.githubusercontent.com/rbizoi/IntelligenceEnDonneesDeSante/main/InterrogationSQL/images/produit_relationel.png" width="400">

# %%
# %sql SELECT COUNT(*) FROM PRODUITS
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(120,)]

# %%
# %sql SELECT COUNT(*) FROM CATEGORIES
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(10,)]

# %%
# %sql SELECT NOM_PRODUIT, NOM_CATEGORIE FROM PRODUITS, CATEGORIES
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1200 rows affected.
# [('Tea', 'Boissons'),
#  ('Tea', 'Condiments'),
#  ('Tea', 'Desserts'),
#  ('Tea', 'Produits laitiers'),
#  ('Tea', 'Pâtes et céréales'),
#  ('Tea', 'Viandes'),
#  ('Tea', 'Produits secs'),
#  ('Tea', 'Poissons et fruits de mer'),
#  ('Tea', 'Conserves'),
#  ('Tea', 'Viande en conserve'),
#  ('Pears', 'Boissons'),
#  ('Pears', 'Condiments'),
#  ('Pears', 'Desserts'),
#  ('Pears', 'Produits laitiers'),
#  ('Pears', 'Pâtes et céréales'),
#  ('Pears', 'Viandes'),
#  ('Pears', 'Produits secs'),
#  ('Pears', 'Poissons et fruits de mer'),
#  ('Pears', 'Conserves'),
#  ('Pears', 'Viande en conserve'),
#  ('Peaches', 'Boissons'),
#  ('Peaches', 'Condiments'),
#  ('Peaches', 'Desserts'),
#  ('Peaches', 'Produits laitiers'),
#  ('Peaches', 'Pâtes et céréales'),
#  ('Peaches', 'Viandes'),
#  ('Peaches', 'Produits secs'),
#  ('Peaches', 'Poissons et fruits de mer'),
#  ('Peaches', 'Conserves'),
# ...

# %%
# %sql SELECT count(*) FROM PRODUITS, CATEGORIES
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(1200,)]

# %% [markdown]
# # La jointure avec condition
#
# <img src="https://raw.githubusercontent.com/rbizoi/IntelligenceEnDonneesDeSante/main/InterrogationSQL/images/jointure.png" width="400">

# %%
# %%sql
# SELECT A.CODE_CATEGORIE CAT,
#        NOM_PRODUIT "Produit",
#        NOM_CATEGORIE "Categorie"
# FROM PRODUITS A
#      JOIN CATEGORIES B
#      ON A.CODE_CATEGORIE = B.CODE_CATEGORIE
# ORDER BY NOM_PRODUIT
# FETCH FIRST 10 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 10 rows affected.
# [(Decimal('6'), 'Alice Mutton', 'Viandes'),
#  (Decimal('7'), 'Amandes', 'Produits secs'),
#  (Decimal('2'), 'Aniseed Syrup', 'Condiments'),
#  (Decimal('1'), 'Beer', 'Boissons'),
#  (Decimal('8'), 'Boston Crab Meat', 'Poissons et fruits de mer'),
#  (Decimal('9'), 'Boysenberry Spread', 'Conserves'),
#  (Decimal('3'), 'Brownie Mix', 'Desserts'),
#  (Decimal('2'), 'Cajun Seasoning', 'Condiments'),
#  (Decimal('3'), 'Cake Mix', 'Desserts'),
#  (Decimal('4'), 'Camembert Pierrot', 'Produits laitiers')]

# %%
# %%sql
# SELECT C.NOM||' '||C.PRENOM "Vendeur",
#        A.SOCIETE "Client",
#        B.DATE_COMMANDE "Commande",
#        B.PORT "Port"
# FROM CLIENTS A
#      JOIN COMMANDES B
#           ON A.CODE_CLIENT = B.CODE_CLIENT
#      JOIN EMPLOYES C
#           ON B.NO_EMPLOYE  = C.NO_EMPLOYE
# WHERE  B.DATE_COMMANDE > '2011-06-29'
# FETCH FIRST 10 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 10 rows affected.
# [('Cazade Anne-Claire', 'Ernst Handel', datetime.date(2011, 6, 30), Decimal('83.90')),
#  ('Twardowski Colette', 'Wolski  Zajazd', datetime.date(2011, 6, 30), Decimal('54.90')),
#  ('Clement Valérie', 'Bólido Comidas preparadas', datetime.date(2011, 6, 30), Decimal('59.70')),
#  ('Marielle Michel', 'QUICK-Stop', datetime.date(2011, 6, 30), Decimal('74.80')),
#  ('Cleret Doris', 'Océano Atlántico Ltda.', datetime.date(2011, 6, 30), Decimal('79.80')),
#  ('Kessler Marc', 'North/South', datetime.date(2011, 6, 30), Decimal('93.30')),
#  ('Jenny Michel', 'Comércio Mineiro', datetime.date(2011, 6, 30), Decimal('85.10')),
#  ('Viry Yvan', 'Ricardo Adocicados', datetime.date(2011, 6, 30), Decimal('64.90')),
#  ('Marielle Michel', 'Toms Spezialitäten', datetime.date(2011, 6, 30), Decimal('68.20')),
#  ('Tourtel Nicole', 'Hungry Owl All-Night Grocers', datetime.date(2011, 6, 30), Decimal('66.30'))]

# %%
# %%sql
# SELECT DC.REF_PRODUIT,
# COUNT( DISTINCT CO.NO_COMMANDE) COM
# FROM DETAILS_COMMANDES DC
#      JOIN PRODUITS PR
#           ON ( DC.PRIX_UNITAIRE BETWEEN PR.PRIX_UNITAIRE*0.95
#           AND PR.PRIX_UNITAIRE*1.05
#           AND PR.REF_PRODUIT = 57 )
#      JOIN COMMANDES CO
#           ON  ( CO.NO_COMMANDE = DC.NO_COMMANDE
#                AND extract(year from CO.DATE_COMMANDE)   = 2011 )
#      JOIN CLIENTS CL
#      ON  ( CO.CODE_CLIENT = CL.CODE_CLIENT AND CL.PAYS LIKE 'A%')
# GROUP BY DC.REF_PRODUIT
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [(Decimal('20'), 276),
#  (Decimal('62'), 259),
#  (Decimal('96'), 292),
#  (Decimal('111'), 228),
#  (Decimal('120'), 274)]

# %% [markdown]
# <img src="https://raw.githubusercontent.com/rbizoi/IntelligenceEnDonneesDeSante/main/InterrogationSQL/images/612.png" width="800">

# %%
# %sql SELECT COUNT(*) FROM CLIENTS
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(91,)]

# %%
# %sql SELECT COUNT(*) FROM COMMANDES
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(13462,)]

# %%
# %sql SELECT COUNT(*) FROM DETAILS_COMMANDES
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(476091,)]

# %%
# %%sql
# SELECT COUNT(*)
# FROM CLIENTS CL
#      JOIN COMMANDES CO
#         ON ( CL.CODE_CLIENT = CO.CODE_CLIENT)
#      JOIN EMPLOYES EM
#         ON ( EM.NO_EMPLOYE = CO.NO_EMPLOYE)
#      JOIN DETAILS_COMMANDES DC
#         ON ( CO.NO_COMMANDE = DC.NO_COMMANDE)
#      JOIN PRODUITS PR
#         ON ( DC.REF_PRODUIT = PR.REF_PRODUIT)
#      JOIN FOURNISSEURS FR
#         ON ( PR.NO_FOURNISSEUR = FR.NO_FOURNISSEUR )
#      JOIN CATEGORIES CA
#         ON ( PR.CODE_CATEGORIE = CA.CODE_CATEGORIE )
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(476091,)]

# %% [markdown]
# # La jointure externe
#
#
# <img src="https://raw.githubusercontent.com/rbizoi/IntelligenceEnDonneesDeSante/main/InterrogationSQL/images/M06-07.png" width="400">

# %% [markdown]
# ## INNER JOIN

# %%
# %%sql
# SELECT COALESCE(C.VILLE,F.VILLE) VILLE,
#        COALESCE(C.SOCIETE,'-------') CLIENT,
#        COALESCE(F.SOCIETE,'-------') FOURNISSEUR
# FROM CLIENTS C INNER JOIN FOURNISSEURS F
#      ON C.VILLE = F.VILLE
# ORDER BY VILLE
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 15 rows affected.
# [('Berlin', 'Alfreds Futterkiste', 'Heli Süßwaren GmbH  Co. KG'),
#  ('Frankfurt a.M.', 'Lehmanns Marktstand', 'Plutzer Lebensmittelgroßmärkte AG'),
#  ('London', "B's Beverages", 'Exotic Liquids'),
#  ('London', 'Consolidated Holdings', 'Exotic Liquids'),
#  ('London', 'Eastern Connection', 'Exotic Liquids'),
#  ('London', 'Seven Seas Imports', 'Exotic Liquids'),
#  ('London', 'Around the Horn', 'Exotic Liquids'),
#  ('London', 'North/South', 'Exotic Liquids'),
#  ('Montréal', 'Mère Paillarde', 'Ma Maison'),
#  ('Paris', 'Spécialités du monde', 'Aux joyeux ecclésiastiques'),
#  ('Paris', 'Paris spécialités', 'Aux joyeux ecclésiastiques'),
#  ('São Paulo', 'Comércio Mineiro', 'Refrescos Americanas LTDA'),
#  ('São Paulo', 'Familia Arquibaldo', 'Refrescos Americanas LTDA'),
#  ('São Paulo', 'Queen Cozinha', 'Refrescos Americanas LTDA'),
#  ('São Paulo', 'Tradição Hipermercados', 'Refrescos Americanas LTDA')]

# %% [markdown]
# ## LEFT OUTER JOIN

# %%
# %%sql
# SELECT COALESCE(C.VILLE,F.VILLE) VILLE,
#        COALESCE(C.SOCIETE,'-------') CLIENT,
#        COALESCE(F.SOCIETE,'-------') FOURNISSEUR
# FROM CLIENTS C LEFT OUTER JOIN FOURNISSEURS F
#      ON C.VILLE = F.VILLE
# ORDER BY VILLE
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 91 rows affected.
# [('Aachen', 'Drachenblut Delikatessen', '-------'),
#  ('Albuquerque', 'Rattlesnake Canyon Grocery', '-------'),
#  ('Anchorage', 'Old World Delicatessen', '-------'),
#  ('Århus', 'Vaffeljernet', '-------'),
#  ('Barcelona', 'Galería del gastrónomo', '-------'),
#  ('Barquisimeto', 'LILA-Supermercado', '-------'),
#  ('Bergamo', 'Magazzini Alimentari Riuniti', '-------'),
#  ('Berlin', 'Alfreds Futterkiste', 'Heli Süßwaren GmbH  Co. KG'),
#  ('Bern', 'Chop-suey Chinese', '-------'),
#  ('Boise', 'Save-a-lot Markets', '-------'),
#  ('Bräcke', 'Folk och fä HB', '-------'),
#  ('Brandenburg', 'Königlich Essen', '-------'),
#  ('Bruxelles', 'Maison Dewey', '-------'),
#  ('Buenos Aires', 'Océano Atlántico Ltda.', '-------'),
#  ('Buenos Aires', 'Cactus Comidas para llevar', '-------'),
#  ('Buenos Aires', 'Rancho grande', '-------'),
#  ('Butte', 'The Cracker Box', '-------'),
# ...

# %% [markdown]
# ## RIGHT OUTER JOIN

# %%
# %%sql
# SELECT COALESCE(C.VILLE,F.VILLE) VILLE,
#        COALESCE(C.SOCIETE,'-------') CLIENT,
#        COALESCE(F.SOCIETE,'-------') FOURNISSEUR
# FROM CLIENTS C RIGHT OUTER JOIN FOURNISSEURS F
#      ON C.VILLE = F.VILLE
# ORDER BY VILLE
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 38 rows affected.
# [('Ann Arbor', '-------', "Grandma Kelly's Homestead"),
#  ('Annecy', '-------', 'Gai pâturage'),
#  ('Bend', '-------', 'Bigfoot Breweries'),
#  ('Berlin', 'Alfreds Futterkiste', 'Heli Süßwaren GmbH  Co. KG'),
#  ('Boston', '-------', 'New England Seafood Cannery'),
#  ('Cuxhaven', '-------', 'Nord-Ost-Fisch Handelsgesellschaft mbH'),
#  ('Frankfurt a.M.', 'Lehmanns Marktstand', 'Plutzer Lebensmittelgroßmärkte AG'),
#  ('Göteborg', '-------', 'PB Knäckebröd AB'),
#  ('Lappeenranta', '-------', 'Karkki Oy'),
#  ('London', 'Around the Horn', 'Exotic Liquids'),
#  ('London', 'Eastern Connection', 'Exotic Liquids'),
#  ('London', 'Consolidated Holdings', 'Exotic Liquids'),
#  ('London', 'North/South', 'Exotic Liquids'),
#  ('London', 'Seven Seas Imports', 'Exotic Liquids'),
#  ('London', "B's Beverages", 'Exotic Liquids'),
#  ('Lyngby', '-------', 'Lyngbysild'),
# ...

# %% [markdown]
# ## FULL OUTER JOIN

# %%
# %%sql
# SELECT COALESCE(C.VILLE,F.VILLE) VILLE,
#        COALESCE(C.SOCIETE,'-------') CLIENT,
#        COALESCE(F.SOCIETE,'-------') FOURNISSEUR
# FROM CLIENTS C FULL OUTER JOIN FOURNISSEURS F
#      ON C.VILLE = F.VILLE
# ORDER BY VILLE
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 114 rows affected.
# [('Aachen', 'Drachenblut Delikatessen', '-------'),
#  ('Albuquerque', 'Rattlesnake Canyon Grocery', '-------'),
#  ('Anchorage', 'Old World Delicatessen', '-------'),
#  ('Ann Arbor', '-------', "Grandma Kelly's Homestead"),
#  ('Annecy', '-------', 'Gai pâturage'),
#  ('Århus', 'Vaffeljernet', '-------'),
#  ('Barcelona', 'Galería del gastrónomo', '-------'),
#  ('Barquisimeto', 'LILA-Supermercado', '-------'),
#  ('Bend', '-------', 'Bigfoot Breweries'),
#  ('Bergamo', 'Magazzini Alimentari Riuniti', '-------'),
#  ('Berlin', 'Alfreds Futterkiste', 'Heli Süßwaren GmbH  Co. KG'),
#  ('Bern', 'Chop-suey Chinese', '-------'),
#  ('Boise', 'Save-a-lot Markets', '-------'),
#  ('Boston', '-------', 'New England Seafood Cannery'),
#  ('Bräcke', 'Folk och fä HB', '-------'),
#  ('Brandenburg', 'Königlich Essen', '-------'),
#  ('Bruxelles', 'Maison Dewey', '-------'),
# ...

# %% [markdown]
# # Atelier 7.1	Les requêtes multi-tables
# <img src="https://raw.githubusercontent.com/rbizoi/IntelligenceEnDonneesDeSante/main/InterrogationSQL/images/612.png" width="800">
# ## Les équijointures
# Écrivez les requêtes vous permettant d’afficher :
#
# >> * Le nom, le prénom et la société cliente pour les employés qui ont effectué une vente pour les clients de Paris.
# >> * La société cliente, le nombre des produits commandés, la ville et le pays qui ont commandé plus de 115 références de produits au mois de mai 2011.
# >> * Le nom de la catégorie du produit, la société fournisseur et le nom du produit, uniquement pour les produits des catégories 1, 4 et 7.
# >> * La société cliente, la société fournisseur et leur ville pour les clients qui sont localisés dans une ville d’un fournisseur (Il s’agit d’une jointure entre la table **CLIENTS** et **FOURNISSEURS**).
# >> * Les sociétés clientes qui ont commandé le produit **'Chai'**.
#
# ## Les jointures externes
# Écrivez les requêtes vous permettant d’afficher :
# >> * Tous les clients et le cumul des quantités vendues pour les clients qui ont passé des commandes. Affichez les enregistrements par ordre décroissant de cumul des commandes avec les valeurs « NULL » à la fin.
# >> * Les localités des clients et le cumul des quantités vendues par localité. Affichez les enregistrements par ordre décroissant de cumul des commandes avec les valeurs « NULL » à la fin.
# >> * Le nom, le prénom, la fonction de tous les employés, la somme des frais de port et le cumul des ventes (prix unitaire fois la quantité) pour les employés qui ont passé des commandes. Affichez les enregistrements par ordre décroissant de cumul des ventes avec les valeurs « NULL » à la fin.
# >> * Le nom, le prénom, la fonction des supérieurs hiérarchiques ainsi le nom et prénom des employés gérés par eux.
# >> * Le nom, le prénom, la fonction des tous les employés, le nom et prénom des employés gérés par eux, si tél est le cas, ainsi que le nom et prénom des employés gérés par les précédents si tél est le cas.
