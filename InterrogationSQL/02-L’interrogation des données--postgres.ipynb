# %% [markdown]
# # Les librairies nécessaires

# %%
import pandas as pd 
import seaborn as sns
import warnings 
import os
import sqlalchemy

from datetime import datetime
warnings.filterwarnings(action="ignore")

# %pylab inline
# %load_ext sql

plt.style.use('seaborn-darkgrid')
sns.set(font_scale=3)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# # La connexion à la base de données PostgreSQL
#
# **`postgresql://user:pass@host:port/dbname[?key=value&key=value...]`**<br>
# **`engine = create_engine("postgresql://scott:tiger@localhost/test")`**<br>

# %%
# %sql postgresql://

# %% [markdown]
# # Projection
#
#
# >> SELECT [ ALL | DISTINCT ] <br>
# >>> { [{ NOM_TABLE | ALIAS2 }.]* ,<br><br>
# >>> [ [{NOM_TABLE |ALIAS2}.]COLONNE1 [AS] ALIAS1[,...]} <br><br>
#
# >> FROM NOM_TABLE ALIAS2 <br>

# %%
# %%sql
# SELECT  CODE_CLIENT,
#         DATE_COMMANDE,
#         NO_EMPLOYE,
#         PORT
# FROM COMMANDES
# FETCH NEXT 5 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [('LONEP', datetime.date(2010, 2, 2), Decimal('84'), Decimal('50.10')),
#  ('PERIC', datetime.date(2010, 2, 2), Decimal('78'), Decimal('97.60')),
#  ('BOTTM', datetime.date(2010, 2, 2), Decimal('72'), Decimal('89.30')),
#  ('SPECD', datetime.date(2010, 2, 2), Decimal('111'), Decimal('86.20')),
#  ('WELLI', datetime.date(2010, 2, 2), Decimal('39'), Decimal('71.90'))]

# %%
# %%sql
# SELECT
#     COMMANDES.CODE_CLIENT,
#     COMMANDES.DATE_COMMANDE,
#     COMMANDES.NO_EMPLOYE,
#     PORT
# FROM COMMANDES
# FETCH NEXT 5 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [('LONEP', datetime.date(2010, 2, 2), Decimal('84'), Decimal('50.10')),
#  ('PERIC', datetime.date(2010, 2, 2), Decimal('78'), Decimal('97.60')),
#  ('BOTTM', datetime.date(2010, 2, 2), Decimal('72'), Decimal('89.30')),
#  ('SPECD', datetime.date(2010, 2, 2), Decimal('111'), Decimal('86.20')),
#  ('WELLI', datetime.date(2010, 2, 2), Decimal('39'), Decimal('71.90'))]

# %%
# %%sql
# select fonction
# from employes
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 111 rows affected.
# [('Président',),
#  ('Vice-Président',),
#  ('Vice-Président',),
#  ('Chef des ventes',),
#  ('Chef des ventes',),
#  ('Chef des ventes',),
#  ('Chef des ventes',),
#  ('Chef des ventes',),
#  ('Chef des ventes',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Assistante commerciale',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Assistante commerciale',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Assistante commerciale',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Assistante commerciale',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Assistante commerciale',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Assistante commerciale',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Assistante commerciale',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Assistante commerciale',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Assistante commerciale',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Représentant(e)',),
#  ('Assistante commerciale',),
#  ('Représentant(e)',),
#  ('Représentant(e)',)]

# %%
# %%sql
# select distinct fonction
# from employes
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [('Vice-Président',),
#  ('Chef des ventes',),
#  ('Représentant(e)',),
#  ('Assistante commerciale',),
#  ('Président',)]

# %% [markdown]
# # Les constantes

# %%
# %%sql
#
# SELECT 0 as "c1", -1234567890 as "c2", +1234567890 as "c3",
#        -123.456 as "c4", +123.456 as "c5", -1E+13 as "c6"
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(0, -1234567890, 1234567890, Decimal('-123.456'), Decimal('123.456'), Decimal('-10000000000000'))]

# %%
# %%sql
# SELECT -123 as "c1", 456 as "c2", +123 as "c3", 456 as "c4",-1E+13 as "c5"
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(-123, 456, 123, 456, Decimal('-10000000000000'))]

# %%
# %%sql
# SELECT now() as "Date"
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 1 rows affected.
# [(datetime.datetime(2022, 11, 22, 17, 40, 51, 389567, tzinfo=datetime.timezone.utc),)]

# %% [markdown]
# # Opérateur de concaténation

# %%
# %%sql
# SELECT
#     NO_EMPLOYE||' -- '||NOM||' -- '||PRENOM||' -- '||DATE_NAISSANCE  "Liste des employés"
# FROM EMPLOYES
# FETCH NEXT 5 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [('37 -- Giroux -- Jean-Claude -- 1979-04-28',),
#  ('14 -- Fuller -- Andrew -- 1984-06-27',),
#  ('18 -- Brasseur -- Hervé -- 1980-05-29',),
#  ('24 -- Buchanan -- Steven -- 1972-11-26',),
#  ('95 -- Leger -- Pierre -- 1989-09-01',)]

# %%
# %%sql
# SELECT
#     concat(NO_EMPLOYE,' -- ',NOM,' -- ',PRENOM)  "Liste des employés"
# FROM EMPLOYES
# FETCH NEXT 5 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [('37 -- Giroux -- Jean-Claude',),
#  ('14 -- Fuller -- Andrew',),
#  ('18 -- Brasseur -- Hervé',),
#  ('24 -- Buchanan -- Steven',),
#  ('95 -- Leger -- Pierre',)]

# %% [markdown]
# # Opérateurs arithmétiques
#
# Une expression arithmétique est une combinaison de noms de colonnes, de constantes et de fonctions arithmétiques (les fonctions arithmétiques sont traitées plus loin) combinées au moyen des opérateurs arithmétiques addition « + », soustraction « - », multiplication « * » ou division « / ».

# %%
# %%sql
# SELECT
#     NOM_PRODUIT "Produit",
#     PRIX_UNITAIRE*UNITES_STOCK "Stock",
#     UNITES_COMMANDEES*12 "Commandes"
# FROM PRODUITS
# FETCH NEXT 5 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [('Tea', Decimal('100.00'), Decimal('240')),
#  ('Pears', Decimal('40.00'), Decimal('120')),
#  ('Peaches', Decimal('40.00'), Decimal('120')),
#  ('Pineapple', Decimal('40.00'), Decimal('120')),
#  ('Cherry Pie Filling', Decimal('40.00'), Decimal('120'))]

# %%
# %%sql
# SELECT
#     NOM||' '||PRENOM as "Employé",
#     SALAIRE * 1.1 as "Salaire"
# FROM EMPLOYES
# FETCH NEXT 5 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [('Giroux Jean-Claude', Decimal('165000.000')),
#  ('Fuller Andrew', Decimal('105600.000')),
#  ('Brasseur Hervé', Decimal('161700.000')),
#  ('Buchanan Steven', Decimal('14300.000')),
#  ('Leger Pierre', Decimal('20900.000'))]

# %%
# %%sql
# SELECT
#     NOM,
#     DATE_NAISSANCE,
#     DATE_NAISSANCE+1 "Jour 1",
#     DATE_NAISSANCE-1 "Jour -1",
#     (now()-DATE_NAISSANCE)/365 "jours"
# FROM EMPLOYES
# FETCH NEXT 5 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [('Giroux', datetime.date(1979, 4, 28), datetime.date(1979, 4, 29), datetime.date(1979, 4, 27), datetime.timedelta(days=43, seconds=52014, microseconds=388087)),
#  ('Fuller', datetime.date(1984, 6, 27), datetime.date(1984, 6, 28), datetime.date(1984, 6, 26), datetime.timedelta(days=38, seconds=37338, microseconds=223703)),
#  ('Brasseur', datetime.date(1980, 5, 29), datetime.date(1980, 5, 30), datetime.date(1980, 5, 28), datetime.timedelta(days=42, seconds=44439, microseconds=593566)),
#  ('Buchanan', datetime.date(1972, 11, 26), datetime.date(1972, 11, 27), datetime.date(1972, 11, 25), datetime.timedelta(days=50, seconds=2068, microseconds=86717)),
#  ('Leger', datetime.date(1989, 9, 1), datetime.date(1989, 9, 2), datetime.date(1989, 8, 31), datetime.timedelta(days=33, seconds=21478, microseconds=497676))]

# %% [markdown]
# # La valeur NULL

# %%
# %%sql
# SELECT NOM, SALAIRE, COMMISSION, SALAIRE+COMMISSION FROM EMPLOYES
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 111 rows affected.
# [('Giroux', Decimal('150000.00'), None, None),
#  ('Fuller', Decimal('96000.00'), None, None),
#  ('Brasseur', Decimal('147000.00'), None, None),
#  ('Buchanan', Decimal('13000.00'), Decimal('12940.00'), Decimal('25940.00')),
#  ('Leger', Decimal('19000.00'), Decimal('11150.00'), Decimal('30150.00')),
#  ('Belin', Decimal('10000.00'), Decimal('10640.00'), Decimal('20640.00')),
#  ('Chambaud', Decimal('12000.00'), Decimal('11600.00'), Decimal('23600.00')),
#  ('Ragon', Decimal('13000.00'), Decimal('5980.00'), Decimal('18980.00')),
#  ('Splingart', Decimal('16000.00'), Decimal('16480.00'), Decimal('32480.00')),
#  ('Besse', Decimal('9900.00'), Decimal('940.00'), Decimal('10840.00')),
#  ('Destenay', Decimal('9900.00'), Decimal('790.00'), Decimal('10690.00')),
#  ('Letertre', Decimal('5600.00'), Decimal('1890.00'), Decimal('7490.00')),
#  ('Kremser', Decimal('6000.00'), Decimal('1610.00'), Decimal('7610.00')),
#  ('Lamarre', Decimal('7800.00'), Decimal('200.00'), Decimal('8000.00')),
#  ('Cleret', Decimal('7900.00'), Decimal('720.00'), Decimal('8620.00')),
#  ('Poidatz', Decimal('6600.00'), Decimal('200.00'), Decimal('6800.00')),
#  ('Messelier', Decimal('9500.00'), Decimal('1470.00'), Decimal('10970.00')),
#  ('Gardeil', Decimal('7800.00'), Decimal('1520.00'), Decimal('9320.00')),
#  ('Capharsie', Decimal('9400.00'), Decimal('410.00'), Decimal('9810.00')),
#  ('Perny', Decimal('6500.00'), Decimal('340.00'), Decimal('6840.00')),
#  ('Courty', Decimal('9900.00'), Decimal('1800.00'), Decimal('11700.00')),
#  ('Suyama', Decimal('8400.00'), Decimal('400.00'), Decimal('8800.00')),
#  ('Malejac', Decimal('8700.00'), Decimal('1130.00'), Decimal('9830.00')),
#  ('Blard', Decimal('5900.00'), Decimal('340.00'), Decimal('6240.00')),
#  ('Pagani', Decimal('6500.00'), Decimal('1330.00'), Decimal('7830.00')),
#  ('Gerard', Decimal('8200.00'), Decimal('1800.00'), Decimal('10000.00')),
#  ('Poupard', Decimal('1800.00'), None, None),
#  ('Piroddi', Decimal('6700.00'), Decimal('190.00'), Decimal('6890.00')),
#  ('Chaussende', Decimal('6600.00'), Decimal('1530.00'), Decimal('8130.00')),
#  ('Hanriot', Decimal('8300.00'), Decimal('1700.00'), Decimal('10000.00')),
#  ('Maurer', Decimal('1400.00'), None, None),
#  ('Davolio', Decimal('8200.00'), Decimal('1740.00'), Decimal('9940.00')),
#  ('Frederic', Decimal('8100.00'), Decimal('1870.00'), Decimal('9970.00')),
#  ('Callahan', Decimal('1200.00'), None, None),
#  ('Pequignot', Decimal('6200.00'), Decimal('1820.00'), Decimal('8020.00')),
#  ('Duriez', Decimal('9100.00'), Decimal('420.00'), Decimal('9520.00')),
#  ('Leverling', Decimal('7400.00'), Decimal('240.00'), Decimal('7640.00')),
#  ('Brunet', Decimal('6600.00'), Decimal('1400.00'), Decimal('8000.00')),
#  ('Cremel', Decimal('6900.00'), Decimal('910.00'), Decimal('7810.00')),
#  ('Perret', Decimal('9500.00'), Decimal('520.00'), Decimal('10020.00')),
#  ('Jenny', Decimal('9800.00'), Decimal('150.00'), Decimal('9950.00')),
#  ('Mennetrier', Decimal('8700.00'), Decimal('1970.00'), Decimal('10670.00')),
#  ('Michiels', Decimal('5500.00'), Decimal('40.00'), Decimal('5540.00')),
#  ('Valot', Decimal('9200.00'), Decimal('680.00'), Decimal('9880.00')),
#  ('Steiner', Decimal('5400.00'), Decimal('1310.00'), Decimal('6710.00')),
#  ('Etienne', Decimal('2000.00'), None, None),
#  ('Gregoire', Decimal('8000.00'), Decimal('30.00'), Decimal('8030.00')),
#  ('Guillossou', Decimal('5200.00'), Decimal('470.00'), Decimal('5670.00')),
#  ('Lefebvre', Decimal('9200.00'), Decimal('530.00'), Decimal('9730.00')),
#  ('Di Clemente', Decimal('8400.00'), Decimal('920.00'), Decimal('9320.00')),
#  ('Bettan', Decimal('5500.00'), Decimal('690.00'), Decimal('6190.00')),
#  ('Rivat', Decimal('5200.00'), Decimal('310.00'), Decimal('5510.00')),
#  ('Alvarez', Decimal('7200.00'), Decimal('1010.00'), Decimal('8210.00')),
#  ('Jacquot', Decimal('8900.00'), Decimal('1030.00'), Decimal('9930.00')),
#  ('Dodsworth', Decimal('8800.00'), Decimal('490.00'), Decimal('9290.00')),
#  ('Petit', Decimal('6300.00'), Decimal('20.00'), Decimal('6320.00')),
#  ('Canu', Decimal('5800.00'), Decimal('550.00'), Decimal('6350.00')),
#  ('Bazart', Decimal('8900.00'), Decimal('760.00'), Decimal('9660.00')),
#  ('Grangirard', Decimal('1700.00'), None, None),
#  ('Barre', Decimal('8800.00'), Decimal('1220.00'), Decimal('10020.00')),
#  ('Mure', Decimal('8200.00'), Decimal('1140.00'), Decimal('9340.00')),
#  ('Jeandel', Decimal('9200.00'), Decimal('1150.00'), Decimal('10350.00')),
#  ('Aubry', Decimal('9500.00'), Decimal('1850.00'), Decimal('11350.00')),
#  ('Kessler', Decimal('6800.00'), Decimal('1780.00'), Decimal('8580.00')),
#  ('Urbaniak', Decimal('7000.00'), Decimal('1760.00'), Decimal('8760.00')),
#  ('Guerdon', Decimal('1700.00'), None, None),
#  ('Griner', Decimal('8100.00'), Decimal('980.00'), Decimal('9080.00')),
#  ('Bodard', Decimal('5500.00'), Decimal('720.00'), Decimal('6220.00')),
#  ('Maillard', Decimal('6600.00'), Decimal('1300.00'), Decimal('7900.00')),
#  ('Dupouey', Decimal('5500.00'), Decimal('40.00'), Decimal('5540.00')),
#  ('Clement', Decimal('7200.00'), Decimal('1370.00'), Decimal('8570.00')),
#  ('Berlioz', Decimal('9400.00'), Decimal('980.00'), Decimal('10380.00')),
#  ('Nocella', Decimal('7600.00'), Decimal('910.00'), Decimal('8510.00')),
#  ('Herve', Decimal('6700.00'), Decimal('1170.00'), Decimal('7870.00')),
#  ('Mangeard', Decimal('8200.00'), Decimal('190.00'), Decimal('8390.00')),
#  ('Cazade', Decimal('7200.00'), Decimal('550.00'), Decimal('7750.00')),
#  ('Devie', Decimal('1540.00'), None, None),
#  ('Peacock', Decimal('6100.00'), Decimal('930.00'), Decimal('7030.00')),
#  ('Idesheim', Decimal('7300.00'), Decimal('600.00'), Decimal('7900.00')),
#  ('Rollet', Decimal('5000.00'), Decimal('570.00'), Decimal('5570.00')),
#  ('Silberreiss', Decimal('9200.00'), Decimal('1100.00'), Decimal('10300.00')),
#  ('Weiss', Decimal('6600.00'), Decimal('1110.00'), Decimal('7710.00')),
#  ('Delorgue', Decimal('5900.00'), Decimal('510.00'), Decimal('6410.00')),
#  ('Zonca', Decimal('6700.00'), Decimal('470.00'), Decimal('7170.00')),
#  ('Twardowski', Decimal('9400.00'), Decimal('1540.00'), Decimal('10940.00')),
#  ('Coutou', Decimal('6900.00'), Decimal('770.00'), Decimal('7670.00')),
#  ('King', Decimal('7200.00'), Decimal('1040.00'), Decimal('8240.00')),
#  ('Dohr', Decimal('8200.00'), Decimal('200.00'), Decimal('8400.00')),
#  ('Maurousset', Decimal('8100.00'), Decimal('1560.00'), Decimal('9660.00')),
#  ('Pouetre', Decimal('2000.00'), None, None),
#  ('Montesinos', Decimal('8700.00'), Decimal('1130.00'), Decimal('9830.00')),
#  ('Aubert', Decimal('5100.00'), Decimal('750.00'), Decimal('5850.00')),
#  ('Thomas', Decimal('7100.00'), Decimal('1310.00'), Decimal('8410.00')),
#  ('Falatik', Decimal('7600.00'), Decimal('1100.00'), Decimal('8700.00')),
#  ('Marielle', Decimal('7100.00'), Decimal('1550.00'), Decimal('8650.00')),
#  ('Marchand', Decimal('6900.00'), Decimal('1280.00'), Decimal('8180.00')),
#  ('Seigne', Decimal('9600.00'), Decimal('1160.00'), Decimal('10760.00')),
#  ('Burst', Decimal('7700.00'), Decimal('1980.00'), Decimal('9680.00')),
#  ('Damas', Decimal('7700.00'), Decimal('530.00'), Decimal('8230.00')),
#  ('Espeche', Decimal('6500.00'), Decimal('1580.00'), Decimal('8080.00')),
#  ('Charles', Decimal('6000.00'), Decimal('1080.00'), Decimal('7080.00')),
#  ('Thimoleon', Decimal('8000.00'), Decimal('1270.00'), Decimal('9270.00')),
#  ('Arrambide', Decimal('5400.00'), Decimal('190.00'), Decimal('5590.00')),
#  ('Ziliox', Decimal('1900.00'), None, None),
#  ('Viry', Decimal('6700.00'), Decimal('740.00'), Decimal('7440.00')),
#  ('Cheutin', Decimal('10000.00'), Decimal('570.00'), Decimal('10570.00')),
#  ('Lombard', Decimal('6400.00'), Decimal('1350.00'), Decimal('7750.00')),
#  ('Tourtel', Decimal('8100.00'), Decimal('1920.00'), Decimal('10020.00')),
#  ('Lampis', Decimal('1300.00'), None, None),
#  ('Regner', Decimal('9300.00'), Decimal('1380.00'), Decimal('10680.00')),
#  ('Teixeira', Decimal('6800.00'), Decimal('330.00'), Decimal('7130.00'))]

# %% [markdown]
# ## COALESCE

# %%
# %%sql
# SELECT NOM,
#        SALAIRE,
#        COMMISSION,
#         SALAIRE+COALESCE(COMMISSION,0) "COMMISSION"
# FROM EMPLOYES
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 111 rows affected.
# [('Giroux', Decimal('150000.00'), None, Decimal('150000.00')),
#  ('Fuller', Decimal('96000.00'), None, Decimal('96000.00')),
#  ('Brasseur', Decimal('147000.00'), None, Decimal('147000.00')),
#  ('Buchanan', Decimal('13000.00'), Decimal('12940.00'), Decimal('25940.00')),
#  ('Leger', Decimal('19000.00'), Decimal('11150.00'), Decimal('30150.00')),
#  ('Belin', Decimal('10000.00'), Decimal('10640.00'), Decimal('20640.00')),
#  ('Chambaud', Decimal('12000.00'), Decimal('11600.00'), Decimal('23600.00')),
#  ('Ragon', Decimal('13000.00'), Decimal('5980.00'), Decimal('18980.00')),
#  ('Splingart', Decimal('16000.00'), Decimal('16480.00'), Decimal('32480.00')),
#  ('Besse', Decimal('9900.00'), Decimal('940.00'), Decimal('10840.00')),
#  ('Destenay', Decimal('9900.00'), Decimal('790.00'), Decimal('10690.00')),
#  ('Letertre', Decimal('5600.00'), Decimal('1890.00'), Decimal('7490.00')),
#  ('Kremser', Decimal('6000.00'), Decimal('1610.00'), Decimal('7610.00')),
#  ('Lamarre', Decimal('7800.00'), Decimal('200.00'), Decimal('8000.00')),
#  ('Cleret', Decimal('7900.00'), Decimal('720.00'), Decimal('8620.00')),
#  ('Poidatz', Decimal('6600.00'), Decimal('200.00'), Decimal('6800.00')),
#  ('Messelier', Decimal('9500.00'), Decimal('1470.00'), Decimal('10970.00')),
#  ('Gardeil', Decimal('7800.00'), Decimal('1520.00'), Decimal('9320.00')),
#  ('Capharsie', Decimal('9400.00'), Decimal('410.00'), Decimal('9810.00')),
#  ('Perny', Decimal('6500.00'), Decimal('340.00'), Decimal('6840.00')),
#  ('Courty', Decimal('9900.00'), Decimal('1800.00'), Decimal('11700.00')),
#  ('Suyama', Decimal('8400.00'), Decimal('400.00'), Decimal('8800.00')),
#  ('Malejac', Decimal('8700.00'), Decimal('1130.00'), Decimal('9830.00')),
#  ('Blard', Decimal('5900.00'), Decimal('340.00'), Decimal('6240.00')),
#  ('Pagani', Decimal('6500.00'), Decimal('1330.00'), Decimal('7830.00')),
#  ('Gerard', Decimal('8200.00'), Decimal('1800.00'), Decimal('10000.00')),
#  ('Poupard', Decimal('1800.00'), None, Decimal('1800.00')),
#  ('Piroddi', Decimal('6700.00'), Decimal('190.00'), Decimal('6890.00')),
#  ('Chaussende', Decimal('6600.00'), Decimal('1530.00'), Decimal('8130.00')),
#  ('Hanriot', Decimal('8300.00'), Decimal('1700.00'), Decimal('10000.00')),
#  ('Maurer', Decimal('1400.00'), None, Decimal('1400.00')),
#  ('Davolio', Decimal('8200.00'), Decimal('1740.00'), Decimal('9940.00')),
#  ('Frederic', Decimal('8100.00'), Decimal('1870.00'), Decimal('9970.00')),
#  ('Callahan', Decimal('1200.00'), None, Decimal('1200.00')),
#  ('Pequignot', Decimal('6200.00'), Decimal('1820.00'), Decimal('8020.00')),
#  ('Duriez', Decimal('9100.00'), Decimal('420.00'), Decimal('9520.00')),
#  ('Leverling', Decimal('7400.00'), Decimal('240.00'), Decimal('7640.00')),
#  ('Brunet', Decimal('6600.00'), Decimal('1400.00'), Decimal('8000.00')),
#  ('Cremel', Decimal('6900.00'), Decimal('910.00'), Decimal('7810.00')),
#  ('Perret', Decimal('9500.00'), Decimal('520.00'), Decimal('10020.00')),
#  ('Jenny', Decimal('9800.00'), Decimal('150.00'), Decimal('9950.00')),
#  ('Mennetrier', Decimal('8700.00'), Decimal('1970.00'), Decimal('10670.00')),
#  ('Michiels', Decimal('5500.00'), Decimal('40.00'), Decimal('5540.00')),
#  ('Valot', Decimal('9200.00'), Decimal('680.00'), Decimal('9880.00')),
#  ('Steiner', Decimal('5400.00'), Decimal('1310.00'), Decimal('6710.00')),
#  ('Etienne', Decimal('2000.00'), None, Decimal('2000.00')),
#  ('Gregoire', Decimal('8000.00'), Decimal('30.00'), Decimal('8030.00')),
#  ('Guillossou', Decimal('5200.00'), Decimal('470.00'), Decimal('5670.00')),
#  ('Lefebvre', Decimal('9200.00'), Decimal('530.00'), Decimal('9730.00')),
#  ('Di Clemente', Decimal('8400.00'), Decimal('920.00'), Decimal('9320.00')),
#  ('Bettan', Decimal('5500.00'), Decimal('690.00'), Decimal('6190.00')),
#  ('Rivat', Decimal('5200.00'), Decimal('310.00'), Decimal('5510.00')),
#  ('Alvarez', Decimal('7200.00'), Decimal('1010.00'), Decimal('8210.00')),
#  ('Jacquot', Decimal('8900.00'), Decimal('1030.00'), Decimal('9930.00')),
#  ('Dodsworth', Decimal('8800.00'), Decimal('490.00'), Decimal('9290.00')),
#  ('Petit', Decimal('6300.00'), Decimal('20.00'), Decimal('6320.00')),
#  ('Canu', Decimal('5800.00'), Decimal('550.00'), Decimal('6350.00')),
#  ('Bazart', Decimal('8900.00'), Decimal('760.00'), Decimal('9660.00')),
#  ('Grangirard', Decimal('1700.00'), None, Decimal('1700.00')),
#  ('Barre', Decimal('8800.00'), Decimal('1220.00'), Decimal('10020.00')),
#  ('Mure', Decimal('8200.00'), Decimal('1140.00'), Decimal('9340.00')),
#  ('Jeandel', Decimal('9200.00'), Decimal('1150.00'), Decimal('10350.00')),
#  ('Aubry', Decimal('9500.00'), Decimal('1850.00'), Decimal('11350.00')),
#  ('Kessler', Decimal('6800.00'), Decimal('1780.00'), Decimal('8580.00')),
#  ('Urbaniak', Decimal('7000.00'), Decimal('1760.00'), Decimal('8760.00')),
#  ('Guerdon', Decimal('1700.00'), None, Decimal('1700.00')),
#  ('Griner', Decimal('8100.00'), Decimal('980.00'), Decimal('9080.00')),
#  ('Bodard', Decimal('5500.00'), Decimal('720.00'), Decimal('6220.00')),
#  ('Maillard', Decimal('6600.00'), Decimal('1300.00'), Decimal('7900.00')),
#  ('Dupouey', Decimal('5500.00'), Decimal('40.00'), Decimal('5540.00')),
#  ('Clement', Decimal('7200.00'), Decimal('1370.00'), Decimal('8570.00')),
#  ('Berlioz', Decimal('9400.00'), Decimal('980.00'), Decimal('10380.00')),
#  ('Nocella', Decimal('7600.00'), Decimal('910.00'), Decimal('8510.00')),
#  ('Herve', Decimal('6700.00'), Decimal('1170.00'), Decimal('7870.00')),
#  ('Mangeard', Decimal('8200.00'), Decimal('190.00'), Decimal('8390.00')),
#  ('Cazade', Decimal('7200.00'), Decimal('550.00'), Decimal('7750.00')),
#  ('Devie', Decimal('1540.00'), None, Decimal('1540.00')),
#  ('Peacock', Decimal('6100.00'), Decimal('930.00'), Decimal('7030.00')),
#  ('Idesheim', Decimal('7300.00'), Decimal('600.00'), Decimal('7900.00')),
#  ('Rollet', Decimal('5000.00'), Decimal('570.00'), Decimal('5570.00')),
#  ('Silberreiss', Decimal('9200.00'), Decimal('1100.00'), Decimal('10300.00')),
#  ('Weiss', Decimal('6600.00'), Decimal('1110.00'), Decimal('7710.00')),
#  ('Delorgue', Decimal('5900.00'), Decimal('510.00'), Decimal('6410.00')),
#  ('Zonca', Decimal('6700.00'), Decimal('470.00'), Decimal('7170.00')),
#  ('Twardowski', Decimal('9400.00'), Decimal('1540.00'), Decimal('10940.00')),
#  ('Coutou', Decimal('6900.00'), Decimal('770.00'), Decimal('7670.00')),
#  ('King', Decimal('7200.00'), Decimal('1040.00'), Decimal('8240.00')),
#  ('Dohr', Decimal('8200.00'), Decimal('200.00'), Decimal('8400.00')),
#  ('Maurousset', Decimal('8100.00'), Decimal('1560.00'), Decimal('9660.00')),
#  ('Pouetre', Decimal('2000.00'), None, Decimal('2000.00')),
#  ('Montesinos', Decimal('8700.00'), Decimal('1130.00'), Decimal('9830.00')),
#  ('Aubert', Decimal('5100.00'), Decimal('750.00'), Decimal('5850.00')),
#  ('Thomas', Decimal('7100.00'), Decimal('1310.00'), Decimal('8410.00')),
#  ('Falatik', Decimal('7600.00'), Decimal('1100.00'), Decimal('8700.00')),
#  ('Marielle', Decimal('7100.00'), Decimal('1550.00'), Decimal('8650.00')),
#  ('Marchand', Decimal('6900.00'), Decimal('1280.00'), Decimal('8180.00')),
#  ('Seigne', Decimal('9600.00'), Decimal('1160.00'), Decimal('10760.00')),
#  ('Burst', Decimal('7700.00'), Decimal('1980.00'), Decimal('9680.00')),
#  ('Damas', Decimal('7700.00'), Decimal('530.00'), Decimal('8230.00')),
#  ('Espeche', Decimal('6500.00'), Decimal('1580.00'), Decimal('8080.00')),
#  ('Charles', Decimal('6000.00'), Decimal('1080.00'), Decimal('7080.00')),
#  ('Thimoleon', Decimal('8000.00'), Decimal('1270.00'), Decimal('9270.00')),
#  ('Arrambide', Decimal('5400.00'), Decimal('190.00'), Decimal('5590.00')),
#  ('Ziliox', Decimal('1900.00'), None, Decimal('1900.00')),
#  ('Viry', Decimal('6700.00'), Decimal('740.00'), Decimal('7440.00')),
#  ('Cheutin', Decimal('10000.00'), Decimal('570.00'), Decimal('10570.00')),
#  ('Lombard', Decimal('6400.00'), Decimal('1350.00'), Decimal('7750.00')),
#  ('Tourtel', Decimal('8100.00'), Decimal('1920.00'), Decimal('10020.00')),
#  ('Lampis', Decimal('1300.00'), None, Decimal('1300.00')),
#  ('Regner', Decimal('9300.00'), Decimal('1380.00'), Decimal('10680.00')),
#  ('Teixeira', Decimal('6800.00'), Decimal('330.00'), Decimal('7130.00'))]

# %%
# %%sql
# SELECT SOCIETE,
#        COALESCE(FAX, 'Non affecté') "Fax"
# FROM CLIENTS
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 91 rows affected.
# [('Consolidated Holdings', '(71) 555-9199'),
#  ('Drachenblut Delikatessen', '0241-059428'),
#  ('Du monde entier', '02.40.67.89.89'),
#  ('Eastern Connection', '(71) 555-3373'),
#  ('Ernst Handel', '7675-3426'),
#  ('Familia Arquibaldo', 'Non affecté'),
#  ('FISSA Fabrica Inter. Salchichas S.A.', '(91) 555 55 93'),
#  ('Folies gourmandes', '03.20.16.10.17'),
#  ('Folk och fä HB', 'Non affecté'),
#  ('Frankenversand', '089-0877451'),
#  ('France restauration', '02.40.32.21.20'),
#  ('Franchi S.p.A.', '011-4988261'),
#  ('Furia Bacalhau e Frutos do Mar', '(1) 354-2535'),
#  ('Galería del gastrónomo', '(93) 203 4561'),
#  ('Godos Cocina Típica', 'Non affecté'),
#  ('Gourmet Lanchonetes', 'Non affecté'),
#  ('Great Lakes Food Market', 'Non affecté'),
#  ('GROSELLA-Restaurante', '(2) 283-3397'),
#  ('Hanari Carnes', '(21) 555-8765'),
#  ('HILARIÓN-Abastos', '(5) 555-1948'),
#  ('Hungry Coyote Import Store', '(503) 555-2376'),
#  ('Hungry Owl All-Night Grocers', '2967 3333'),
#  ('Island Trading', 'Non affecté'),
#  ('Königlich Essen', 'Non affecté'),
#  ("La corne d'abondance", '01.30.59.85.11'),
#  ("La maison d'Asie", '05.61.77.61.11'),
#  ('Laughing Bacchus Wine Cellars', '(604) 555-7293'),
#  ('Lazy K Kountry Store', '(509) 555-6221'),
#  ('Lehmanns Marktstand', '069-0245874'),
#  ("Let's Stop N Shop", 'Non affecté'),
#  ('LILA-Supermercado', '(9) 331-7256'),
#  ('LINO-Delicateses', '(8) 34-93-93'),
#  ('Lonesome Pine Restaurant', '(503) 555-9646'),
#  ('Magazzini Alimentari Riuniti', '035-640231'),
#  ('Maison Dewey', '(02) 201 24 68'),
#  ('Mère Paillarde', '(514) 555-8055'),
#  ('Morgenstern Gesundkost', 'Non affecté'),
#  ('North/South', '(71) 555-2530'),
#  ('Océano Atlántico Ltda.', '(1) 135-5535'),
#  ('Old World Delicatessen', '(907) 555-2880'),
#  ('Ottilies Käseladen', '0221-0765721'),
#  ('Paris spécialités', '01.42.34.22.77'),
#  ('Pericles Comidas clásicas', '(5) 545-3745'),
#  ('Piccolo und mehr', '6562-9723'),
#  ('Princesa Isabel Vinhos', 'Non affecté'),
#  ('Que Delícia', '(21) 555-4545'),
#  ('Queen Cozinha', 'Non affecté'),
#  ('QUICK-Stop', 'Non affecté'),
#  ('Rancho grande', '(1) 123-5556'),
#  ('Rattlesnake Canyon Grocery', '(505) 555-3620'),
#  ('Reggiani Caseifici', '0522-556722'),
#  ('Ricardo Adocicados', 'Non affecté'),
#  ('Richter Supermarkt', 'Non affecté'),
#  ('Romero y tomillo', '(91) 745 6210'),
#  ('Santé Gourmet', '07-98 92 47'),
#  ('Save-a-lot Markets', 'Non affecté'),
#  ('Seven Seas Imports', '(71) 555-5646'),
#  ('Simons bistro', '31 13 35 57'),
#  ('Spécialités du monde', '01.47.55.60.20'),
#  ('Split Rail Beer  Ale', '(307) 555-6525'),
#  ('Suprêmes délices', '(071) 23 67 22 21'),
#  ('The Big Cheese', 'Non affecté'),
#  ('The Cracker Box', '(406) 555-8083'),
#  ('Toms Spezialitäten', '0251-035695'),
#  ('Tortuga Restaurante', 'Non affecté'),
#  ('Tradição Hipermercados', '(11) 555-2168'),
#  ("Trail's Head Gourmet Provisioners", '(206) 555-2174'),
#  ('Vaffeljernet', '86 22 33 44'),
#  ('Victuailles en stock', '04.78.32.54.87'),
#  ('Vins et alcools Chevalier', '03.26.47.15.11'),
#  ('Die Wandernde Kuh', '0711-035428'),
#  ('Wartian Herkku', '981-443655'),
#  ('Wellington Importadora', 'Non affecté'),
#  ('White Clover Markets', '(206) 555-4115'),
#  ('Wilman Kala', '90-224 8858'),
#  ('Wolski  Zajazd', '(26) 642-7012'),
#  ('Alfreds Futterkiste', '030-0076545'),
#  ('Ana Trujillo Emparedados y helados', '(5) 555-3745'),
#  ('Antonio Moreno Taquería', 'Non affecté'),
#  ('Around the Horn', '(71) 555-6750'),
#  ('Berglunds snabbköp', '0921-12 34 67'),
#  ('Blauer See Delikatessen', '0621-08924'),
#  ('Blondel père et fils', '03.88.60.15.32'),
#  ('Bólido Comidas preparadas', '(91) 555 91 99'),
#  ("Bon app'", '04.91.24.45.41'),
#  ('Bottom-Dollar Markets', '(604) 555-3745'),
#  ("B's Beverages", 'Non affecté'),
#  ('Cactus Comidas para llevar', '(1) 135-4892'),
#  ('Centro comercial Moctezuma', '(5) 555-7293'),
#  ('Chop-suey Chinese', 'Non affecté'),
#  ('Comércio Mineiro', 'Non affecté')]

# %% [markdown]
# # Tri du résultat d'une requête
#
# >> **SELECT [ALL | DISTINCT]{*,[EXPRESSION1 [AS] ALIAS1[,...]}<br>
# >> FROM NOM_TABLE<br>
# >> ORDER BY <br>
# >> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[NOM_COLONNE1|ALIAS1|POSITION1|EXPRESSION1][ASC|DESC] [NULLS {FIRST|LAST}],<br>
# >> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[NOM_COLONNE2|ALIAS2|POSITION2|EXPRESSION2][ASC|DESC] [NULLS {FIRST|LAST}]**<br>

# %%
# %%sql
# SELECT NOM,
#        PRENOM,
#        FONCTION
# FROM EMPLOYES ORDER BY NOM
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 111 rows affected.
# [('Alvarez', 'Marcel', 'Représentant(e)'),
#  ('Arrambide', 'Jean Pierre', 'Représentant(e)'),
#  ('Aubert', 'Maria', 'Représentant(e)'),
#  ('Aubry', 'Jean-Claude', 'Représentant(e)'),
#  ('Barre', 'Jean-Paul', 'Représentant(e)'),
#  ('Bazart', 'Régis', 'Représentant(e)'),
#  ('Belin', 'Chantal', 'Chef des ventes'),
#  ('Berlioz', 'Jacques', 'Représentant(e)'),
#  ('Besse', 'José', 'Représentant(e)'),
#  ('Bettan', 'Henri-Michel', 'Représentant(e)'),
#  ('Blard', 'Jean-Benoît', 'Représentant(e)'),
#  ('Bodard', 'René', 'Représentant(e)'),
#  ('Brasseur', 'Hervé', 'Vice-Président'),
#  ('Brunet', 'Jean-Luc', 'Représentant(e)'),
#  ('Buchanan', 'Steven', 'Chef des ventes'),
#  ('Burst', 'Jean-Yves', 'Représentant(e)'),
#  ('Callahan', 'Laura', 'Assistante commerciale'),
#  ('Canu', 'Christian', 'Représentant(e)'),
#  ('Capharsie', 'Gérard', 'Représentant(e)'),
#  ('Cazade', 'Anne-Claire', 'Représentant(e)'),
#  ('Chambaud', 'Axelle', 'Chef des ventes'),
#  ('Charles', 'Philippe', 'Représentant(e)'),
#  ('Chaussende', 'Maurice', 'Représentant(e)'),
#  ('Cheutin', 'Corinne', 'Représentant(e)'),
#  ('Clement', 'Valérie', 'Représentant(e)'),
#  ('Cleret', 'Doris', 'Représentant(e)'),
#  ('Courty', 'Jean-Louis', 'Représentant(e)'),
#  ('Coutou', 'Myriam', 'Représentant(e)'),
#  ('Cremel', 'Brigitte', 'Représentant(e)'),
#  ('Damas', 'Lydiane', 'Représentant(e)'),
#  ('Davolio', 'Nancy', 'Représentant(e)'),
#  ('Delorgue', 'Jean', 'Représentant(e)'),
#  ('Destenay', 'Agnès', 'Représentant(e)'),
#  ('Devie', 'Thérèse', 'Assistante commerciale'),
#  ('Di Clemente', 'Luc', 'Représentant(e)'),
#  ('Dodsworth', 'Anne', 'Représentant(e)'),
#  ('Dohr', 'Sylvie', 'Représentant(e)'),
#  ('Dupouey', 'Pierre', 'Représentant(e)'),
#  ('Duriez', 'Maurice', 'Représentant(e)'),
#  ('Espeche', 'Eric', 'Représentant(e)'),
#  ('Etienne', 'Brigitte', 'Assistante commerciale'),
#  ('Falatik', 'Bernard', 'Représentant(e)'),
#  ('Frederic', 'Jean Marie', 'Représentant(e)'),
#  ('Fuller', 'Andrew', 'Vice-Président'),
#  ('Gardeil', 'Henri', 'Représentant(e)'),
#  ('Gerard', 'Sylvie', 'Représentant(e)'),
#  ('Giroux', 'Jean-Claude', 'Président'),
#  ('Grangirard', 'Patricia', 'Assistante commerciale'),
#  ('Gregoire', 'Renée', 'Représentant(e)'),
#  ('Griner', 'Florence', 'Représentant(e)'),
#  ('Guerdon', 'Béatrice', 'Assistante commerciale'),
#  ('Guillossou', 'Nadine', 'Représentant(e)'),
#  ('Hanriot', 'Catherine', 'Représentant(e)'),
#  ('Herve', 'Didier', 'Représentant(e)'),
#  ('Idesheim', 'Annick', 'Représentant(e)'),
#  ('Jacquot', 'Philippe', 'Représentant(e)'),
#  ('Jeandel', 'Véronique', 'Représentant(e)'),
#  ('Jenny', 'Michel', 'Représentant(e)'),
#  ('Kessler', 'Marc', 'Représentant(e)'),
#  ('King', 'Robert', 'Représentant(e)'),
#  ('Kremser', 'Arnaud', 'Représentant(e)'),
#  ('Lamarre', 'Eric', 'Représentant(e)'),
#  ('Lampis', 'Gabrielle', 'Assistante commerciale'),
#  ('Lefebvre', 'Michel', 'Représentant(e)'),
#  ('Leger', 'Pierre', 'Chef des ventes'),
#  ('Letertre', 'Sylvie', 'Représentant(e)'),
#  ('Leverling', 'Janet', 'Représentant(e)'),
#  ('Lombard', 'Christiane', 'Représentant(e)'),
#  ('Maillard', 'Corinne', 'Représentant(e)'),
#  ('Malejac', 'Yannick', 'Représentant(e)'),
#  ('Mangeard', 'Jocelyne', 'Représentant(e)'),
#  ('Marchand', 'Dominique', 'Représentant(e)'),
#  ('Marielle', 'Michel', 'Représentant(e)'),
#  ('Maurer', 'Véronique', 'Assistante commerciale'),
#  ('Maurousset', 'James', 'Représentant(e)'),
#  ('Mennetrier', 'Alexandra', 'Représentant(e)'),
#  ('Messelier', 'Philippe', 'Représentant(e)'),
#  ('Michiels', 'François', 'Représentant(e)'),
#  ('Montesinos', 'Aline', 'Représentant(e)'),
#  ('Mure', 'Guy', 'Représentant(e)'),
#  ('Nocella', 'Guy', 'Représentant(e)'),
#  ('Pagani', 'Hector', 'Représentant(e)'),
#  ('Peacock', 'Margaret', 'Représentant(e)'),
#  ('Pequignot', 'Guy', 'Représentant(e)'),
#  ('Perny', 'Sylvie', 'Représentant(e)'),
#  ('Perret', 'Laurence', 'Représentant(e)'),
#  ('Petit', 'Michel', 'Représentant(e)'),
#  ('Piroddi', 'Nathalie', 'Représentant(e)'),
#  ('Poidatz', 'Benoît', 'Représentant(e)'),
#  ('Pouetre', 'Camille-Hélène', 'Assistante commerciale'),
#  ('Poupard', 'Claudette', 'Assistante commerciale'),
#  ('Ragon', 'André', 'Chef des ventes'),
#  ('Regner', 'Charles', 'Représentant(e)'),
#  ('Rivat', 'Jean-Louis', 'Représentant(e)'),
#  ('Rollet', 'Philippe', 'Représentant(e)'),
#  ('Seigne', 'Marie-Pierre', 'Représentant(e)'),
#  ('Silberreiss', 'Albert', 'Représentant(e)'),
#  ('Splingart', 'Lydia', 'Chef des ventes'),
#  ('Steiner', 'Jean', 'Représentant(e)'),
#  ('Suyama', 'Michael', 'Représentant(e)'),
#  ('Teixeira', 'Claudia', 'Représentant(e)'),
#  ('Thimoleon', 'Georges', 'Représentant(e)'),
#  ('Thomas', 'Patricia', 'Représentant(e)'),
#  ('Tourtel', 'Nicole', 'Représentant(e)'),
#  ('Twardowski', 'Colette', 'Représentant(e)'),
#  ('Urbaniak', 'Isabelle', 'Représentant(e)'),
#  ('Valot', 'Alain', 'Représentant(e)'),
#  ('Viry', 'Yvan', 'Représentant(e)'),
#  ('Weiss', 'Sylvie', 'Représentant(e)'),
#  ('Ziliox', 'Francoise', 'Assistante commerciale'),
#  ('Zonca', 'Virginie', 'Représentant(e)')]

# %%
# %%sql
# SELECT NOM||' '||PRENOM "Employé", FONCTION
# FROM EMPLOYES
# ORDER BY "Employé" ASC
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 111 rows affected.
# [('Alvarez Marcel', 'Représentant(e)'),
#  ('Arrambide Jean Pierre', 'Représentant(e)'),
#  ('Aubert Maria', 'Représentant(e)'),
#  ('Aubry Jean-Claude', 'Représentant(e)'),
#  ('Barre Jean-Paul', 'Représentant(e)'),
#  ('Bazart Régis', 'Représentant(e)'),
#  ('Belin Chantal', 'Chef des ventes'),
#  ('Berlioz Jacques', 'Représentant(e)'),
#  ('Besse José', 'Représentant(e)'),
#  ('Bettan Henri-Michel', 'Représentant(e)'),
#  ('Blard Jean-Benoît', 'Représentant(e)'),
#  ('Bodard René', 'Représentant(e)'),
#  ('Brasseur Hervé', 'Vice-Président'),
#  ('Brunet Jean-Luc', 'Représentant(e)'),
#  ('Buchanan Steven', 'Chef des ventes'),
#  ('Burst Jean-Yves', 'Représentant(e)'),
#  ('Callahan Laura', 'Assistante commerciale'),
#  ('Canu Christian', 'Représentant(e)'),
#  ('Capharsie Gérard', 'Représentant(e)'),
#  ('Cazade Anne-Claire', 'Représentant(e)'),
#  ('Chambaud Axelle', 'Chef des ventes'),
#  ('Charles Philippe', 'Représentant(e)'),
#  ('Chaussende Maurice', 'Représentant(e)'),
#  ('Cheutin Corinne', 'Représentant(e)'),
#  ('Clement Valérie', 'Représentant(e)'),
#  ('Cleret Doris', 'Représentant(e)'),
#  ('Courty Jean-Louis', 'Représentant(e)'),
#  ('Coutou Myriam', 'Représentant(e)'),
#  ('Cremel Brigitte', 'Représentant(e)'),
#  ('Damas Lydiane', 'Représentant(e)'),
#  ('Davolio Nancy', 'Représentant(e)'),
#  ('Delorgue Jean', 'Représentant(e)'),
#  ('Destenay Agnès', 'Représentant(e)'),
#  ('Devie Thérèse', 'Assistante commerciale'),
#  ('Di Clemente Luc', 'Représentant(e)'),
#  ('Dodsworth Anne', 'Représentant(e)'),
#  ('Dohr Sylvie', 'Représentant(e)'),
#  ('Dupouey Pierre', 'Représentant(e)'),
#  ('Duriez Maurice', 'Représentant(e)'),
#  ('Espeche Eric', 'Représentant(e)'),
#  ('Etienne Brigitte', 'Assistante commerciale'),
#  ('Falatik Bernard', 'Représentant(e)'),
#  ('Frederic Jean Marie', 'Représentant(e)'),
#  ('Fuller Andrew', 'Vice-Président'),
#  ('Gardeil Henri', 'Représentant(e)'),
#  ('Gerard Sylvie', 'Représentant(e)'),
#  ('Giroux Jean-Claude', 'Président'),
#  ('Grangirard Patricia', 'Assistante commerciale'),
#  ('Gregoire Renée', 'Représentant(e)'),
#  ('Griner Florence', 'Représentant(e)'),
#  ('Guerdon Béatrice', 'Assistante commerciale'),
#  ('Guillossou Nadine', 'Représentant(e)'),
#  ('Hanriot Catherine', 'Représentant(e)'),
#  ('Herve Didier', 'Représentant(e)'),
#  ('Idesheim Annick', 'Représentant(e)'),
#  ('Jacquot Philippe', 'Représentant(e)'),
#  ('Jeandel Véronique', 'Représentant(e)'),
#  ('Jenny Michel', 'Représentant(e)'),
#  ('Kessler Marc', 'Représentant(e)'),
#  ('King Robert', 'Représentant(e)'),
#  ('Kremser Arnaud', 'Représentant(e)'),
#  ('Lamarre Eric', 'Représentant(e)'),
#  ('Lampis Gabrielle', 'Assistante commerciale'),
#  ('Lefebvre Michel', 'Représentant(e)'),
#  ('Leger Pierre', 'Chef des ventes'),
#  ('Letertre Sylvie', 'Représentant(e)'),
#  ('Leverling Janet', 'Représentant(e)'),
#  ('Lombard Christiane', 'Représentant(e)'),
#  ('Maillard Corinne', 'Représentant(e)'),
#  ('Malejac Yannick', 'Représentant(e)'),
#  ('Mangeard Jocelyne', 'Représentant(e)'),
#  ('Marchand Dominique', 'Représentant(e)'),
#  ('Marielle Michel', 'Représentant(e)'),
#  ('Maurer Véronique', 'Assistante commerciale'),
#  ('Maurousset James', 'Représentant(e)'),
#  ('Mennetrier Alexandra', 'Représentant(e)'),
#  ('Messelier Philippe', 'Représentant(e)'),
#  ('Michiels François', 'Représentant(e)'),
#  ('Montesinos Aline', 'Représentant(e)'),
#  ('Mure Guy', 'Représentant(e)'),
#  ('Nocella Guy', 'Représentant(e)'),
#  ('Pagani Hector', 'Représentant(e)'),
#  ('Peacock Margaret', 'Représentant(e)'),
#  ('Pequignot Guy', 'Représentant(e)'),
#  ('Perny Sylvie', 'Représentant(e)'),
#  ('Perret Laurence', 'Représentant(e)'),
#  ('Petit Michel', 'Représentant(e)'),
#  ('Piroddi Nathalie', 'Représentant(e)'),
#  ('Poidatz Benoît', 'Représentant(e)'),
#  ('Pouetre Camille-Hélène', 'Assistante commerciale'),
#  ('Poupard Claudette', 'Assistante commerciale'),
#  ('Ragon André', 'Chef des ventes'),
#  ('Regner Charles', 'Représentant(e)'),
#  ('Rivat Jean-Louis', 'Représentant(e)'),
#  ('Rollet Philippe', 'Représentant(e)'),
#  ('Seigne Marie-Pierre', 'Représentant(e)'),
#  ('Silberreiss Albert', 'Représentant(e)'),
#  ('Splingart Lydia', 'Chef des ventes'),
#  ('Steiner Jean', 'Représentant(e)'),
#  ('Suyama Michael', 'Représentant(e)'),
#  ('Teixeira Claudia', 'Représentant(e)'),
#  ('Thimoleon Georges', 'Représentant(e)'),
#  ('Thomas Patricia', 'Représentant(e)'),
#  ('Tourtel Nicole', 'Représentant(e)'),
#  ('Twardowski Colette', 'Représentant(e)'),
#  ('Urbaniak Isabelle', 'Représentant(e)'),
#  ('Valot Alain', 'Représentant(e)'),
#  ('Viry Yvan', 'Représentant(e)'),
#  ('Weiss Sylvie', 'Représentant(e)'),
#  ('Ziliox Francoise', 'Assistante commerciale'),
#  ('Zonca Virginie', 'Représentant(e)')]

# %% [markdown]
# Le tri se fait d'abord selon le premier critère spécifié dans la clause « **ORDER BY** », puis les lignes ayant la même valeur pour le premier critère sont triées selon le deuxième critère de la clause « **ORDER BY** », etc.

# %%
# %%sql
# SELECT NOM_PRODUIT, NO_FOURNISSEUR, CODE_CATEGORIE
# FROM PRODUITS
# ORDER BY NO_FOURNISSEUR, CODE_CATEGORIE DESC
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 120 rows affected.
# [('Aniseed Syrup', Decimal('1'), Decimal('2')),
#  ('Chai', Decimal('1'), Decimal('1')),
#  ('Chang', Decimal('1'), Decimal('1')),
#  ('Cherry Pie Filling', Decimal('2'), Decimal('9')),
#  ('Amandes', Decimal('2'), Decimal('7')),
#  ('Brownie Mix', Decimal('2'), Decimal('3')),
#  ('Louisiana Fiery Hot Pepper Sauce', Decimal('2'), Decimal('2')),
#  ('Louisiana Hot Spiced Okra', Decimal('2'), Decimal('2')),
#  ("Chef Anton's Gumbo Mix", Decimal('2'), Decimal('2')),
#  ("Chef Anton's Cajun Seasoning", Decimal('2'), Decimal('2')),
#  ("Uncle Bob's Organic Dried Pears", Decimal('3'), Decimal('7')),
#  ('Northwoods Cranberry Sauce', Decimal('3'), Decimal('2')),
#  ("Grandma's Boysenberry Spread", Decimal('3'), Decimal('2')),
#  ('Corn', Decimal('4'), Decimal('9')),
#  ('Ikura', Decimal('4'), Decimal('8')),
#  ('Longlife Tofu', Decimal('4'), Decimal('7')),
#  ('Long Grain Rice', Decimal('4'), Decimal('7')),
#  ('Mishi Kobe Niku', Decimal('4'), Decimal('6')),
#  ('Scones', Decimal('4'), Decimal('3')),
#  ('Mustard', Decimal('4'), Decimal('2')),
#  ('Green Beans', Decimal('5'), Decimal('9')),
#  ('Peas', Decimal('5'), Decimal('9')),
#  ('Walnuts', Decimal('5'), Decimal('7')),
#  ('Queso Cabrales', Decimal('5'), Decimal('4')),
#  ('Queso Manchego La Pastora', Decimal('5'), Decimal('4')),
#  ('Peaches', Decimal('6'), Decimal('9')),
#  ('Konbu', Decimal('6'), Decimal('8')),
#  ('Tofu', Decimal('6'), Decimal('7')),
#  ('Long Grain Rice - Gnocchi', Decimal('6'), Decimal('5')),
#  ('Les Comptoirs  - Olive Oil', Decimal('6'), Decimal('2')),
#  ('Genen Shouyu', Decimal('6'), Decimal('2')),
#  ('Carnarvon Tigers', Decimal('7'), Decimal('8')),
#  ('Alice Mutton', Decimal('7'), Decimal('6')),
#  ('Chocolate Biscuits Mix', Decimal('7'), Decimal('3')),
#  ('Pavlova', Decimal('7'), Decimal('3')),
#  ('Vegie-spread', Decimal('7'), Decimal('2')),
#  ('Outback Lager', Decimal('7'), Decimal('1')),
#  ('Dried Plums', Decimal('8'), Decimal('7')),
#  ("Sir Rodney's Marmalade", Decimal('8'), Decimal('3')),
#  ('Teatime Chocolate Biscuits', Decimal('8'), Decimal('3')),
#  ("Sir Rodney's Scones", Decimal('8'), Decimal('3')),
#  ('Scottish Longbreads', Decimal('8'), Decimal('3')),
#  ('Tunnbröd', Decimal('9'), Decimal('5')),
#  ("Gustaf's Knäckebröd", Decimal('9'), Decimal('5')),
#  ('Guaraná Fantástica', Decimal('10'), Decimal('1')),
#  ('Granola', Decimal('11'), Decimal('5')),
#  ('Gumbär Gummibärchen', Decimal('11'), Decimal('3')),
#  ('NuNuCa Nuß-Nougat-Creme', Decimal('11'), Decimal('3')),
#  ('Schoggi Schokolade', Decimal('11'), Decimal('3')),
#  ('Rössle Sauerkraut', Decimal('12'), Decimal('7')),
#  ('Thüringer Rostbratwurst', Decimal('12'), Decimal('6')),
#  ('Wimmers gute Semmelknödel', Decimal('12'), Decimal('5')),
#  ('Original Frankfurter grüne Soße', Decimal('12'), Decimal('2')),
#  ('Rhönbräu Klosterbier', Decimal('12'), Decimal('1')),
#  ('Fruit Cocktail', Decimal('13'), Decimal('9')),
#  ('Nord-Ost Matjeshering', Decimal('13'), Decimal('8')),
#  ('Vegetable Soup', Decimal('13'), Decimal('2')),
#  ('Smoked Salmon', Decimal('14'), Decimal('10')),
#  ('Ravioli', Decimal('14'), Decimal('5')),
#  ('Mozzarella di Giovanni', Decimal('14'), Decimal('4')),
#  ('Gorgonzola Telino', Decimal('14'), Decimal('4')),
#  ('Mascarpone Fabioli', Decimal('14'), Decimal('4')),
#  ('Hot Pepper Sauce', Decimal('14'), Decimal('2')),
#  ('Clam Chowder', Decimal('14'), Decimal('2')),
#  ('Green Tea', Decimal('14'), Decimal('1')),
#  ('Tea', Decimal('14'), Decimal('1')),
#  ('Gudbrandsdalsost', Decimal('15'), Decimal('4')),
#  ('Fløtemysost', Decimal('15'), Decimal('4')),
#  ('Geitost', Decimal('15'), Decimal('4')),
#  ('Tomato Sauce', Decimal('16'), Decimal('2')),
#  ('Chicken Soup', Decimal('16'), Decimal('2')),
#  ('Coffee', Decimal('16'), Decimal('1')),
#  ('Sasquatch Ale', Decimal('16'), Decimal('1')),
#  ('Steeleye Stout', Decimal('16'), Decimal('1')),
#  ('Laughing Lumberjack Lager', Decimal('16'), Decimal('1')),
#  ('Röd Kaviar', Decimal('17'), Decimal('8')),
#  ('Inlagd Sill', Decimal('17'), Decimal('8')),
#  ('Gravad lax', Decimal('17'), Decimal('8')),
#  ('Syrup', Decimal('17'), Decimal('2')),
#  ('Hot Cereal', Decimal('18'), Decimal('5')),
#  ('Mozzarella', Decimal('18'), Decimal('4')),
#  ('Beer', Decimal('18'), Decimal('1')),
#  ('Chartreuse verte', Decimal('18'), Decimal('1')),
#  ('Côte de Blaye', Decimal('18'), Decimal('1')),
#  ('Crab Meat', Decimal('19'), Decimal('10')),
#  ("Jack's New England Clam Chowder", Decimal('19'), Decimal('8')),
#  ('Boston Crab Meat', Decimal('19'), Decimal('8')),
#  ('Singaporean Hokkien Fried Mee', Decimal('20'), Decimal('5')),
#  ('Cake Mix', Decimal('20'), Decimal('3')),
#  ('Gula Malacca', Decimal('20'), Decimal('2')),
#  ('Ipoh Coffee', Decimal('20'), Decimal('1')),
#  ('Røgede sild', Decimal('21'), Decimal('8')),
#  ('Spegesild', Decimal('21'), Decimal('8')),
#  ('Dried Apples', Decimal('21'), Decimal('7')),
#  ('Dried Pears', Decimal('21'), Decimal('7')),
#  ('Chocolade', Decimal('22'), Decimal('3')),
#  ('Zaanse koeken', Decimal('22'), Decimal('3')),
#  ('Potato Chips', Decimal('23'), Decimal('7')),
#  ('Valkoinen suklaa', Decimal('23'), Decimal('3')),
#  ('Maxilaku', Decimal('23'), Decimal('3')),
#  ('Lakkalikööri', Decimal('23'), Decimal('1')),
#  ('Marmalade', Decimal('24'), Decimal('9')),
#  ('Manjimup Dried Apples', Decimal('24'), Decimal('7')),
#  ('Perth Pasties', Decimal('24'), Decimal('6')),
#  ('Filo Mix', Decimal('24'), Decimal('5')),
#  ('Pears', Decimal('25'), Decimal('9')),
#  ('Tourtière', Decimal('25'), Decimal('6')),
#  ('Pâté chinois', Decimal('25'), Decimal('6')),
#  ('Boysenberry Spread', Decimal('26'), Decimal('9')),
#  ('Ravioli Angelo', Decimal('26'), Decimal('5')),
#  ('Gnocchi di nonna Alice', Decimal('26'), Decimal('5')),
#  ('Curry Sauce', Decimal('26'), Decimal('2')),
#  ('Tuna Fish', Decimal('27'), Decimal('10')),
#  ('Pineapple', Decimal('27'), Decimal('9')),
#  ('Escargots de Bourgogne', Decimal('27'), Decimal('8')),
#  ('Cajun Seasoning', Decimal('27'), Decimal('2')),
#  ('Raclette Courdavault', Decimal('28'), Decimal('4')),
#  ('Camembert Pierrot', Decimal('28'), Decimal('4')),
#  ('Tarte au sucre', Decimal('29'), Decimal('3')),
#  ("Sirop d'érable", Decimal('29'), Decimal('2'))]

# %% [markdown]
# Si un attribut sur lequel porte un critère de tri contient la valeur « **NULL** », les lignes correspondantes sont affichées en dernier. Oracle traite les valeurs « **NULL** » comme si elles étaient des valeurs infinies.

# %%
# %%sql
# SELECT NOM,PRENOM,SALAIRE,COMMISSION
# FROM EMPLOYES
# ORDER BY COMMISSION
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 111 rows affected.
# [('Petit', 'Michel', Decimal('6300.00'), Decimal('20.00')),
#  ('Gregoire', 'Renée', Decimal('8000.00'), Decimal('30.00')),
#  ('Michiels', 'François', Decimal('5500.00'), Decimal('40.00')),
#  ('Dupouey', 'Pierre', Decimal('5500.00'), Decimal('40.00')),
#  ('Jenny', 'Michel', Decimal('9800.00'), Decimal('150.00')),
#  ('Piroddi', 'Nathalie', Decimal('6700.00'), Decimal('190.00')),
#  ('Arrambide', 'Jean Pierre', Decimal('5400.00'), Decimal('190.00')),
#  ('Mangeard', 'Jocelyne', Decimal('8200.00'), Decimal('190.00')),
#  ('Dohr', 'Sylvie', Decimal('8200.00'), Decimal('200.00')),
#  ('Lamarre', 'Eric', Decimal('7800.00'), Decimal('200.00')),
#  ('Poidatz', 'Benoît', Decimal('6600.00'), Decimal('200.00')),
#  ('Leverling', 'Janet', Decimal('7400.00'), Decimal('240.00')),
#  ('Rivat', 'Jean-Louis', Decimal('5200.00'), Decimal('310.00')),
#  ('Teixeira', 'Claudia', Decimal('6800.00'), Decimal('330.00')),
#  ('Blard', 'Jean-Benoît', Decimal('5900.00'), Decimal('340.00')),
#  ('Perny', 'Sylvie', Decimal('6500.00'), Decimal('340.00')),
#  ('Suyama', 'Michael', Decimal('8400.00'), Decimal('400.00')),
#  ('Capharsie', 'Gérard', Decimal('9400.00'), Decimal('410.00')),
#  ('Duriez', 'Maurice', Decimal('9100.00'), Decimal('420.00')),
#  ('Guillossou', 'Nadine', Decimal('5200.00'), Decimal('470.00')),
#  ('Zonca', 'Virginie', Decimal('6700.00'), Decimal('470.00')),
#  ('Dodsworth', 'Anne', Decimal('8800.00'), Decimal('490.00')),
#  ('Delorgue', 'Jean', Decimal('5900.00'), Decimal('510.00')),
#  ('Perret', 'Laurence', Decimal('9500.00'), Decimal('520.00')),
#  ('Lefebvre', 'Michel', Decimal('9200.00'), Decimal('530.00')),
#  ('Damas', 'Lydiane', Decimal('7700.00'), Decimal('530.00')),
#  ('Canu', 'Christian', Decimal('5800.00'), Decimal('550.00')),
#  ('Cazade', 'Anne-Claire', Decimal('7200.00'), Decimal('550.00')),
#  ('Rollet', 'Philippe', Decimal('5000.00'), Decimal('570.00')),
#  ('Cheutin', 'Corinne', Decimal('10000.00'), Decimal('570.00')),
#  ('Idesheim', 'Annick', Decimal('7300.00'), Decimal('600.00')),
#  ('Valot', 'Alain', Decimal('9200.00'), Decimal('680.00')),
#  ('Bettan', 'Henri-Michel', Decimal('5500.00'), Decimal('690.00')),
#  ('Cleret', 'Doris', Decimal('7900.00'), Decimal('720.00')),
#  ('Bodard', 'René', Decimal('5500.00'), Decimal('720.00')),
#  ('Viry', 'Yvan', Decimal('6700.00'), Decimal('740.00')),
#  ('Aubert', 'Maria', Decimal('5100.00'), Decimal('750.00')),
#  ('Bazart', 'Régis', Decimal('8900.00'), Decimal('760.00')),
#  ('Coutou', 'Myriam', Decimal('6900.00'), Decimal('770.00')),
#  ('Destenay', 'Agnès', Decimal('9900.00'), Decimal('790.00')),
#  ('Cremel', 'Brigitte', Decimal('6900.00'), Decimal('910.00')),
#  ('Nocella', 'Guy', Decimal('7600.00'), Decimal('910.00')),
#  ('Di Clemente', 'Luc', Decimal('8400.00'), Decimal('920.00')),
#  ('Peacock', 'Margaret', Decimal('6100.00'), Decimal('930.00')),
#  ('Besse', 'José', Decimal('9900.00'), Decimal('940.00')),
#  ('Griner', 'Florence', Decimal('8100.00'), Decimal('980.00')),
#  ('Berlioz', 'Jacques', Decimal('9400.00'), Decimal('980.00')),
#  ('Alvarez', 'Marcel', Decimal('7200.00'), Decimal('1010.00')),
#  ('Jacquot', 'Philippe', Decimal('8900.00'), Decimal('1030.00')),
#  ('King', 'Robert', Decimal('7200.00'), Decimal('1040.00')),
#  ('Charles', 'Philippe', Decimal('6000.00'), Decimal('1080.00')),
#  ('Silberreiss', 'Albert', Decimal('9200.00'), Decimal('1100.00')),
#  ('Falatik', 'Bernard', Decimal('7600.00'), Decimal('1100.00')),
#  ('Weiss', 'Sylvie', Decimal('6600.00'), Decimal('1110.00')),
#  ('Malejac', 'Yannick', Decimal('8700.00'), Decimal('1130.00')),
#  ('Montesinos', 'Aline', Decimal('8700.00'), Decimal('1130.00')),
#  ('Mure', 'Guy', Decimal('8200.00'), Decimal('1140.00')),
#  ('Jeandel', 'Véronique', Decimal('9200.00'), Decimal('1150.00')),
#  ('Seigne', 'Marie-Pierre', Decimal('9600.00'), Decimal('1160.00')),
#  ('Herve', 'Didier', Decimal('6700.00'), Decimal('1170.00')),
#  ('Barre', 'Jean-Paul', Decimal('8800.00'), Decimal('1220.00')),
#  ('Thimoleon', 'Georges', Decimal('8000.00'), Decimal('1270.00')),
#  ('Marchand', 'Dominique', Decimal('6900.00'), Decimal('1280.00')),
#  ('Maillard', 'Corinne', Decimal('6600.00'), Decimal('1300.00')),
#  ('Steiner', 'Jean', Decimal('5400.00'), Decimal('1310.00')),
#  ('Thomas', 'Patricia', Decimal('7100.00'), Decimal('1310.00')),
#  ('Pagani', 'Hector', Decimal('6500.00'), Decimal('1330.00')),
#  ('Lombard', 'Christiane', Decimal('6400.00'), Decimal('1350.00')),
#  ('Clement', 'Valérie', Decimal('7200.00'), Decimal('1370.00')),
#  ('Regner', 'Charles', Decimal('9300.00'), Decimal('1380.00')),
#  ('Brunet', 'Jean-Luc', Decimal('6600.00'), Decimal('1400.00')),
#  ('Messelier', 'Philippe', Decimal('9500.00'), Decimal('1470.00')),
#  ('Gardeil', 'Henri', Decimal('7800.00'), Decimal('1520.00')),
#  ('Chaussende', 'Maurice', Decimal('6600.00'), Decimal('1530.00')),
#  ('Twardowski', 'Colette', Decimal('9400.00'), Decimal('1540.00')),
#  ('Marielle', 'Michel', Decimal('7100.00'), Decimal('1550.00')),
#  ('Maurousset', 'James', Decimal('8100.00'), Decimal('1560.00')),
#  ('Espeche', 'Eric', Decimal('6500.00'), Decimal('1580.00')),
#  ('Kremser', 'Arnaud', Decimal('6000.00'), Decimal('1610.00')),
#  ('Hanriot', 'Catherine', Decimal('8300.00'), Decimal('1700.00')),
#  ('Davolio', 'Nancy', Decimal('8200.00'), Decimal('1740.00')),
#  ('Urbaniak', 'Isabelle', Decimal('7000.00'), Decimal('1760.00')),
#  ('Kessler', 'Marc', Decimal('6800.00'), Decimal('1780.00')),
#  ('Gerard', 'Sylvie', Decimal('8200.00'), Decimal('1800.00')),
#  ('Courty', 'Jean-Louis', Decimal('9900.00'), Decimal('1800.00')),
#  ('Pequignot', 'Guy', Decimal('6200.00'), Decimal('1820.00')),
#  ('Aubry', 'Jean-Claude', Decimal('9500.00'), Decimal('1850.00')),
#  ('Frederic', 'Jean Marie', Decimal('8100.00'), Decimal('1870.00')),
#  ('Letertre', 'Sylvie', Decimal('5600.00'), Decimal('1890.00')),
#  ('Tourtel', 'Nicole', Decimal('8100.00'), Decimal('1920.00')),
#  ('Mennetrier', 'Alexandra', Decimal('8700.00'), Decimal('1970.00')),
#  ('Burst', 'Jean-Yves', Decimal('7700.00'), Decimal('1980.00')),
#  ('Ragon', 'André', Decimal('13000.00'), Decimal('5980.00')),
#  ('Belin', 'Chantal', Decimal('10000.00'), Decimal('10640.00')),
#  ('Leger', 'Pierre', Decimal('19000.00'), Decimal('11150.00')),
#  ('Chambaud', 'Axelle', Decimal('12000.00'), Decimal('11600.00')),
#  ('Buchanan', 'Steven', Decimal('13000.00'), Decimal('12940.00')),
#  ('Splingart', 'Lydia', Decimal('16000.00'), Decimal('16480.00')),
#  ('Fuller', 'Andrew', Decimal('96000.00'), None),
#  ('Devie', 'Thérèse', Decimal('1540.00'), None),
#  ('Grangirard', 'Patricia', Decimal('1700.00'), None),
#  ('Etienne', 'Brigitte', Decimal('2000.00'), None),
#  ('Giroux', 'Jean-Claude', Decimal('150000.00'), None),
#  ('Callahan', 'Laura', Decimal('1200.00'), None),
#  ('Pouetre', 'Camille-Hélène', Decimal('2000.00'), None),
#  ('Maurer', 'Véronique', Decimal('1400.00'), None),
#  ('Poupard', 'Claudette', Decimal('1800.00'), None),
#  ('Ziliox', 'Francoise', Decimal('1900.00'), None),
#  ('Lampis', 'Gabrielle', Decimal('1300.00'), None),
#  ('Brasseur', 'Hervé', Decimal('147000.00'), None),
#  ('Guerdon', 'Béatrice', Decimal('1700.00'), None)]

# %%
# %%sql
# SELECT NOM,PRENOM,SALAIRE,COMMISSION
# FROM EMPLOYES
# ORDER BY COMMISSION NULLS FIRST
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 111 rows affected.
# [('Maurer', 'Véronique', Decimal('1400.00'), None),
#  ('Fuller', 'Andrew', Decimal('96000.00'), None),
#  ('Brasseur', 'Hervé', Decimal('147000.00'), None),
#  ('Lampis', 'Gabrielle', Decimal('1300.00'), None),
#  ('Ziliox', 'Francoise', Decimal('1900.00'), None),
#  ('Pouetre', 'Camille-Hélène', Decimal('2000.00'), None),
#  ('Devie', 'Thérèse', Decimal('1540.00'), None),
#  ('Guerdon', 'Béatrice', Decimal('1700.00'), None),
#  ('Grangirard', 'Patricia', Decimal('1700.00'), None),
#  ('Callahan', 'Laura', Decimal('1200.00'), None),
#  ('Poupard', 'Claudette', Decimal('1800.00'), None),
#  ('Etienne', 'Brigitte', Decimal('2000.00'), None),
#  ('Giroux', 'Jean-Claude', Decimal('150000.00'), None),
#  ('Petit', 'Michel', Decimal('6300.00'), Decimal('20.00')),
#  ('Gregoire', 'Renée', Decimal('8000.00'), Decimal('30.00')),
#  ('Michiels', 'François', Decimal('5500.00'), Decimal('40.00')),
#  ('Dupouey', 'Pierre', Decimal('5500.00'), Decimal('40.00')),
#  ('Jenny', 'Michel', Decimal('9800.00'), Decimal('150.00')),
#  ('Mangeard', 'Jocelyne', Decimal('8200.00'), Decimal('190.00')),
#  ('Arrambide', 'Jean Pierre', Decimal('5400.00'), Decimal('190.00')),
#  ('Piroddi', 'Nathalie', Decimal('6700.00'), Decimal('190.00')),
#  ('Lamarre', 'Eric', Decimal('7800.00'), Decimal('200.00')),
#  ('Poidatz', 'Benoît', Decimal('6600.00'), Decimal('200.00')),
#  ('Dohr', 'Sylvie', Decimal('8200.00'), Decimal('200.00')),
#  ('Leverling', 'Janet', Decimal('7400.00'), Decimal('240.00')),
#  ('Rivat', 'Jean-Louis', Decimal('5200.00'), Decimal('310.00')),
#  ('Teixeira', 'Claudia', Decimal('6800.00'), Decimal('330.00')),
#  ('Perny', 'Sylvie', Decimal('6500.00'), Decimal('340.00')),
#  ('Blard', 'Jean-Benoît', Decimal('5900.00'), Decimal('340.00')),
#  ('Suyama', 'Michael', Decimal('8400.00'), Decimal('400.00')),
#  ('Capharsie', 'Gérard', Decimal('9400.00'), Decimal('410.00')),
#  ('Duriez', 'Maurice', Decimal('9100.00'), Decimal('420.00')),
#  ('Guillossou', 'Nadine', Decimal('5200.00'), Decimal('470.00')),
#  ('Zonca', 'Virginie', Decimal('6700.00'), Decimal('470.00')),
#  ('Dodsworth', 'Anne', Decimal('8800.00'), Decimal('490.00')),
#  ('Delorgue', 'Jean', Decimal('5900.00'), Decimal('510.00')),
#  ('Perret', 'Laurence', Decimal('9500.00'), Decimal('520.00')),
#  ('Damas', 'Lydiane', Decimal('7700.00'), Decimal('530.00')),
#  ('Lefebvre', 'Michel', Decimal('9200.00'), Decimal('530.00')),
#  ('Cazade', 'Anne-Claire', Decimal('7200.00'), Decimal('550.00')),
#  ('Canu', 'Christian', Decimal('5800.00'), Decimal('550.00')),
#  ('Cheutin', 'Corinne', Decimal('10000.00'), Decimal('570.00')),
#  ('Rollet', 'Philippe', Decimal('5000.00'), Decimal('570.00')),
#  ('Idesheim', 'Annick', Decimal('7300.00'), Decimal('600.00')),
#  ('Valot', 'Alain', Decimal('9200.00'), Decimal('680.00')),
#  ('Bettan', 'Henri-Michel', Decimal('5500.00'), Decimal('690.00')),
#  ('Bodard', 'René', Decimal('5500.00'), Decimal('720.00')),
#  ('Cleret', 'Doris', Decimal('7900.00'), Decimal('720.00')),
#  ('Viry', 'Yvan', Decimal('6700.00'), Decimal('740.00')),
#  ('Aubert', 'Maria', Decimal('5100.00'), Decimal('750.00')),
#  ('Bazart', 'Régis', Decimal('8900.00'), Decimal('760.00')),
#  ('Coutou', 'Myriam', Decimal('6900.00'), Decimal('770.00')),
#  ('Destenay', 'Agnès', Decimal('9900.00'), Decimal('790.00')),
#  ('Cremel', 'Brigitte', Decimal('6900.00'), Decimal('910.00')),
#  ('Nocella', 'Guy', Decimal('7600.00'), Decimal('910.00')),
#  ('Di Clemente', 'Luc', Decimal('8400.00'), Decimal('920.00')),
#  ('Peacock', 'Margaret', Decimal('6100.00'), Decimal('930.00')),
#  ('Besse', 'José', Decimal('9900.00'), Decimal('940.00')),
#  ('Griner', 'Florence', Decimal('8100.00'), Decimal('980.00')),
#  ('Berlioz', 'Jacques', Decimal('9400.00'), Decimal('980.00')),
#  ('Alvarez', 'Marcel', Decimal('7200.00'), Decimal('1010.00')),
#  ('Jacquot', 'Philippe', Decimal('8900.00'), Decimal('1030.00')),
#  ('King', 'Robert', Decimal('7200.00'), Decimal('1040.00')),
#  ('Charles', 'Philippe', Decimal('6000.00'), Decimal('1080.00')),
#  ('Silberreiss', 'Albert', Decimal('9200.00'), Decimal('1100.00')),
#  ('Falatik', 'Bernard', Decimal('7600.00'), Decimal('1100.00')),
#  ('Weiss', 'Sylvie', Decimal('6600.00'), Decimal('1110.00')),
#  ('Malejac', 'Yannick', Decimal('8700.00'), Decimal('1130.00')),
#  ('Montesinos', 'Aline', Decimal('8700.00'), Decimal('1130.00')),
#  ('Mure', 'Guy', Decimal('8200.00'), Decimal('1140.00')),
#  ('Jeandel', 'Véronique', Decimal('9200.00'), Decimal('1150.00')),
#  ('Seigne', 'Marie-Pierre', Decimal('9600.00'), Decimal('1160.00')),
#  ('Herve', 'Didier', Decimal('6700.00'), Decimal('1170.00')),
#  ('Barre', 'Jean-Paul', Decimal('8800.00'), Decimal('1220.00')),
#  ('Thimoleon', 'Georges', Decimal('8000.00'), Decimal('1270.00')),
#  ('Marchand', 'Dominique', Decimal('6900.00'), Decimal('1280.00')),
#  ('Maillard', 'Corinne', Decimal('6600.00'), Decimal('1300.00')),
#  ('Thomas', 'Patricia', Decimal('7100.00'), Decimal('1310.00')),
#  ('Steiner', 'Jean', Decimal('5400.00'), Decimal('1310.00')),
#  ('Pagani', 'Hector', Decimal('6500.00'), Decimal('1330.00')),
#  ('Lombard', 'Christiane', Decimal('6400.00'), Decimal('1350.00')),
#  ('Clement', 'Valérie', Decimal('7200.00'), Decimal('1370.00')),
#  ('Regner', 'Charles', Decimal('9300.00'), Decimal('1380.00')),
#  ('Brunet', 'Jean-Luc', Decimal('6600.00'), Decimal('1400.00')),
#  ('Messelier', 'Philippe', Decimal('9500.00'), Decimal('1470.00')),
#  ('Gardeil', 'Henri', Decimal('7800.00'), Decimal('1520.00')),
#  ('Chaussende', 'Maurice', Decimal('6600.00'), Decimal('1530.00')),
#  ('Twardowski', 'Colette', Decimal('9400.00'), Decimal('1540.00')),
#  ('Marielle', 'Michel', Decimal('7100.00'), Decimal('1550.00')),
#  ('Maurousset', 'James', Decimal('8100.00'), Decimal('1560.00')),
#  ('Espeche', 'Eric', Decimal('6500.00'), Decimal('1580.00')),
#  ('Kremser', 'Arnaud', Decimal('6000.00'), Decimal('1610.00')),
#  ('Hanriot', 'Catherine', Decimal('8300.00'), Decimal('1700.00')),
#  ('Davolio', 'Nancy', Decimal('8200.00'), Decimal('1740.00')),
#  ('Urbaniak', 'Isabelle', Decimal('7000.00'), Decimal('1760.00')),
#  ('Kessler', 'Marc', Decimal('6800.00'), Decimal('1780.00')),
#  ('Courty', 'Jean-Louis', Decimal('9900.00'), Decimal('1800.00')),
#  ('Gerard', 'Sylvie', Decimal('8200.00'), Decimal('1800.00')),
#  ('Pequignot', 'Guy', Decimal('6200.00'), Decimal('1820.00')),
#  ('Aubry', 'Jean-Claude', Decimal('9500.00'), Decimal('1850.00')),
#  ('Frederic', 'Jean Marie', Decimal('8100.00'), Decimal('1870.00')),
#  ('Letertre', 'Sylvie', Decimal('5600.00'), Decimal('1890.00')),
#  ('Tourtel', 'Nicole', Decimal('8100.00'), Decimal('1920.00')),
#  ('Mennetrier', 'Alexandra', Decimal('8700.00'), Decimal('1970.00')),
#  ('Burst', 'Jean-Yves', Decimal('7700.00'), Decimal('1980.00')),
#  ('Ragon', 'André', Decimal('13000.00'), Decimal('5980.00')),
#  ('Belin', 'Chantal', Decimal('10000.00'), Decimal('10640.00')),
#  ('Leger', 'Pierre', Decimal('19000.00'), Decimal('11150.00')),
#  ('Chambaud', 'Axelle', Decimal('12000.00'), Decimal('11600.00')),
#  ('Buchanan', 'Steven', Decimal('13000.00'), Decimal('12940.00')),
#  ('Splingart', 'Lydia', Decimal('16000.00'), Decimal('16480.00'))]

# %% [markdown]
# # La limitation d’enregistrements

# %%
# %%sql
# SELECT CODE_CATEGORIE,NOM_CATEGORIE
# FROM CATEGORIES  FETCH FIRST 3 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 3 rows affected.
# [(Decimal('1'), 'Boissons'),
#  (Decimal('2'), 'Condiments'),
#  (Decimal('3'), 'Desserts')]

# %%
# %%sql
# SELECT CODE_CATEGORIE,NOM_CATEGORIE
# FROM CATEGORIES  OFFSET 5 ROWS FETCH NEXT 3 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 3 rows affected.
# [(Decimal('6'), 'Viandes'),
#  (Decimal('7'), 'Produits secs'),
#  (Decimal('8'), 'Poissons et fruits de mer')]

# %%
# %%sql
# SELECT NOM_PRODUIT, UNITES_STOCK
# FROM PRODUITS
# ORDER BY UNITES_STOCK DESC NULLS LAST
# FETCH NEXT 5 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [('Potato Chips', Decimal('200')),
#  ('Rhönbräu Klosterbier', Decimal('125')),
#  ('Green Tea', Decimal('125')),
#  ('Boston Crab Meat', Decimal('123')),
#  ('Crab Meat', Decimal('120'))]

# %%
# %%sql
# SELECT NO_COMMANDE,REF_PRODUIT,QUANTITE,PRIX_UNITAIRE
# FROM DETAILS_COMMANDES FETCH NEXT 5 ROWS ONLY
# Out:
#  * postgresql://stagiaire:***@51.91.76.248:15432/cours
# 5 rows affected.
# [(Decimal('215576'), Decimal('112'), Decimal('166'), Decimal('37.80')),
#  (Decimal('215576'), Decimal('113'), Decimal('192'), Decimal('65.76')),
#  (Decimal('215576'), Decimal('78'), Decimal('101'), Decimal('47.16')),
#  (Decimal('215576'), Decimal('47'), Decimal('119'), Decimal('63.24')),
#  (Decimal('215576'), Decimal('62'), Decimal('128'), Decimal('94.56'))]

# %% [markdown]
# # Atelier 2.1	Interrogation des données
#
# <img src="https://raw.githubusercontent.com/rbizoi/IntelligenceEnDonneesDeSante/main/InterrogationSQL/images/612.png" width="800">

# %% [markdown]
# ## Projection
# Écrivez les requêtes vous permettant d’afficher :
# >> * Le nom, le prénom et la date de naissance de tous les employés de la société.<br>
# >> * Le nom de la société, la ville et le pays de tous les fournisseurs.<br>
# >> * La fonction de tous les employés.<br>
# >> * Toutes les fonctions des employés de l’entreprise, chaque fonction doit être affichée une seule fois.<br>
# >> * **La liste des localités dans lesquelles la société a au moins un client.**<br>
#
# ## Opérateurs
# Créez les requêtes vous permettant d’afficher :
# >> * Les produits commercialisés, la valeur du stock par produit et la valeur des produits commandés. Dans la table **PRODUITS**, vous trouvez les champs **UNITES_STOCK** et **UNITES_COMMANDEES** que vous multipliez par le **PRIX_UNITAIRE** pour retrouver les valeurs des deux stocks.<br>
# >> * **Le nom, le prénom, l’âge et l’ancienneté des employés, dans la société.**<br>
# >> * Le numéro de la commande, le temps écoulé entre la commande et la livraison de celle-ci ainsi que les frais de port.<br>
#
# ## Les ordres de tri
# >> * Les employés par ordre alphabétique.<br>
# >> * Les employés depuis le plus récemment embauché jusqu’au plus ancien.<br>
# >> * **Les fournisseurs dans l’ordre alphabétique de leur pays et ville de résidence.**<br>
# >> * Les employés par ordre alphabétique de leur fonction et du plus grand salaire au plus petit.<br>
# >> * Les employés dans l’ordre de leur commission.<br>
