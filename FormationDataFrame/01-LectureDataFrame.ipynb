# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Lecture-et-écriture-des-fichiers-avec-Pandas" data-toc-modified-id="Lecture-et-écriture-des-fichiers-avec-Pandas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Lecture et écriture des fichiers avec Pandas</a></span><ul class="toc-item"><li><span><a href="#Lecture-fichier1-CSV" data-toc-modified-id="Lecture-fichier1-CSV-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Lecture fichier1 CSV</a></span></li><li><span><a href="#Ecriture-fichier1-CSV" data-toc-modified-id="Ecriture-fichier1-CSV-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Ecriture fichier1 CSV</a></span></li><li><span><a href="#Lecture-fichier2-CSV" data-toc-modified-id="Lecture-fichier2-CSV-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Lecture fichier2 CSV</a></span></li><li><span><a href="#Ecriture-fichier2-CSV" data-toc-modified-id="Ecriture-fichier2-CSV-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Ecriture fichier2 CSV</a></span></li><li><span><a href="#Lecture-fichier3-CSV" data-toc-modified-id="Lecture-fichier3-CSV-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Lecture fichier3 CSV</a></span></li><li><span><a href="#Ecriture-fichier2-CSV" data-toc-modified-id="Ecriture-fichier2-CSV-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Ecriture fichier2 CSV</a></span></li><li><span><a href="#Lecture-fichier-EXCEL" data-toc-modified-id="Lecture-fichier-EXCEL-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Lecture fichier EXCEL</a></span></li><li><span><a href="#Ecriture-fichier-EXCEL" data-toc-modified-id="Ecriture-fichier-EXCEL-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Ecriture fichier EXCEL</a></span></li><li><span><a href="#Lecture-fichier-JSON" data-toc-modified-id="Lecture-fichier-JSON-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Lecture fichier JSON</a></span></li><li><span><a href="#Ecriture-fichier-JSON-to-CSV" data-toc-modified-id="Ecriture-fichier-JSON-to-CSV-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Ecriture fichier JSON to CSV</a></span></li></ul></li></ul></div>

# %%
import pandas as pd, os

# %% [markdown]
# # Lecture et écriture des fichiers avec Pandas

# %% [markdown]
# ## Lecture fichier1 CSV

# %%
varA=pd.read_csv("donnees/AirQualityUCI01.csv")
varA.head(3)
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# 1  13.3  47.7  0.7255          NaN          NaN
# 2  11.9  54.0  0.7502          NaN          NaN

# %%
varA.tail(3)
# Out:
#      Date Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 9468  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9469  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9470  NaN  NaN     NaN          NaN       NaN       NaN            NaN
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)   T  RH  AH  \
# 9468      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9469      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9470      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
#
#       Unnamed: 15  Unnamed: 16
# 9468          NaN          NaN
# 9469          NaN          NaN
# 9470          NaN          NaN

# %% [markdown]
# ## Ecriture fichier1 CSV

# %%
varA.to_csv("donnees/sauvegarde_AirQualityUCI01.csv",index=False)

# %% [markdown]
# ## Lecture fichier2 CSV

# %%
varA=pd.read_csv("donnees/AirQualityUCI02.csv", sep=";")
varA
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %% [markdown]
# ## Ecriture fichier2 CSV

# %%
varA.to_csv("donnees/sauvegarde_AirQualityUCI02.csv",index=False)

# %% [markdown]
# ## Lecture fichier3 CSV

# %%
varA=pd.read_csv("donnees/AirQualityUCI03.csv", sep="\t")
varA
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %% [markdown]
# ## Ecriture fichier2 CSV

# %%
varA.to_csv("donnees/sauvegarde_AirQualityUCI03.csv",index=False)

# %% [markdown]
# ## Lecture fichier EXCEL

# %% [raw]
# !pip install xlrd
# !pip install openpyxl

# %%
varA=pd.read_excel("donnees/Infarct.xlsx")
varA
# Out:
# /home/razvan/anaconda3/envs/coursDB/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#      NUMERO  INFARCT  CO  TABAC  AGE POIDS  TAILLE        IMC ATCD  HTA
# 0         1        0   0      0   47    48     173  16.037956    0    0
# 1         2        0   0      0   17     .     162          .    0    0
# 2         3        0   0      0   35    53     163  19.948059    0    0
# 3         4        0   0      0   82    78     157  31.644285    0    0
# 4         5        0   0      0   50    52     172  17.577068    .    0
# ..      ...      ...  ..    ...  ...   ...     ...        ...  ...  ...
# 444     445        1   1      2   31    67     162  25.529644    1    0
# 445     446        1   1      2   30    80     154  33.732502    1    0
# 446     447        1   1      2   42    67     167  24.023809    1    1
# ...

# %% [markdown]
# ## Ecriture fichier EXCEL

# %%
varA.to_excel("donnees/sauvegarde_Infarct.xlsx",index=False)

# %% [markdown]
# ## Lecture fichier JSON

# %%
varA=pd.read_json("donnees/agents.json",lines=True)
varA
# Out:
#               id   longitude   latitude country_name     sex
# 0      227417393  100.858407  33.152198        China    Male
# 1     6821129477  -72.437953  19.325568        Haiti  Female
# 2     2078667700   80.856365  23.645271        India  Female
# 3      477556555   93.336040  33.458647        China  Female
# 4     1379059984   80.772870  28.816938        India  Female
# ...          ...         ...        ...          ...     ...
# 9995  4510940262  105.925081  17.259746      Vietnam  Female
# 9996  4805300627    8.916702  51.148797      Germany  Female
# 9997   603596498  114.444277  40.196297        China    Male
# 9998  7058964901  -84.137412  10.061553   Costa Rica  Female
# 9999  1506725528   79.025016  13.363841        India  Female
#
# [10000 rows x 5 columns]

# %% [markdown]
# ## Ecriture fichier JSON to CSV

# %%
varA.to_csv("donnees/sauvegarde_agents.csv",index=False)

# %% [markdown]
# # Données Météo

# %%
# !ls -al donnees/synop*
# Out:
# -rw-rw-r-- 1 razvan razvan 4054875 sept. 30 23:10 donnees/synop.202309.csv
# -rw-rw-r-- 1 razvan razvan 4107655 oct.  31 22:10 donnees/synop.202310.csv

# %%
def lectureFichier(repertoire='donnees',fichier='synop.202309.csv'):
    meteo = pd.read_csv(os.path.join(repertoire,fichier),
                                               sep=';',
                                               usecols=['numer_sta','date','dd','ff','t','u','vv',
                                                        'pres','rr1','rr3','rr6','rr12','rr24'],
                                               na_values='mq',
                                               dtype={'numer_sta':str,'date':str},
                                              ).rename( columns={'numer_sta':'Station',
                                                                  'date':'DateHeure',
                                                                  'dd':'DirectionVent',
                                                                  'ff':'VitesseVent',
                                                                  't':'Temperature',
                                                                  'u':'Humidite',
                                                                  'vv':'Visibilite',
                                                                  'pres':'Pression',
                                                                  'rr1' :'Precipitation01',
                                                                  'rr3' :'Precipitation03',
                                                                  'rr6' :'Precipitation06',
                                                                  'rr12':'Precipitation12',
                                                                  'rr24':'Precipitation24'})
    meteo["DateHeure"] = pd.to_datetime(meteo["DateHeure"], format='%Y%m%d%H%M%S')
    meteo.Temperature  = meteo.Temperature - 273.15
    meteo.Pression     = meteo.Pression / 100
    meteo.Visibilite   = meteo.Visibilite / 1000
    return meteo

# %%
meteo1 = lectureFichier(repertoire='donnees',fichier='synop.202309.csv')
meteo1.shape
# Out:
# (14594, 13)

# %%
meteo2 = lectureFichier(repertoire='donnees',fichier='synop.202310.csv')
meteo2.shape
# Out:
# (14759, 13)

# %%
meteo = pd.concat([meteo1,meteo2],axis=0).reset_index().drop(columns='index')
meteo.shape
# Out:
# (29353, 13)

# %%
meteo.head()
# Out:
#   Station  DateHeure  DirectionVent  VitesseVent  Temperature  Humidite  \
# 0   07005 2023-09-01          230.0          1.7         17.4      97.0
# 1   07015 2023-09-01          160.0          1.8         15.5      98.0
# 2   07020 2023-09-01          210.0          6.5         18.0      97.0
# 3   07027 2023-09-01          200.0          4.6         17.2      92.0
# 4   07037 2023-09-01          250.0          4.7         16.3      98.0
#
#    Visibilite  Pression  Precipitation01  Precipitation03  Precipitation06  \
# 0        5.51    1002.7              0.4              0.8              2.0
# 1       11.01    1005.5              0.0              0.0              1.6
# 2        8.00    1008.4              1.6              3.8              6.4
# 3       28.84    1003.6             -0.1              0.2              0.6
# 4        7.03     993.8              2.9              5.5              5.7
#
#    Precipitation12  Precipitation24
# 0             12.3             12.3
# ...

# %%
meteo.tail()
# Out:
#       Station           DateHeure  DirectionVent  VitesseVent  Temperature  \
# 29348   81401 2023-10-31 21:00:00           40.0          1.3         30.1
# 29349   81405 2023-10-31 21:00:00           80.0          4.5         29.8
# 29350   81408 2023-10-31 21:00:00           60.0          3.0         30.5
# 29351   81415 2023-10-31 21:00:00           50.0          2.8         32.5
# 29352   89642 2023-10-31 21:00:00           90.0          3.1         -7.5
#
#        Humidite  Visibilite  Pression  Precipitation01  Precipitation03  \
# 29348      69.0         NaN    1007.2              0.0              0.0
# 29349      75.0       48.32    1007.5              0.0              0.0
# 29350      67.0         NaN    1006.9              0.0              0.0
# 29351      57.0         NaN       NaN              0.0              0.0
# 29352      60.0         NaN     949.0              NaN              NaN
#
#        Precipitation06  Precipitation12  Precipitation24
# ...
